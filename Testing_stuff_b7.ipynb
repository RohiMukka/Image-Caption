# %% [markdown]
# <a href="https://colab.research.google.com/github/RohiMukka/Image-Caption/blob/main/Testing_stuff_b7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import collections
import random
from tqdm import tqdm
import numpy as np
import os
import time
import json
from PIL import Image

# %%
# !wget https://storage.googleapis.com/cloud-tpu-checkpoints/efficientnet/noisystudent/noisy_student_efficientnet-b7.tar.gz
# Out:
# --2022-04-08 03:38:23--  https://storage.googleapis.com/cloud-tpu-checkpoints/efficientnet/noisystudent/noisy_student_efficientnet-b7.tar.gz
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.201.128, 142.250.152.128, 173.194.193.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.201.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 491946092 (469M) [application/octet-stream]
# Saving to: ‘noisy_student_efficientnet-b7.tar.gz’
#
# noisy_student_effic 100%[===================>] 469.16M   112MB/s    in 4.7s
#
# 2022-04-08 03:38:28 (100 MB/s) - ‘noisy_student_efficientnet-b7.tar.gz’ saved [491946092/491946092]

# %%
# !tar -xf noisy_student_efficientnet-b7.tar.gz

# %%
#!wget https://github.com/MarkusRosen/keras-efficientnet-regression/blob/master/efficientnet_weight_update_util.py
# !python weight_update_util.py --model b7 --notop --ckpt /content/noisy_student_efficientnet-b7/model.ckpt --o efficientnetb7_notop.h5
# Out:
# 2022-04-08 03:39:49.823711: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb7_notop.h5
# 258080768/258076736 [==============================] - 1s 0us/step
# 258088960/258076736 [==============================] - 1s 0us/step
# check variables match in each block
# blocks_0 and block1a match.
# blocks_1 and block1b match.
# blocks_2 and block1c match.
# blocks_3 and block1d match.
# blocks_4 and block2a match.
# blocks_5 and block2b match.
# blocks_6 and block2c match.
# blocks_7 and block2d match.
# blocks_8 and block2e match.
# blocks_9 and block2f match.
# blocks_10 and block2g match.
# blocks_11 and block3a match.
# blocks_12 and block3b match.
# blocks_13 and block3c match.
# blocks_14 and block3d match.
# blocks_15 and block3e match.
# blocks_16 and block3f match.
# blocks_17 and block3g match.
# blocks_18 and block4a match.
# blocks_19 and block4b match.
# blocks_20 and block4c match.
# blocks_21 and block4d match.
# blocks_22 and block4e match.
# blocks_23 and block4f match.
# blocks_24 and block4g match.
# blocks_25 and block4h match.
# blocks_26 and block4i match.
# blocks_27 and block4j match.
# blocks_28 and block5a match.
# blocks_29 and block5b match.
# blocks_30 and block5c match.
# blocks_31 and block5d match.
# blocks_32 and block5e match.
# blocks_33 and block5f match.
# blocks_34 and block5g match.
# blocks_35 and block5h match.
# blocks_36 and block5i match.
# blocks_37 and block5j match.
# blocks_38 and block6a match.
# blocks_39 and block6b match.
# blocks_40 and block6c match.
# blocks_41 and block6d match.
# blocks_42 and block6e match.
# blocks_43 and block6f match.
# blocks_44 and block6g match.
# blocks_45 and block6h match.
# blocks_46 and block6i match.
# blocks_47 and block6j match.
# blocks_48 and block6k match.
# blocks_49 and block6l match.
# blocks_50 and block6m match.
# blocks_51 and block7a match.
# blocks_52 and block7b match.
# blocks_53 and block7c match.
# blocks_54 and block7d match.
# skipping variable normalization/mean:0: normalization is a layerin keras implementation, but preprocessing in TF implementation.
# skipping variable normalization/variance:0: normalization is a layerin keras implementation, but preprocessing in TF implementation.
# skipping variable normalization/count:0: normalization is a layerin keras implementation, but preprocessing in TF implementation.
# 1035/1038 weights updated

# %%
#!unzip /content/noisy.student.notop-b6.h5.zip
#from efficientnet.model import EfficientNetB6
#!pip install efficientnet
#import efficientnet.keras as efn 

#model = efn.EfficientNetB6(weights="/content/noisy.student.notop-b6.h5", include_top=False)
#model = EfficientNetB6(weights="/content/noisy.student.notop-b6.h5", include_top=False)

# %%
# Download caption annotation files
annotation_folder = '/annotations/'
if not os.path.exists(os.path.abspath('.') + annotation_folder):
  annotation_zip = tf.keras.utils.get_file('captions.zip',
                                           cache_subdir=os.path.abspath('.'),
                                           origin='http://images.cocodataset.org/annotations/annotations_trainval2017.zip',
                                           extract=True)
  annotation_file = os.path.dirname(annotation_zip)+'/annotations/captions_train2017.json'
  os.remove(annotation_zip)

# Download image files
image_folder = '/train2017/'
if not os.path.exists(os.path.abspath('.') + image_folder):
  image_zip = tf.keras.utils.get_file('train2017.zip',
                                      cache_subdir=os.path.abspath('.'),
                                      origin='http://images.cocodataset.org/zips/train2017.zip',
                                      extract=True)
  PATH = os.path.dirname(image_zip) + image_folder
  os.remove(image_zip)
else:
  PATH = os.path.abspath('.') + image_folder
# Out:
# Downloading data from http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# 252911616/252907541 [==============================] - 3s 0us/step
# 252919808/252907541 [==============================] - 3s 0us/step
# Downloading data from http://images.cocodataset.org/zips/train2017.zip
# 19336863744/19336861798 [==============================] - 423s 0us/step
# 19336871936/19336861798 [==============================] - 423s 0us/step

# %%
with open(annotation_file, 'r') as f:
    annotations = json.load(f)

# %%
# Group all captions together having the same image ID.
image_path_to_caption = collections.defaultdict(list)
for val in annotations['annotations']:
  caption = f"<start> {val['caption']} <end>"
  image_path = PATH + '%012d.jpg' % (val['image_id'])
  image_path_to_caption[image_path].append(caption)

# %%
image_paths = list(image_path_to_caption.keys())
random.shuffle(image_paths)
train_image_paths = image_paths
print("Number of images : ",len(image_paths),"\nDataset size: ",len(train_image_paths))
# Out:
# Number of images :  118287
# Dataset size:  118287

# %%
train_captions=[]
img_name_vector=[]

for path in train_image_paths:
    caption_list=image_path_to_caption[path]
    train_captions.extend(caption_list)
    img_name_vector.extend([path]*len(caption_list))

# %%
print(train_captions[1])
Image.open(img_name_vector[1])
# Out:
# <start> A sign on a pole in front on a building <end>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=427x640 at 0x7FC1AB7D5550>

# %%
def load_image(image_path):
    img=tf.io.read_file(image_path)
    img=tf.io.decode_jpeg(img,channels=3)
    img=tf.keras.layers.Resizing(300,300)(img)
    img=tf.keras.applications.efficientnet.preprocess_input(img)
    return img, image_path

# %%
Image_Model=tf.keras.applications.EfficientNetB7(include_top=False,weights='/content/efficientnetb7_notop.h5')
new_input = Image_Model.input
hidden_layer=Image_Model.layers[-1].output
image_features_extract=tf.keras.Model(new_input,hidden_layer)

# %%
encode_train=sorted(set(img_name_vector))
image_dataset=tf.data.Dataset.from_tensor_slices(encode_train)
image_dataset=image_dataset.map(load_image,num_parallel_calls=tf.data.AUTOTUNE).batch(64)

for img,path in tqdm(image_dataset):
    batch_features=image_features_extract(img)
    batch_features=tf.reshape(batch_features,(batch_features.shape[0],-1,batch_features.shape[3]))
    for bf, p in zip(batch_features,path):
        path_of_feature=p.numpy().decode("utf-8")
        np.save(path_of_feature,bf.numpy())
# Out:
# 100%|██████████| 1849/1849 [29:57<00:00,  1.03it/s]

# %%
caption_dataset= tf.data.Dataset.from_tensor_slices(train_captions)

def standardize(inputs):
    inputs=tf.strings.lower(inputs)
    return tf.strings.regex_replace(inputs,r'''!\"#$%\(\)\*\+.,-/:;=?@\[\\\]^_`{|}~''',"")

max_length=50 #max word count
vocabulary_size=15000
tokenizer=tf.keras.layers.TextVectorization(max_tokens=vocabulary_size,standardize=standardize,output_sequence_length=max_length)
tokenizer.adapt(caption_dataset)

# %%
cap_vector = caption_dataset.map(lambda x: tokenizer(x))

# %%
word_to_index = tf.keras.layers.StringLookup(
    mask_token="",
    vocabulary=tokenizer.get_vocabulary())
index_to_word = tf.keras.layers.StringLookup(
    mask_token="",
    vocabulary=tokenizer.get_vocabulary(),
    invert=True)

# %%
img_to_cap_vector = collections.defaultdict(list)
for img, cap in zip(img_name_vector, cap_vector):
  img_to_cap_vector[img].append(cap)

# Create training and validation sets using an 80-20 split randomly.
img_keys = list(img_to_cap_vector.keys())
random.shuffle(img_keys)

slice_index = int(len(img_keys)*0.8)
img_name_train_keys, img_name_val_keys = img_keys[:slice_index], img_keys[slice_index:]

img_name_train = []
cap_train = []
for imgt in img_name_train_keys:
  capt_len = len(img_to_cap_vector[imgt])
  img_name_train.extend([imgt] * capt_len)
  cap_train.extend(img_to_cap_vector[imgt])

img_name_val = []
cap_val = []
for imgv in img_name_val_keys:
  capv_len = len(img_to_cap_vector[imgv])
  img_name_val.extend([imgv] * capv_len)
  cap_val.extend(img_to_cap_vector[imgv])

# %%
len(img_name_train), len(cap_train), len(img_name_val), len(cap_val)
# Out:
# (473402, 473402, 118351, 118351)

# %%
BATCH_SIZE = 64
BUFFER_SIZE = 1000
embedding_dim = 600
units = 512
num_steps = len(img_name_train) // BATCH_SIZE
# These two variables represent that vector shape
features_shape = 2560
attention_features_shape = 81

# %%
def map_func(img_name, cap):
  img_tensor = np.load(img_name.decode('utf-8')+'.npy')
  return img_tensor, cap

# %%
dataset = tf.data.Dataset.from_tensor_slices((img_name_train, cap_train))

# Use map to load the numpy files in parallel
dataset = dataset.map(lambda item1, item2: tf.numpy_function(
          map_func, [item1, item2], [tf.float32, tf.int64]),
          num_parallel_calls=tf.data.AUTOTUNE)

# Shuffle and batch
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
dataset = dataset.prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
class BahdanauAttention(tf.keras.Model):
  def __init__(self, units):
    super(BahdanauAttention, self).__init__()
    self.W1 = tf.keras.layers.Dense(units)
    self.W2 = tf.keras.layers.Dense(units)
    self.V = tf.keras.layers.Dense(1)

  def call(self, features, hidden):
    
    hidden_with_time_axis = tf.expand_dims(hidden, 1)

    
    attention_hidden_layer = (tf.nn.tanh(self.W1(features) +
                                         self.W2(hidden_with_time_axis)))

    
    score = self.V(attention_hidden_layer)

    
    attention_weights = tf.nn.softmax(score, axis=1)

    
    context_vector = attention_weights * features
    context_vector = tf.reduce_sum(context_vector, axis=1)

    return context_vector, attention_weights

# %%
class CNN_Encoder(tf.keras.Model):
    
    def __init__(self, embedding_dim):
        super(CNN_Encoder, self).__init__()
        
        self.fc = tf.keras.layers.Dense(embedding_dim)

    def call(self, x):
        x = self.fc(x)
        x = tf.nn.relu(x)
        return x

# %%
class RNN_Decoder(tf.keras.Model):
  def __init__(self, embedding_dim, units, vocab_size):
    super(RNN_Decoder, self).__init__()
    self.units = units

    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc1 = tf.keras.layers.Dense(self.units)
    self.fc2 = tf.keras.layers.Dense(vocab_size)

    self.attention = BahdanauAttention(self.units)

  def call(self, x, features, hidden):
    # defining attention as a separate model
    context_vector, attention_weights = self.attention(features, hidden)
    x = self.embedding(x)
    x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)
    output, state = self.gru(x)
    x = self.fc1(output)
    x = tf.reshape(x, (-1, x.shape[2]))
    x = self.fc2(x)

    return x, state, attention_weights

  def reset_state(self, batch_size):
    return tf.zeros((batch_size, self.units))

# %%
encoder = CNN_Encoder(embedding_dim)
decoder = RNN_Decoder(embedding_dim, units, tokenizer.vocabulary_size())

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')


def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %%
checkpoint_path = "./checkpoints/train"
ckpt = tf.train.Checkpoint(encoder=encoder,
                           decoder=decoder,
                           optimizer=optimizer)
ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# %%
start_epoch = 0
if ckpt_manager.latest_checkpoint:
  start_epoch = int(ckpt_manager.latest_checkpoint.split('-')[-1])
  # restoring the latest checkpoint in checkpoint_path
  ckpt.restore(ckpt_manager.latest_checkpoint)

# %%
loss_plot = []

# %%
@tf.function
def train_step(img_tensor, target):
  loss = 0


  hidden = decoder.reset_state(batch_size=target.shape[0])

  dec_input = tf.expand_dims([word_to_index('<start>')] * target.shape[0], 1)

  with tf.GradientTape() as tape:
      features = encoder(img_tensor)

      for i in range(1, target.shape[1]):
          # passing the features through the decoder
          predictions, hidden, _ = decoder(dec_input, features, hidden)

          loss += loss_function(target[:, i], predictions)

          # using teacher forcing
          dec_input = tf.expand_dims(target[:, i], 1)

  total_loss = (loss / int(target.shape[1]))

  trainable_variables = encoder.trainable_variables + decoder.trainable_variables

  gradients = tape.gradient(loss, trainable_variables)

  optimizer.apply_gradients(zip(gradients, trainable_variables))

  return loss, total_loss

# %%
EPOCHS = 25

for epoch in range(start_epoch, EPOCHS):
    start = time.time()
    total_loss = 0

    for (batch, (img_tensor, target)) in enumerate(dataset):
        batch_loss, t_loss = train_step(img_tensor, target)
        total_loss += t_loss

        if batch % 100 == 0:
            average_batch_loss = batch_loss.numpy()/int(target.shape[1])
            print(f'Epoch {epoch+1} Batch {batch} Loss {average_batch_loss:.4f}')
    # storing the epoch end loss value to plot later
    loss_plot.append(total_loss / num_steps)

    if epoch % 5 == 0:
      ckpt_manager.save()

    print(f'Epoch {epoch+1} Loss {total_loss/num_steps:.6f}')
    print(f'Time taken for 1 epoch {time.time()-start:.2f} sec\n')
# Out:
# Epoch 1 Batch 0 Loss 2.1518
# Epoch 1 Batch 100 Loss 1.2008
# Epoch 1 Batch 200 Loss 1.2112
# Epoch 1 Batch 300 Loss 0.9618
# Epoch 1 Batch 400 Loss 0.8797
# Epoch 1 Batch 500 Loss 0.8560
# Epoch 1 Batch 600 Loss 0.7794
# Epoch 1 Batch 700 Loss 0.6936
# Epoch 1 Batch 800 Loss 0.8460
# Epoch 1 Batch 900 Loss 0.8120
# Epoch 1 Batch 1000 Loss 0.8172
# Epoch 1 Batch 1100 Loss 0.7912
# Epoch 1 Batch 1200 Loss 0.8583
# Epoch 1 Batch 1300 Loss 0.7084
# Epoch 1 Batch 1400 Loss 0.7214
# Epoch 1 Batch 1500 Loss 0.6840
# Epoch 1 Batch 1600 Loss 0.6423
# Epoch 1 Batch 1700 Loss 0.7547
# Epoch 1 Batch 1800 Loss 0.7292
# Epoch 1 Batch 1900 Loss 0.6834
# Epoch 1 Batch 2000 Loss 0.7389
# Epoch 1 Batch 2100 Loss 0.6956
# Epoch 1 Batch 2200 Loss 0.6351
# Epoch 1 Batch 2300 Loss 0.6809
# Epoch 1 Batch 2400 Loss 0.6249
# Epoch 1 Batch 2500 Loss 0.6614
# Epoch 1 Batch 2600 Loss 0.6773
# Epoch 1 Batch 2700 Loss 0.6571
# Epoch 1 Batch 2800 Loss 0.6941
# Epoch 1 Batch 2900 Loss 0.6612
# Epoch 1 Batch 3000 Loss 0.6867
# Epoch 1 Batch 3100 Loss 0.6904
# Epoch 1 Batch 3200 Loss 0.6248
# Epoch 1 Batch 3300 Loss 0.6184
# Epoch 1 Batch 3400 Loss 0.5962
# Epoch 1 Batch 3500 Loss 0.6741
# Epoch 1 Batch 3600 Loss 0.6997
# Epoch 1 Batch 3700 Loss 0.6762
# Epoch 1 Batch 3800 Loss 0.6425
# Epoch 1 Batch 3900 Loss 0.6172
# Epoch 1 Batch 4000 Loss 0.6538
# Epoch 1 Batch 4100 Loss 0.7029
# Epoch 1 Batch 4200 Loss 0.7179
# Epoch 1 Batch 4300 Loss 0.7108
# Epoch 1 Batch 4400 Loss 0.6921
# Epoch 1 Batch 4500 Loss 0.6460
# Epoch 1 Batch 4600 Loss 0.6531
# Epoch 1 Batch 4700 Loss 0.6284
# Epoch 1 Batch 4800 Loss 0.6959
# Epoch 1 Batch 4900 Loss 0.6424
# Epoch 1 Batch 5000 Loss 0.6827
# Epoch 1 Batch 5100 Loss 0.6504
# Epoch 1 Batch 5200 Loss 0.6333
# Epoch 1 Batch 5300 Loss 0.6530
# Epoch 1 Batch 5400 Loss 0.5612
# Epoch 1 Batch 5500 Loss 0.6897
# Epoch 1 Batch 5600 Loss 0.6385
# Epoch 1 Batch 5700 Loss 0.6136
# Epoch 1 Batch 5800 Loss 0.5813
# Epoch 1 Batch 5900 Loss 0.5794
# Epoch 1 Batch 6000 Loss 0.5926
# Epoch 1 Batch 6100 Loss 0.6101
# Epoch 1 Batch 6200 Loss 0.6106
# Epoch 1 Batch 6300 Loss 0.6323
# Epoch 1 Batch 6400 Loss 0.6060
# Epoch 1 Batch 6500 Loss 0.7240
# Epoch 1 Batch 6600 Loss 0.5957
# Epoch 1 Batch 6700 Loss 0.6877
# Epoch 1 Batch 6800 Loss 0.5948
# Epoch 1 Batch 6900 Loss 0.6091
# Epoch 1 Batch 7000 Loss 0.6224
# Epoch 1 Batch 7100 Loss 0.5979
# Epoch 1 Batch 7200 Loss 0.5870
# Epoch 1 Batch 7300 Loss 0.6516
# Epoch 1 Loss 0.696370
# Time taken for 1 epoch 2092.94 sec
#
# Epoch 2 Batch 0 Loss 0.6052
# Epoch 2 Batch 100 Loss 0.6073
# Epoch 2 Batch 200 Loss 0.5482
# Epoch 2 Batch 300 Loss 0.5823
# Epoch 2 Batch 400 Loss 0.6193
# Epoch 2 Batch 500 Loss 0.6214
# Epoch 2 Batch 600 Loss 0.6551
# Epoch 2 Batch 700 Loss 0.6020
# Epoch 2 Batch 800 Loss 0.6525
# Epoch 2 Batch 900 Loss 0.5815
# Epoch 2 Batch 1000 Loss 0.6095
# Epoch 2 Batch 1100 Loss 0.5840
# Epoch 2 Batch 1200 Loss 0.6062
# Epoch 2 Batch 1300 Loss 0.5780
# Epoch 2 Batch 1400 Loss 0.5220
# Epoch 2 Batch 1500 Loss 0.6126
# Epoch 2 Batch 1600 Loss 0.5907
# Epoch 2 Batch 1700 Loss 0.6027
# Epoch 2 Batch 1800 Loss 0.6461
# Epoch 2 Batch 1900 Loss 0.6393
# Epoch 2 Batch 2000 Loss 0.6301
# Epoch 2 Batch 2100 Loss 0.5470
# Epoch 2 Batch 2200 Loss 0.5691
# Epoch 2 Batch 2300 Loss 0.6010
# Epoch 2 Batch 2400 Loss 0.5496
# Epoch 2 Batch 2500 Loss 0.6233
# Epoch 2 Batch 2600 Loss 0.6136
# Epoch 2 Batch 2700 Loss 0.5931
# Epoch 2 Batch 2800 Loss 0.5978
# Epoch 2 Batch 2900 Loss 0.5529
# Epoch 2 Batch 3000 Loss 0.6794
# Epoch 2 Batch 3100 Loss 0.5451
# Epoch 2 Batch 3200 Loss 0.6205
# Epoch 2 Batch 3300 Loss 0.5517
# Epoch 2 Batch 3400 Loss 0.5908
# Epoch 2 Batch 3500 Loss 0.6065
# Epoch 2 Batch 3600 Loss 0.6149
# Epoch 2 Batch 3700 Loss 0.6386
# Epoch 2 Batch 3800 Loss 0.6449
# Epoch 2 Batch 3900 Loss 0.5931
# Epoch 2 Batch 4000 Loss 0.6057
# Epoch 2 Batch 4100 Loss 0.5746
# Epoch 2 Batch 4200 Loss 0.6609
# Epoch 2 Batch 4300 Loss 0.6366
# Epoch 2 Batch 4400 Loss 0.6320
# Epoch 2 Batch 4500 Loss 0.6043
# Epoch 2 Batch 4600 Loss 0.5925
# Epoch 2 Batch 4700 Loss 0.5989
# Epoch 2 Batch 4800 Loss 0.6192
# Epoch 2 Batch 4900 Loss 0.5774
# Epoch 2 Batch 5000 Loss 0.5786
# Epoch 2 Batch 5100 Loss 0.5127
# Epoch 2 Batch 5200 Loss 0.6190
# Epoch 2 Batch 5300 Loss 0.5938
# Epoch 2 Batch 5400 Loss 0.5762
# Epoch 2 Batch 5500 Loss 0.5587
# Epoch 2 Batch 5600 Loss 0.6506
# Epoch 2 Batch 5700 Loss 0.5841
# Epoch 2 Batch 5800 Loss 0.5823
# Epoch 2 Batch 5900 Loss 0.5934
# Epoch 2 Batch 6000 Loss 0.5871
# Epoch 2 Batch 6100 Loss 0.5937
# Epoch 2 Batch 6200 Loss 0.5350
# Epoch 2 Batch 6300 Loss 0.5746
# Epoch 2 Batch 6400 Loss 0.6222
# Epoch 2 Batch 6500 Loss 0.5878
# Epoch 2 Batch 6600 Loss 0.6306
# Epoch 2 Batch 6700 Loss 0.6371
# Epoch 2 Batch 6800 Loss 0.6065
# Epoch 2 Batch 6900 Loss 0.5897
# Epoch 2 Batch 7000 Loss 0.5470
# Epoch 2 Batch 7100 Loss 0.6037
# Epoch 2 Batch 7200 Loss 0.5728
# Epoch 2 Batch 7300 Loss 0.5826
# Epoch 2 Loss 0.601262
# Time taken for 1 epoch 2003.28 sec
#
# Epoch 3 Batch 0 Loss 0.5628
# Epoch 3 Batch 100 Loss 0.5543
# Epoch 3 Batch 200 Loss 0.6120
# Epoch 3 Batch 300 Loss 0.6059
# Epoch 3 Batch 400 Loss 0.6084
# Epoch 3 Batch 500 Loss 0.5409
# Epoch 3 Batch 600 Loss 0.5744
# Epoch 3 Batch 700 Loss 0.5495
# Epoch 3 Batch 800 Loss 0.6100
# Epoch 3 Batch 900 Loss 0.6280
# Epoch 3 Batch 1000 Loss 0.6122
# Epoch 3 Batch 1100 Loss 0.5603
# Epoch 3 Batch 1200 Loss 0.5825
# Epoch 3 Batch 1300 Loss 0.5661
# Epoch 3 Batch 1400 Loss 0.5321
# Epoch 3 Batch 1500 Loss 0.6143
# Epoch 3 Batch 1600 Loss 0.5681
# Epoch 3 Batch 1700 Loss 0.5442
# Epoch 3 Batch 1800 Loss 0.5948
# Epoch 3 Batch 1900 Loss 0.5367
# Epoch 3 Batch 2000 Loss 0.5564
# Epoch 3 Batch 2100 Loss 0.5495
# Epoch 3 Batch 2200 Loss 0.5978
# Epoch 3 Batch 2300 Loss 0.5417
# Epoch 3 Batch 2400 Loss 0.5357
# Epoch 3 Batch 2500 Loss 0.5729
# Epoch 3 Batch 2600 Loss 0.5334
# Epoch 3 Batch 2700 Loss 0.5969
# Epoch 3 Batch 2800 Loss 0.5808
# Epoch 3 Batch 2900 Loss 0.6050
# Epoch 3 Batch 3000 Loss 0.5687
# Epoch 3 Batch 3100 Loss 0.5438
# Epoch 3 Batch 3200 Loss 0.5328
# Epoch 3 Batch 3300 Loss 0.5608
# Epoch 3 Batch 3400 Loss 0.5710
# Epoch 3 Batch 3500 Loss 0.5802
# Epoch 3 Batch 3600 Loss 0.6165
# Epoch 3 Batch 3700 Loss 0.5703
# Epoch 3 Batch 3800 Loss 0.5406
# Epoch 3 Batch 3900 Loss 0.5517
# Epoch 3 Batch 4000 Loss 0.5705
# Epoch 3 Batch 4100 Loss 0.5216
# Epoch 3 Batch 4200 Loss 0.5459
# Epoch 3 Batch 4300 Loss 0.5691
# Epoch 3 Batch 4400 Loss 0.5363
# Epoch 3 Batch 4500 Loss 0.5450
# Epoch 3 Batch 4600 Loss 0.5587
# Epoch 3 Batch 4700 Loss 0.5597
# Epoch 3 Batch 4800 Loss 0.5496
# Epoch 3 Batch 4900 Loss 0.5872
# Epoch 3 Batch 5000 Loss 0.5253
# Epoch 3 Batch 5100 Loss 0.5676
# Epoch 3 Batch 5200 Loss 0.6266
# Epoch 3 Batch 5300 Loss 0.5136
# Epoch 3 Batch 5400 Loss 0.5581
# Epoch 3 Batch 5500 Loss 0.5376
# Epoch 3 Batch 5600 Loss 0.5440
# Epoch 3 Batch 5700 Loss 0.5516
# Epoch 3 Batch 5800 Loss 0.5417
# Epoch 3 Batch 5900 Loss 0.6076
# Epoch 3 Batch 6000 Loss 0.5899
# Epoch 3 Batch 6100 Loss 0.5633
# Epoch 3 Batch 6200 Loss 0.5282
# Epoch 3 Batch 6300 Loss 0.5633
# Epoch 3 Batch 6400 Loss 0.5313
# Epoch 3 Batch 6500 Loss 0.5421
# Epoch 3 Batch 6600 Loss 0.5455
# Epoch 3 Batch 6700 Loss 0.5469
# Epoch 3 Batch 6800 Loss 0.5999
# Epoch 3 Batch 6900 Loss 0.5399
# Epoch 3 Batch 7000 Loss 0.5325
# Epoch 3 Batch 7100 Loss 0.5301
# Epoch 3 Batch 7200 Loss 0.5675
# Epoch 3 Batch 7300 Loss 0.5662
# Epoch 3 Loss 0.569949
# Time taken for 1 epoch 2002.50 sec
#
# Epoch 4 Batch 0 Loss 0.5968
# Epoch 4 Batch 100 Loss 0.6011
# Epoch 4 Batch 200 Loss 0.5455
# Epoch 4 Batch 300 Loss 0.5241
# Epoch 4 Batch 400 Loss 0.5747
# Epoch 4 Batch 500 Loss 0.5479
# Epoch 4 Batch 600 Loss 0.5944
# Epoch 4 Batch 700 Loss 0.5607
# Epoch 4 Batch 800 Loss 0.4602
# Epoch 4 Batch 900 Loss 0.5805
# Epoch 4 Batch 1000 Loss 0.5409
# Epoch 4 Batch 1100 Loss 0.5453
# Epoch 4 Batch 1200 Loss 0.6216
# Epoch 4 Batch 1300 Loss 0.5258
# Epoch 4 Batch 1400 Loss 0.4926
# Epoch 4 Batch 1500 Loss 0.5716
# Epoch 4 Batch 1600 Loss 0.5288
# Epoch 4 Batch 1700 Loss 0.6329
# Epoch 4 Batch 1800 Loss 0.5559
# Epoch 4 Batch 1900 Loss 0.5131
# Epoch 4 Batch 2000 Loss 0.6028
# Epoch 4 Batch 2100 Loss 0.4627
# Epoch 4 Batch 2200 Loss 0.4963
# Epoch 4 Batch 2300 Loss 0.5298
# Epoch 4 Batch 2400 Loss 0.5595
# Epoch 4 Batch 2500 Loss 0.5713
# Epoch 4 Batch 2600 Loss 0.5553
# Epoch 4 Batch 2700 Loss 0.6187
# Epoch 4 Batch 2800 Loss 0.5612
# Epoch 4 Batch 2900 Loss 0.5193
# Epoch 4 Batch 3000 Loss 0.5699
# Epoch 4 Batch 3100 Loss 0.5649
# Epoch 4 Batch 3200 Loss 0.5637
# Epoch 4 Batch 3300 Loss 0.5847
# Epoch 4 Batch 3400 Loss 0.5588
# Epoch 4 Batch 3500 Loss 0.5182
# Epoch 4 Batch 3600 Loss 0.6044
# Epoch 4 Batch 3700 Loss 0.5181
# Epoch 4 Batch 3800 Loss 0.5714
# Epoch 4 Batch 3900 Loss 0.5358
# Epoch 4 Batch 4000 Loss 0.5347
# Epoch 4 Batch 4100 Loss 0.5667
# Epoch 4 Batch 4200 Loss 0.5506
# Epoch 4 Batch 4300 Loss 0.5230
# Epoch 4 Batch 4400 Loss 0.5044
# Epoch 4 Batch 4500 Loss 0.4660
# Epoch 4 Batch 4600 Loss 0.5907
# Epoch 4 Batch 4700 Loss 0.5342
# Epoch 4 Batch 4800 Loss 0.5710
# Epoch 4 Batch 4900 Loss 0.5209
# Epoch 4 Batch 5000 Loss 0.4751
# Epoch 4 Batch 5100 Loss 0.5453
# Epoch 4 Batch 5200 Loss 0.5597
# Epoch 4 Batch 5300 Loss 0.5152
# Epoch 4 Batch 5400 Loss 0.5770
# Epoch 4 Batch 5500 Loss 0.5392
# Epoch 4 Batch 5600 Loss 0.5425
# Epoch 4 Batch 5700 Loss 0.5353
# Epoch 4 Batch 5800 Loss 0.4966
# Epoch 4 Batch 5900 Loss 0.6228
# Epoch 4 Batch 6000 Loss 0.5834
# Epoch 4 Batch 6100 Loss 0.5658
# Epoch 4 Batch 6200 Loss 0.5474
# Epoch 4 Batch 6300 Loss 0.5455
# Epoch 4 Batch 6400 Loss 0.5290
# Epoch 4 Batch 6500 Loss 0.5189
# Epoch 4 Batch 6600 Loss 0.5526
# Epoch 4 Batch 6700 Loss 0.5441
# Epoch 4 Batch 6800 Loss 0.5360
# Epoch 4 Batch 6900 Loss 0.5572
# Epoch 4 Batch 7000 Loss 0.5166
# Epoch 4 Batch 7100 Loss 0.5376
# Epoch 4 Batch 7200 Loss 0.5701
# Epoch 4 Batch 7300 Loss 0.5587
# Epoch 4 Loss 0.548404
# Time taken for 1 epoch 2001.47 sec
#
# Epoch 5 Batch 0 Loss 0.5563
# Epoch 5 Batch 100 Loss 0.5345
# Epoch 5 Batch 200 Loss 0.5075
# Epoch 5 Batch 300 Loss 0.5117
# Epoch 5 Batch 400 Loss 0.5389
# Epoch 5 Batch 500 Loss 0.5185
# Epoch 5 Batch 600 Loss 0.5243
# Epoch 5 Batch 700 Loss 0.5654
# Epoch 5 Batch 800 Loss 0.5369
# Epoch 5 Batch 900 Loss 0.5112
# Epoch 5 Batch 1000 Loss 0.5389
# Epoch 5 Batch 1100 Loss 0.5170
# Epoch 5 Batch 1200 Loss 0.5403
# Epoch 5 Batch 1300 Loss 0.5210
# Epoch 5 Batch 1400 Loss 0.4989
# Epoch 5 Batch 1500 Loss 0.4741
# Epoch 5 Batch 1600 Loss 0.5521
# Epoch 5 Batch 1700 Loss 0.4909
# Epoch 5 Batch 1800 Loss 0.5292
# Epoch 5 Batch 1900 Loss 0.5618
# Epoch 5 Batch 2000 Loss 0.5063
# Epoch 5 Batch 2100 Loss 0.5390
# Epoch 5 Batch 2200 Loss 0.5306
# Epoch 5 Batch 2300 Loss 0.5475
# Epoch 5 Batch 2400 Loss 0.5524
# Epoch 5 Batch 2500 Loss 0.5570
# Epoch 5 Batch 2600 Loss 0.5443
# Epoch 5 Batch 2700 Loss 0.5833
# Epoch 5 Batch 2800 Loss 0.5808
# Epoch 5 Batch 2900 Loss 0.5512
# Epoch 5 Batch 3000 Loss 0.5344
# Epoch 5 Batch 3100 Loss 0.5215
# Epoch 5 Batch 3200 Loss 0.5263
# Epoch 5 Batch 3300 Loss 0.5468
# Epoch 5 Batch 3400 Loss 0.5453
# Epoch 5 Batch 3500 Loss 0.4990
# Epoch 5 Batch 3600 Loss 0.5695
# Epoch 5 Batch 3700 Loss 0.4899
# Epoch 5 Batch 3800 Loss 0.5026
# Epoch 5 Batch 3900 Loss 0.5175
# Epoch 5 Batch 4000 Loss 0.5688
# Epoch 5 Batch 4100 Loss 0.5110
# Epoch 5 Batch 4200 Loss 0.4817
# Epoch 5 Batch 4300 Loss 0.5675
# Epoch 5 Batch 4400 Loss 0.5189
# Epoch 5 Batch 4500 Loss 0.5081
# Epoch 5 Batch 4600 Loss 0.6065
# Epoch 5 Batch 4700 Loss 0.5134
# Epoch 5 Batch 4800 Loss 0.5446
# Epoch 5 Batch 4900 Loss 0.4992
# Epoch 5 Batch 5000 Loss 0.5186
# Epoch 5 Batch 5100 Loss 0.5247
# Epoch 5 Batch 5200 Loss 0.5250
# Epoch 5 Batch 5300 Loss 0.5399
# Epoch 5 Batch 5400 Loss 0.5087
# Epoch 5 Batch 5500 Loss 0.5246
# Epoch 5 Batch 5600 Loss 0.5238
# Epoch 5 Batch 5700 Loss 0.5640
# Epoch 5 Batch 5800 Loss 0.5993
# Epoch 5 Batch 5900 Loss 0.4672
# Epoch 5 Batch 6000 Loss 0.5040
# Epoch 5 Batch 6100 Loss 0.5083
# Epoch 5 Batch 6200 Loss 0.5649
# Epoch 5 Batch 6300 Loss 0.5244
# Epoch 5 Batch 6400 Loss 0.5134
# Epoch 5 Batch 6500 Loss 0.5745
# Epoch 5 Batch 6600 Loss 0.5558
# Epoch 5 Batch 6700 Loss 0.5048
# Epoch 5 Batch 6800 Loss 0.5441
# Epoch 5 Batch 6900 Loss 0.5542
# Epoch 5 Batch 7000 Loss 0.5534
# Epoch 5 Batch 7100 Loss 0.5287
# Epoch 5 Batch 7200 Loss 0.5248
# Epoch 5 Batch 7300 Loss 0.5333
# Epoch 5 Loss 0.530934
# Time taken for 1 epoch 2003.14 sec
#
# Epoch 6 Batch 0 Loss 0.5299
# Epoch 6 Batch 100 Loss 0.5260
# Epoch 6 Batch 200 Loss 0.5002
# Epoch 6 Batch 300 Loss 0.5380
# Epoch 6 Batch 400 Loss 0.5179
# Epoch 6 Batch 500 Loss 0.5230
# Epoch 6 Batch 600 Loss 0.5065
# Epoch 6 Batch 700 Loss 0.5486
# Epoch 6 Batch 800 Loss 0.5478
# Epoch 6 Batch 900 Loss 0.4880
# Epoch 6 Batch 1000 Loss 0.5377
# Epoch 6 Batch 1100 Loss 0.5048
# Epoch 6 Batch 1200 Loss 0.5364
# Epoch 6 Batch 1300 Loss 0.4796
# Epoch 6 Batch 1400 Loss 0.5003
# Epoch 6 Batch 1500 Loss 0.5392
# Epoch 6 Batch 1600 Loss 0.4878
# Epoch 6 Batch 1700 Loss 0.5171
# Epoch 6 Batch 1800 Loss 0.5915
# Epoch 6 Batch 1900 Loss 0.5673
# Epoch 6 Batch 2000 Loss 0.5431
# Epoch 6 Batch 2100 Loss 0.5065
# Epoch 6 Batch 2200 Loss 0.5050
# Epoch 6 Batch 2300 Loss 0.5782
# Epoch 6 Batch 2400 Loss 0.5238
# Epoch 6 Batch 2500 Loss 0.4963
# Epoch 6 Batch 2600 Loss 0.5710
# Epoch 6 Batch 2700 Loss 0.5537
# Epoch 6 Batch 2800 Loss 0.5280
# Epoch 6 Batch 2900 Loss 0.5200
# Epoch 6 Batch 3000 Loss 0.5222
# Epoch 6 Batch 3100 Loss 0.5301
# Epoch 6 Batch 3200 Loss 0.4762
# Epoch 6 Batch 3300 Loss 0.4661
# Epoch 6 Batch 3400 Loss 0.5448
# Epoch 6 Batch 3500 Loss 0.4843
# Epoch 6 Batch 3600 Loss 0.5112
# Epoch 6 Batch 3700 Loss 0.5354
# Epoch 6 Batch 3800 Loss 0.5717
# Epoch 6 Batch 3900 Loss 0.5195
# Epoch 6 Batch 4000 Loss 0.5226
# Epoch 6 Batch 4100 Loss 0.4774
# Epoch 6 Batch 4200 Loss 0.5012
# Epoch 6 Batch 4300 Loss 0.4694
# Epoch 6 Batch 4400 Loss 0.5004
# Epoch 6 Batch 4500 Loss 0.5177
# Epoch 6 Batch 4600 Loss 0.5113
# Epoch 6 Batch 4700 Loss 0.5402
# Epoch 6 Batch 4800 Loss 0.4683
# Epoch 6 Batch 4900 Loss 0.4989
# Epoch 6 Batch 5000 Loss 0.4911
# Epoch 6 Batch 5100 Loss 0.5345
# Epoch 6 Batch 5200 Loss 0.5626
# Epoch 6 Batch 5300 Loss 0.5097
# Epoch 6 Batch 5400 Loss 0.5148
# Epoch 6 Batch 5500 Loss 0.5167
# Epoch 6 Batch 5600 Loss 0.4984
# Epoch 6 Batch 5700 Loss 0.5095
# Epoch 6 Batch 5800 Loss 0.4909
# Epoch 6 Batch 5900 Loss 0.4732
# Epoch 6 Batch 6000 Loss 0.5366
# Epoch 6 Batch 6100 Loss 0.5017
# Epoch 6 Batch 6200 Loss 0.4822
# Epoch 6 Batch 6300 Loss 0.5443
# Epoch 6 Batch 6400 Loss 0.5458
# Epoch 6 Batch 6500 Loss 0.5552
# Epoch 6 Batch 6600 Loss 0.4933
# Epoch 6 Batch 6700 Loss 0.5640
# Epoch 6 Batch 6800 Loss 0.5077
# Epoch 6 Batch 6900 Loss 0.5014
# Epoch 6 Batch 7000 Loss 0.4914
# Epoch 6 Batch 7100 Loss 0.4966
# Epoch 6 Batch 7200 Loss 0.5312
# Epoch 6 Batch 7300 Loss 0.5568
# Epoch 6 Loss 0.516002
# Time taken for 1 epoch 2002.68 sec
#
# Epoch 7 Batch 0 Loss 0.5127
# Epoch 7 Batch 100 Loss 0.5170
# Epoch 7 Batch 200 Loss 0.5360
# Epoch 7 Batch 300 Loss 0.4866
# Epoch 7 Batch 400 Loss 0.5124
# Epoch 7 Batch 500 Loss 0.4450
# Epoch 7 Batch 600 Loss 0.5102
# Epoch 7 Batch 700 Loss 0.5169
# Epoch 7 Batch 800 Loss 0.4841
# Epoch 7 Batch 900 Loss 0.5085
# Epoch 7 Batch 1000 Loss 0.5110
# Epoch 7 Batch 1100 Loss 0.4650
# Epoch 7 Batch 1200 Loss 0.4767
# Epoch 7 Batch 1300 Loss 0.5123
# Epoch 7 Batch 1400 Loss 0.4639
# Epoch 7 Batch 1500 Loss 0.4534
# Epoch 7 Batch 1600 Loss 0.5265
# Epoch 7 Batch 1700 Loss 0.4814
# Epoch 7 Batch 1800 Loss 0.5509
# Epoch 7 Batch 1900 Loss 0.5694
# Epoch 7 Batch 2000 Loss 0.4761
# Epoch 7 Batch 2100 Loss 0.4973
# Epoch 7 Batch 2200 Loss 0.4972
# Epoch 7 Batch 2300 Loss 0.5133
# Epoch 7 Batch 2400 Loss 0.4448
# Epoch 7 Batch 2500 Loss 0.5340
# Epoch 7 Batch 2600 Loss 0.4769
# Epoch 7 Batch 2700 Loss 0.4869
# Epoch 7 Batch 2800 Loss 0.4625
# Epoch 7 Batch 2900 Loss 0.4936
# Epoch 7 Batch 3000 Loss 0.5779
# Epoch 7 Batch 3100 Loss 0.5472
# Epoch 7 Batch 3200 Loss 0.4942
# Epoch 7 Batch 3300 Loss 0.5388
# Epoch 7 Batch 3400 Loss 0.5395
# Epoch 7 Batch 3500 Loss 0.4256
# Epoch 7 Batch 3600 Loss 0.5026
# Epoch 7 Batch 3700 Loss 0.5394
# Epoch 7 Batch 3800 Loss 0.4911
# Epoch 7 Batch 3900 Loss 0.5047
# Epoch 7 Batch 4000 Loss 0.5304
# Epoch 7 Batch 4100 Loss 0.4544
# Epoch 7 Batch 4200 Loss 0.5663
# Epoch 7 Batch 4300 Loss 0.5155
# Epoch 7 Batch 4400 Loss 0.4836
# Epoch 7 Batch 4500 Loss 0.5422
# Epoch 7 Batch 4600 Loss 0.4836
# Epoch 7 Batch 4700 Loss 0.5098
# Epoch 7 Batch 4800 Loss 0.5430
# Epoch 7 Batch 4900 Loss 0.4691
# Epoch 7 Batch 5000 Loss 0.4777
# Epoch 7 Batch 5100 Loss 0.4992
# Epoch 7 Batch 5200 Loss 0.4986
# Epoch 7 Batch 5300 Loss 0.5290
# Epoch 7 Batch 5400 Loss 0.4554
# Epoch 7 Batch 5500 Loss 0.5291
# Epoch 7 Batch 5600 Loss 0.4888
# Epoch 7 Batch 5700 Loss 0.5462
# Epoch 7 Batch 5800 Loss 0.5046
# Epoch 7 Batch 5900 Loss 0.4863
# Epoch 7 Batch 6000 Loss 0.4689
# Epoch 7 Batch 6100 Loss 0.4884
# Epoch 7 Batch 6200 Loss 0.5501
# Epoch 7 Batch 6300 Loss 0.5197
# Epoch 7 Batch 6400 Loss 0.4762
# Epoch 7 Batch 6500 Loss 0.5754
# Epoch 7 Batch 6600 Loss 0.4564
# Epoch 7 Batch 6700 Loss 0.4862
# Epoch 7 Batch 6800 Loss 0.5177
# Epoch 7 Batch 6900 Loss 0.5319
# Epoch 7 Batch 7000 Loss 0.5009
# Epoch 7 Batch 7100 Loss 0.5275
# Epoch 7 Batch 7200 Loss 0.4962
# Epoch 7 Batch 7300 Loss 0.4920
# Epoch 7 Loss 0.504066
# Time taken for 1 epoch 2002.65 sec
#
# Epoch 8 Batch 0 Loss 0.4940
# Epoch 8 Batch 100 Loss 0.4690
# Epoch 8 Batch 200 Loss 0.5374
# Epoch 8 Batch 300 Loss 0.4784
# Epoch 8 Batch 400 Loss 0.5586
# Epoch 8 Batch 500 Loss 0.4806
# Epoch 8 Batch 600 Loss 0.5134
# Epoch 8 Batch 700 Loss 0.4711
# Epoch 8 Batch 800 Loss 0.4872
# Epoch 8 Batch 900 Loss 0.4883
# Epoch 8 Batch 1000 Loss 0.4367
# Epoch 8 Batch 1100 Loss 0.4807
# Epoch 8 Batch 1200 Loss 0.5341
# Epoch 8 Batch 1300 Loss 0.5061
# Epoch 8 Batch 1400 Loss 0.5401
# Epoch 8 Batch 1500 Loss 0.4968
# Epoch 8 Batch 1600 Loss 0.4787
# Epoch 8 Batch 1700 Loss 0.5113
# Epoch 8 Batch 1800 Loss 0.4869
# Epoch 8 Batch 1900 Loss 0.5212
# Epoch 8 Batch 2000 Loss 0.5298
# Epoch 8 Batch 2100 Loss 0.4884
# Epoch 8 Batch 2200 Loss 0.4830
# Epoch 8 Batch 2300 Loss 0.4869
# Epoch 8 Batch 2400 Loss 0.4754
# Epoch 8 Batch 2500 Loss 0.4483
# Epoch 8 Batch 2600 Loss 0.4540
# Epoch 8 Batch 2700 Loss 0.5099
# Epoch 8 Batch 2800 Loss 0.4878
# Epoch 8 Batch 2900 Loss 0.4521
# Epoch 8 Batch 3000 Loss 0.5013
# Epoch 8 Batch 3100 Loss 0.4841
# Epoch 8 Batch 3200 Loss 0.4778
# Epoch 8 Batch 3300 Loss 0.4685
# Epoch 8 Batch 3400 Loss 0.4682
# Epoch 8 Batch 3500 Loss 0.5295
# Epoch 8 Batch 3600 Loss 0.4891
# Epoch 8 Batch 3700 Loss 0.4708
# Epoch 8 Batch 3800 Loss 0.5196
# Epoch 8 Batch 3900 Loss 0.4646
# Epoch 8 Batch 4000 Loss 0.5004
# Epoch 8 Batch 4100 Loss 0.4599
# Epoch 8 Batch 4200 Loss 0.4945
# Epoch 8 Batch 4300 Loss 0.4642
# Epoch 8 Batch 4400 Loss 0.5410
# Epoch 8 Batch 4500 Loss 0.4549
# Epoch 8 Batch 4600 Loss 0.4831
# Epoch 8 Batch 4700 Loss 0.5184
# Epoch 8 Batch 4800 Loss 0.5172
# Epoch 8 Batch 4900 Loss 0.5702
# Epoch 8 Batch 5000 Loss 0.4828
# Epoch 8 Batch 5100 Loss 0.5111
# Epoch 8 Batch 5200 Loss 0.4474
# Epoch 8 Batch 5300 Loss 0.5062
# Epoch 8 Batch 5400 Loss 0.4435
# Epoch 8 Batch 5500 Loss 0.5128
# Epoch 8 Batch 5600 Loss 0.4938
# Epoch 8 Batch 5700 Loss 0.5055
# Epoch 8 Batch 5800 Loss 0.4965
# Epoch 8 Batch 5900 Loss 0.4772
# Epoch 8 Batch 6000 Loss 0.5009
# Epoch 8 Batch 6100 Loss 0.4866
# Epoch 8 Batch 6200 Loss 0.4896
# Epoch 8 Batch 6300 Loss 0.4915
# Epoch 8 Batch 6400 Loss 0.4570
# Epoch 8 Batch 6500 Loss 0.5259
# Epoch 8 Batch 6600 Loss 0.4636
# Epoch 8 Batch 6700 Loss 0.4522
# Epoch 8 Batch 6800 Loss 0.4695
# Epoch 8 Batch 6900 Loss 0.4816
# Epoch 8 Batch 7000 Loss 0.4990
# Epoch 8 Batch 7100 Loss 0.4990
# Epoch 8 Batch 7200 Loss 0.4993
# Epoch 8 Batch 7300 Loss 0.5136
# Epoch 8 Loss 0.493509
# Time taken for 1 epoch 2002.46 sec
#
# Epoch 9 Batch 0 Loss 0.4565
# Epoch 9 Batch 100 Loss 0.4723
# Epoch 9 Batch 200 Loss 0.4719
# Epoch 9 Batch 300 Loss 0.4931
# Epoch 9 Batch 400 Loss 0.4940
# Epoch 9 Batch 500 Loss 0.5070
# Epoch 9 Batch 600 Loss 0.4313
# Epoch 9 Batch 700 Loss 0.4465
# Epoch 9 Batch 800 Loss 0.4641
# Epoch 9 Batch 900 Loss 0.5121
# Epoch 9 Batch 1000 Loss 0.4324
# Epoch 9 Batch 1100 Loss 0.4554
# Epoch 9 Batch 1200 Loss 0.5769
# Epoch 9 Batch 1300 Loss 0.4889
# Epoch 9 Batch 1400 Loss 0.5020
# Epoch 9 Batch 1500 Loss 0.5440
# Epoch 9 Batch 1600 Loss 0.4653
# Epoch 9 Batch 1700 Loss 0.4676
# Epoch 9 Batch 1800 Loss 0.4555
# Epoch 9 Batch 1900 Loss 0.5087
# Epoch 9 Batch 2000 Loss 0.4526
# Epoch 9 Batch 2100 Loss 0.4857
# Epoch 9 Batch 2200 Loss 0.5001
# Epoch 9 Batch 2300 Loss 0.4790
# Epoch 9 Batch 2400 Loss 0.4620
# Epoch 9 Batch 2500 Loss 0.4740
# Epoch 9 Batch 2600 Loss 0.4921
# Epoch 9 Batch 2700 Loss 0.5008
# Epoch 9 Batch 2800 Loss 0.4952
# Epoch 9 Batch 2900 Loss 0.4943
# Epoch 9 Batch 3000 Loss 0.4614
# Epoch 9 Batch 3100 Loss 0.5142
# Epoch 9 Batch 3200 Loss 0.5186
# Epoch 9 Batch 3300 Loss 0.4595
# Epoch 9 Batch 3400 Loss 0.4980
# Epoch 9 Batch 3500 Loss 0.5103
# Epoch 9 Batch 3600 Loss 0.5464
# Epoch 9 Batch 3700 Loss 0.4931
# Epoch 9 Batch 3800 Loss 0.5001
# Epoch 9 Batch 3900 Loss 0.4585
# Epoch 9 Batch 4000 Loss 0.4910
# Epoch 9 Batch 4100 Loss 0.5233
# Epoch 9 Batch 4200 Loss 0.5013
# Epoch 9 Batch 4300 Loss 0.4254
# Epoch 9 Batch 4400 Loss 0.4745
# Epoch 9 Batch 4500 Loss 0.4690
# Epoch 9 Batch 4600 Loss 0.5271
# Epoch 9 Batch 4700 Loss 0.4839
# Epoch 9 Batch 4800 Loss 0.4835
# Epoch 9 Batch 4900 Loss 0.4518
# Epoch 9 Batch 5000 Loss 0.4895
# Epoch 9 Batch 5100 Loss 0.4502
# Epoch 9 Batch 5200 Loss 0.4887
# Epoch 9 Batch 5300 Loss 0.4793
# Epoch 9 Batch 5400 Loss 0.4731
# Epoch 9 Batch 5500 Loss 0.4667
# Epoch 9 Batch 5600 Loss 0.5345
# Epoch 9 Batch 5700 Loss 0.4782
# Epoch 9 Batch 5800 Loss 0.5335
# Epoch 9 Batch 5900 Loss 0.4950
# Epoch 9 Batch 6000 Loss 0.4914
# Epoch 9 Batch 6100 Loss 0.5190
# Epoch 9 Batch 6200 Loss 0.4837
# Epoch 9 Batch 6300 Loss 0.4380
# Epoch 9 Batch 6400 Loss 0.4920
# Epoch 9 Batch 6500 Loss 0.4412
# Epoch 9 Batch 6600 Loss 0.5083
# Epoch 9 Batch 6700 Loss 0.4423
# Epoch 9 Batch 6800 Loss 0.4527
# Epoch 9 Batch 6900 Loss 0.4961
# Epoch 9 Batch 7000 Loss 0.4862
# Epoch 9 Batch 7100 Loss 0.4611
# Epoch 9 Batch 7200 Loss 0.4981
# Epoch 9 Batch 7300 Loss 0.4919
# Epoch 9 Loss 0.484351
# Time taken for 1 epoch 2003.03 sec
#
# Epoch 10 Batch 0 Loss 0.5060
# Epoch 10 Batch 100 Loss 0.4482
# Epoch 10 Batch 200 Loss 0.4861
# Epoch 10 Batch 300 Loss 0.4800
# Epoch 10 Batch 400 Loss 0.5149
# Epoch 10 Batch 500 Loss 0.5015
# Epoch 10 Batch 600 Loss 0.4771
# Epoch 10 Batch 700 Loss 0.4624
# Epoch 10 Batch 800 Loss 0.5068
# Epoch 10 Batch 900 Loss 0.4740
# Epoch 10 Batch 1000 Loss 0.4975
# Epoch 10 Batch 1100 Loss 0.4872
# Epoch 10 Batch 1200 Loss 0.4754
# Epoch 10 Batch 1300 Loss 0.4905
# Epoch 10 Batch 1400 Loss 0.4646
# Epoch 10 Batch 1500 Loss 0.4722
# Epoch 10 Batch 1600 Loss 0.5124
# Epoch 10 Batch 1700 Loss 0.4595
# Epoch 10 Batch 1800 Loss 0.4830
# Epoch 10 Batch 1900 Loss 0.4499
# Epoch 10 Batch 2000 Loss 0.4538
# Epoch 10 Batch 2100 Loss 0.4937
# Epoch 10 Batch 2200 Loss 0.4806
# Epoch 10 Batch 2300 Loss 0.4596
# Epoch 10 Batch 2400 Loss 0.4458
# Epoch 10 Batch 2500 Loss 0.4710
# Epoch 10 Batch 2600 Loss 0.4780
# Epoch 10 Batch 2700 Loss 0.5069
# Epoch 10 Batch 2800 Loss 0.4825
# Epoch 10 Batch 2900 Loss 0.4745
# Epoch 10 Batch 3000 Loss 0.4588
# Epoch 10 Batch 3100 Loss 0.5170
# Epoch 10 Batch 3200 Loss 0.4540
# Epoch 10 Batch 3300 Loss 0.4914
# Epoch 10 Batch 3400 Loss 0.4754
# Epoch 10 Batch 3500 Loss 0.5590
# Epoch 10 Batch 3600 Loss 0.4966
# Epoch 10 Batch 3700 Loss 0.4207
# Epoch 10 Batch 3800 Loss 0.4745
# Epoch 10 Batch 3900 Loss 0.4946
# Epoch 10 Batch 4000 Loss 0.4914
# Epoch 10 Batch 4100 Loss 0.4568
# Epoch 10 Batch 4200 Loss 0.4538
# Epoch 10 Batch 4300 Loss 0.4861
# Epoch 10 Batch 4400 Loss 0.4938
# Epoch 10 Batch 4500 Loss 0.5039
# Epoch 10 Batch 4600 Loss 0.4917
# Epoch 10 Batch 4700 Loss 0.4591
# Epoch 10 Batch 4800 Loss 0.4543
# Epoch 10 Batch 4900 Loss 0.4753
# Epoch 10 Batch 5000 Loss 0.4755
# Epoch 10 Batch 5100 Loss 0.5106
# Epoch 10 Batch 5200 Loss 0.4654
# Epoch 10 Batch 5300 Loss 0.4419
# Epoch 10 Batch 5400 Loss 0.4717
# Epoch 10 Batch 5500 Loss 0.4850
# Epoch 10 Batch 5600 Loss 0.4677
# Epoch 10 Batch 5700 Loss 0.4876
# Epoch 10 Batch 5800 Loss 0.5093
# Epoch 10 Batch 5900 Loss 0.4632
# Epoch 10 Batch 6000 Loss 0.5117
# Epoch 10 Batch 6100 Loss 0.4684
# Epoch 10 Batch 6200 Loss 0.4944
# Epoch 10 Batch 6300 Loss 0.4748
# Epoch 10 Batch 6400 Loss 0.4617
# Epoch 10 Batch 6500 Loss 0.4558
# Epoch 10 Batch 6600 Loss 0.4873
# Epoch 10 Batch 6700 Loss 0.4747
# Epoch 10 Batch 6800 Loss 0.4488
# Epoch 10 Batch 6900 Loss 0.4402
# Epoch 10 Batch 7000 Loss 0.5122
# Epoch 10 Batch 7100 Loss 0.4697
# Epoch 10 Batch 7200 Loss 0.5121
# Epoch 10 Batch 7300 Loss 0.4799
# Epoch 10 Loss 0.477047
# Time taken for 1 epoch 2001.31 sec
#
# Epoch 11 Batch 0 Loss 0.4762
# Epoch 11 Batch 100 Loss 0.5070
# Epoch 11 Batch 200 Loss 0.5225
# Epoch 11 Batch 300 Loss 0.4262
# Epoch 11 Batch 400 Loss 0.4506
# Epoch 11 Batch 500 Loss 0.5092
# Epoch 11 Batch 600 Loss 0.4571
# Epoch 11 Batch 700 Loss 0.4640
# Epoch 11 Batch 800 Loss 0.5069
# Epoch 11 Batch 900 Loss 0.4830
# Epoch 11 Batch 1000 Loss 0.4527
# Epoch 11 Batch 1100 Loss 0.5172
# Epoch 11 Batch 1200 Loss 0.4603
# Epoch 11 Batch 1300 Loss 0.4858
# Epoch 11 Batch 1400 Loss 0.4760
# Epoch 11 Batch 1500 Loss 0.5017
# Epoch 11 Batch 1600 Loss 0.4710
# Epoch 11 Batch 1700 Loss 0.5251
# Epoch 11 Batch 1800 Loss 0.4843
# Epoch 11 Batch 1900 Loss 0.4808
# Epoch 11 Batch 2000 Loss 0.5069
# Epoch 11 Batch 2100 Loss 0.4826
# Epoch 11 Batch 2200 Loss 0.5230
# Epoch 11 Batch 2300 Loss 0.5090
# Epoch 11 Batch 2400 Loss 0.4462
# Epoch 11 Batch 2500 Loss 0.4911
# Epoch 11 Batch 2600 Loss 0.5033
# Epoch 11 Batch 2700 Loss 0.4409
# Epoch 11 Batch 2800 Loss 0.5025
# Epoch 11 Batch 2900 Loss 0.4737
# Epoch 11 Batch 3000 Loss 0.4534
# Epoch 11 Batch 3100 Loss 0.4561
# Epoch 11 Batch 3200 Loss 0.4676
# Epoch 11 Batch 3300 Loss 0.4724
# Epoch 11 Batch 3400 Loss 0.5235
# Epoch 11 Batch 3500 Loss 0.4792
# Epoch 11 Batch 3600 Loss 0.4469
# Epoch 11 Batch 3700 Loss 0.4893
# Epoch 11 Batch 3800 Loss 0.4466
# Epoch 11 Batch 3900 Loss 0.4449
# Epoch 11 Batch 4000 Loss 0.5211
# Epoch 11 Batch 4100 Loss 0.4320
# Epoch 11 Batch 4200 Loss 0.4545
# Epoch 11 Batch 4300 Loss 0.4501
# Epoch 11 Batch 4400 Loss 0.4383
# Epoch 11 Batch 4500 Loss 0.4674
# Epoch 11 Batch 4600 Loss 0.4623
# Epoch 11 Batch 4700 Loss 0.4331
# Epoch 11 Batch 4800 Loss 0.4660
# Epoch 11 Batch 4900 Loss 0.4412
# Epoch 11 Batch 5000 Loss 0.4831
# Epoch 11 Batch 5100 Loss 0.4921
# Epoch 11 Batch 5200 Loss 0.4475
# Epoch 11 Batch 5300 Loss 0.4834
# Epoch 11 Batch 5400 Loss 0.4710
# Epoch 11 Batch 5500 Loss 0.5362
# Epoch 11 Batch 5600 Loss 0.4406
# Epoch 11 Batch 5700 Loss 0.4931
# Epoch 11 Batch 5800 Loss 0.4995
# Epoch 11 Batch 5900 Loss 0.4848
# Epoch 11 Batch 6000 Loss 0.4733
# Epoch 11 Batch 6100 Loss 0.4350
# Epoch 11 Batch 6200 Loss 0.4625
# Epoch 11 Batch 6300 Loss 0.4614
# Epoch 11 Batch 6400 Loss 0.4420
# Epoch 11 Batch 6500 Loss 0.4491
# Epoch 11 Batch 6600 Loss 0.4777
# Epoch 11 Batch 6700 Loss 0.4865
# Epoch 11 Batch 6800 Loss 0.5163
# Epoch 11 Batch 6900 Loss 0.4664
# Epoch 11 Batch 7000 Loss 0.4923
# Epoch 11 Batch 7100 Loss 0.4456
# Epoch 11 Batch 7200 Loss 0.4529
# Epoch 11 Batch 7300 Loss 0.4603
# Epoch 11 Loss 0.469941
# Time taken for 1 epoch 2003.14 sec
#
# Epoch 12 Batch 0 Loss 0.4895
# Epoch 12 Batch 100 Loss 0.4191
# Epoch 12 Batch 200 Loss 0.5034
# Epoch 12 Batch 300 Loss 0.4518
# Epoch 12 Batch 400 Loss 0.4733
# Epoch 12 Batch 500 Loss 0.5092
# Epoch 12 Batch 600 Loss 0.5222
# Epoch 12 Batch 700 Loss 0.4451
# Epoch 12 Batch 800 Loss 0.5036
# Epoch 12 Batch 900 Loss 0.4310
# Epoch 12 Batch 1000 Loss 0.4282
# Epoch 12 Batch 1100 Loss 0.4691
# Epoch 12 Batch 1200 Loss 0.4264
# Epoch 12 Batch 1300 Loss 0.4977
# Epoch 12 Batch 1400 Loss 0.4741
# Epoch 12 Batch 1500 Loss 0.4574
# Epoch 12 Batch 1600 Loss 0.4848
# Epoch 12 Batch 1700 Loss 0.4856
# Epoch 12 Batch 1800 Loss 0.5343
# Epoch 12 Batch 1900 Loss 0.4663
# Epoch 12 Batch 2000 Loss 0.4529
# Epoch 12 Batch 2100 Loss 0.4599
# Epoch 12 Batch 2200 Loss 0.4378
# Epoch 12 Batch 2300 Loss 0.4154
# Epoch 12 Batch 2400 Loss 0.4649
# Epoch 12 Batch 2500 Loss 0.4534
# Epoch 12 Batch 2600 Loss 0.5030
# Epoch 12 Batch 2700 Loss 0.5058
# Epoch 12 Batch 2800 Loss 0.4387
# Epoch 12 Batch 2900 Loss 0.4502
# Epoch 12 Batch 3000 Loss 0.4870
# Epoch 12 Batch 3100 Loss 0.4807
# Epoch 12 Batch 3200 Loss 0.4329
# Epoch 12 Batch 3300 Loss 0.4169
# Epoch 12 Batch 3400 Loss 0.4515
# Epoch 12 Batch 3500 Loss 0.4275
# Epoch 12 Batch 3600 Loss 0.4604
# Epoch 12 Batch 3700 Loss 0.4800
# Epoch 12 Batch 3800 Loss 0.4899
# Epoch 12 Batch 3900 Loss 0.4864
# Epoch 12 Batch 4000 Loss 0.4513
# Epoch 12 Batch 4100 Loss 0.4110
# Epoch 12 Batch 4200 Loss 0.4659
# Epoch 12 Batch 4300 Loss 0.4720
# Epoch 12 Batch 4400 Loss 0.4122
# Epoch 12 Batch 4500 Loss 0.4321
# Epoch 12 Batch 4600 Loss 0.4689
# Epoch 12 Batch 4700 Loss 0.4763
# Epoch 12 Batch 4800 Loss 0.4289
# Epoch 12 Batch 4900 Loss 0.4453
# Epoch 12 Batch 5000 Loss 0.4366
# Epoch 12 Batch 5100 Loss 0.4959
# Epoch 12 Batch 5200 Loss 0.4470
# Epoch 12 Batch 5300 Loss 0.4492
# Epoch 12 Batch 5400 Loss 0.4543
# Epoch 12 Batch 5500 Loss 0.4781
# Epoch 12 Batch 5600 Loss 0.4669
# Epoch 12 Batch 5700 Loss 0.4514
# Epoch 12 Batch 5800 Loss 0.5130
# Epoch 12 Batch 5900 Loss 0.4805
# Epoch 12 Batch 6000 Loss 0.4869
# Epoch 12 Batch 6100 Loss 0.4106
# Epoch 12 Batch 6200 Loss 0.4869
# Epoch 12 Batch 6300 Loss 0.4873
# Epoch 12 Batch 6400 Loss 0.4422
# Epoch 12 Batch 6500 Loss 0.4456
# Epoch 12 Batch 6600 Loss 0.4823
# Epoch 12 Batch 6700 Loss 0.4010
# Epoch 12 Batch 6800 Loss 0.4611
# Epoch 12 Batch 6900 Loss 0.4770
# Epoch 12 Batch 7000 Loss 0.4528
# Epoch 12 Batch 7100 Loss 0.4682
# Epoch 12 Batch 7200 Loss 0.4671
# Epoch 12 Batch 7300 Loss 0.4394
# Epoch 12 Loss 0.464341
# Time taken for 1 epoch 2002.47 sec
#
# Epoch 13 Batch 0 Loss 0.4661
# Epoch 13 Batch 100 Loss 0.4308
# Epoch 13 Batch 200 Loss 0.4473
# Epoch 13 Batch 300 Loss 0.5065
# Epoch 13 Batch 400 Loss 0.4753
# Epoch 13 Batch 500 Loss 0.4296
# Epoch 13 Batch 600 Loss 0.4696
# Epoch 13 Batch 700 Loss 0.4518
# Epoch 13 Batch 800 Loss 0.4596
# Epoch 13 Batch 900 Loss 0.4366
# Epoch 13 Batch 1000 Loss 0.4296
# Epoch 13 Batch 1100 Loss 0.4417
# Epoch 13 Batch 1200 Loss 0.4802
# Epoch 13 Batch 1300 Loss 0.4865
# Epoch 13 Batch 1400 Loss 0.4540
# Epoch 13 Batch 1500 Loss 0.4280
# Epoch 13 Batch 1600 Loss 0.4807
# Epoch 13 Batch 1700 Loss 0.4506
# Epoch 13 Batch 1800 Loss 0.4916
# Epoch 13 Batch 1900 Loss 0.4403
# Epoch 13 Batch 2000 Loss 0.4335
# Epoch 13 Batch 2100 Loss 0.4631
# Epoch 13 Batch 2200 Loss 0.4414
# Epoch 13 Batch 2300 Loss 0.4446
# Epoch 13 Batch 2400 Loss 0.4442
# Epoch 13 Batch 2500 Loss 0.4703
# Epoch 13 Batch 2600 Loss 0.4574
# Epoch 13 Batch 2700 Loss 0.4418
# Epoch 13 Batch 2800 Loss 0.5055
# Epoch 13 Batch 2900 Loss 0.4327
# Epoch 13 Batch 3000 Loss 0.4335
# Epoch 13 Batch 3100 Loss 0.4696
# Epoch 13 Batch 3200 Loss 0.4569
# Epoch 13 Batch 3300 Loss 0.4900
# Epoch 13 Batch 3400 Loss 0.4746
# Epoch 13 Batch 3500 Loss 0.4996
# Epoch 13 Batch 3600 Loss 0.4405
# Epoch 13 Batch 3700 Loss 0.4470
# Epoch 13 Batch 3800 Loss 0.4790
# Epoch 13 Batch 3900 Loss 0.4759
# Epoch 13 Batch 4000 Loss 0.4550
# Epoch 13 Batch 4100 Loss 0.4197
# Epoch 13 Batch 4200 Loss 0.4569
# Epoch 13 Batch 4300 Loss 0.4313
# Epoch 13 Batch 4400 Loss 0.4476
# Epoch 13 Batch 4500 Loss 0.4504
# Epoch 13 Batch 4600 Loss 0.3941
# Epoch 13 Batch 4700 Loss 0.4738
# Epoch 13 Batch 4800 Loss 0.5058
# Epoch 13 Batch 4900 Loss 0.4640
# Epoch 13 Batch 5000 Loss 0.4373
# Epoch 13 Batch 5100 Loss 0.4597
# Epoch 13 Batch 5200 Loss 0.4873
# Epoch 13 Batch 5300 Loss 0.4072
# Epoch 13 Batch 5400 Loss 0.4422
# Epoch 13 Batch 5500 Loss 0.4468
# Epoch 13 Batch 5600 Loss 0.4815
# Epoch 13 Batch 5700 Loss 0.4998
# Epoch 13 Batch 5800 Loss 0.4468
# Epoch 13 Batch 5900 Loss 0.4738
# Epoch 13 Batch 6000 Loss 0.4969
# Epoch 13 Batch 6100 Loss 0.5128
# Epoch 13 Batch 6200 Loss 0.4567
# Epoch 13 Batch 6300 Loss 0.4412
# Epoch 13 Batch 6400 Loss 0.5102
# Epoch 13 Batch 6500 Loss 0.4690
# Epoch 13 Batch 6600 Loss 0.4399
# Epoch 13 Batch 6700 Loss 0.4252
# Epoch 13 Batch 6800 Loss 0.4770
# Epoch 13 Batch 6900 Loss 0.4941
# Epoch 13 Batch 7000 Loss 0.4148
# Epoch 13 Batch 7100 Loss 0.4386
# Epoch 13 Batch 7200 Loss 0.4692
# Epoch 13 Batch 7300 Loss 0.4677
# Epoch 13 Loss 0.458646
# Time taken for 1 epoch 2001.75 sec
#
# Epoch 14 Batch 0 Loss 0.4285
# Epoch 14 Batch 100 Loss 0.4668
# Epoch 14 Batch 200 Loss 0.4850
# Epoch 14 Batch 300 Loss 0.4612
# Epoch 14 Batch 400 Loss 0.4359
# Epoch 14 Batch 500 Loss 0.4633
# Epoch 14 Batch 600 Loss 0.4187
# Epoch 14 Batch 700 Loss 0.4916
# Epoch 14 Batch 800 Loss 0.5023
# Epoch 14 Batch 900 Loss 0.5314
# Epoch 14 Batch 1000 Loss 0.4546
# Epoch 14 Batch 1100 Loss 0.4496
# Epoch 14 Batch 1200 Loss 0.4758
# Epoch 14 Batch 1300 Loss 0.4731
# Epoch 14 Batch 1400 Loss 0.4398
# Epoch 14 Batch 1500 Loss 0.4852
# Epoch 14 Batch 1600 Loss 0.4890
# Epoch 14 Batch 1700 Loss 0.4579
# Epoch 14 Batch 1800 Loss 0.4307
# Epoch 14 Batch 1900 Loss 0.4760
# Epoch 14 Batch 2000 Loss 0.4284
# Epoch 14 Batch 2100 Loss 0.4659
# Epoch 14 Batch 2200 Loss 0.4120
# Epoch 14 Batch 2300 Loss 0.4473
# Epoch 14 Batch 2400 Loss 0.4394
# Epoch 14 Batch 2500 Loss 0.4509
# Epoch 14 Batch 2600 Loss 0.4693
# Epoch 14 Batch 2700 Loss 0.4867
# Epoch 14 Batch 2800 Loss 0.4558
# Epoch 14 Batch 2900 Loss 0.4562
# Epoch 14 Batch 3000 Loss 0.4904
# Epoch 14 Batch 3100 Loss 0.4405
# Epoch 14 Batch 3200 Loss 0.4671
# Epoch 14 Batch 3300 Loss 0.4631
# Epoch 14 Batch 3400 Loss 0.4579
# Epoch 14 Batch 3500 Loss 0.4734
# Epoch 14 Batch 3600 Loss 0.4855
# Epoch 14 Batch 3700 Loss 0.4465
# Epoch 14 Batch 3800 Loss 0.4711
# Epoch 14 Batch 3900 Loss 0.4682
# Epoch 14 Batch 4000 Loss 0.4523
# Epoch 14 Batch 4100 Loss 0.4534
# Epoch 14 Batch 4200 Loss 0.4315
# Epoch 14 Batch 4300 Loss 0.5146
# Epoch 14 Batch 4400 Loss 0.4695
# Epoch 14 Batch 4500 Loss 0.4592
# Epoch 14 Batch 4600 Loss 0.4584
# Epoch 14 Batch 4700 Loss 0.4695
# Epoch 14 Batch 4800 Loss 0.4308
# Epoch 14 Batch 4900 Loss 0.4462
# Epoch 14 Batch 5000 Loss 0.4568
# Epoch 14 Batch 5100 Loss 0.4953
# Epoch 14 Batch 5200 Loss 0.5019
# Epoch 14 Batch 5300 Loss 0.4608
# Epoch 14 Batch 5400 Loss 0.4514
# Epoch 14 Batch 5500 Loss 0.4973
# Epoch 14 Batch 5600 Loss 0.4559
# Epoch 14 Batch 5700 Loss 0.4416
# Epoch 14 Batch 5800 Loss 0.4604
# Epoch 14 Batch 5900 Loss 0.4789
# Epoch 14 Batch 6000 Loss 0.4413
# Epoch 14 Batch 6100 Loss 0.4913
# Epoch 14 Batch 6200 Loss 0.4570
# Epoch 14 Batch 6300 Loss 0.4513
# Epoch 14 Batch 6400 Loss 0.4487
# Epoch 14 Batch 6500 Loss 0.4041
# Epoch 14 Batch 6600 Loss 0.4696
# Epoch 14 Batch 6700 Loss 0.4565
# Epoch 14 Batch 6800 Loss 0.4541
# Epoch 14 Batch 6900 Loss 0.4106
# Epoch 14 Batch 7000 Loss 0.4885
# Epoch 14 Batch 7100 Loss 0.4696
# Epoch 14 Batch 7200 Loss 0.4560
# Epoch 14 Batch 7300 Loss 0.4453
# Epoch 14 Loss 0.454100
# Time taken for 1 epoch 2002.35 sec
#
# Epoch 15 Batch 0 Loss 0.4260
# Epoch 15 Batch 100 Loss 0.4486
# Epoch 15 Batch 200 Loss 0.4586
# Epoch 15 Batch 300 Loss 0.4643
# Epoch 15 Batch 400 Loss 0.4766
# Epoch 15 Batch 500 Loss 0.4361
# Epoch 15 Batch 600 Loss 0.4626
# Epoch 15 Batch 700 Loss 0.4651
# Epoch 15 Batch 800 Loss 0.4945
# Epoch 15 Batch 900 Loss 0.4432
# Epoch 15 Batch 1000 Loss 0.4275
# Epoch 15 Batch 1100 Loss 0.4460
# Epoch 15 Batch 1200 Loss 0.4725
# Epoch 15 Batch 1300 Loss 0.4640
# Epoch 15 Batch 1400 Loss 0.4696
# Epoch 15 Batch 1500 Loss 0.4029
# Epoch 15 Batch 1600 Loss 0.4660
# Epoch 15 Batch 1700 Loss 0.4533
# Epoch 15 Batch 1800 Loss 0.4301
# Epoch 15 Batch 1900 Loss 0.4348
# Epoch 15 Batch 2000 Loss 0.4431
# Epoch 15 Batch 2100 Loss 0.4597
# Epoch 15 Batch 2200 Loss 0.4338
# Epoch 15 Batch 2300 Loss 0.4400
# Epoch 15 Batch 2400 Loss 0.4852
# Epoch 15 Batch 2500 Loss 0.4487
# Epoch 15 Batch 2600 Loss 0.4895
# Epoch 15 Batch 2700 Loss 0.4539
# Epoch 15 Batch 2800 Loss 0.4511
# Epoch 15 Batch 2900 Loss 0.4465
# Epoch 15 Batch 3000 Loss 0.4890
# Epoch 15 Batch 3100 Loss 0.5169
# Epoch 15 Batch 3200 Loss 0.4250
# Epoch 15 Batch 3300 Loss 0.4221
# Epoch 15 Batch 3400 Loss 0.4366
# Epoch 15 Batch 3500 Loss 0.4111
# Epoch 15 Batch 3600 Loss 0.4483
# Epoch 15 Batch 3700 Loss 0.4146
# Epoch 15 Batch 3800 Loss 0.4429
# Epoch 15 Batch 3900 Loss 0.4871
# Epoch 15 Batch 4000 Loss 0.4518
# Epoch 15 Batch 4100 Loss 0.4207
# Epoch 15 Batch 4200 Loss 0.4333
# Epoch 15 Batch 4300 Loss 0.4256
# Epoch 15 Batch 4400 Loss 0.4209
# Epoch 15 Batch 4500 Loss 0.4568
# Epoch 15 Batch 4600 Loss 0.4635
# Epoch 15 Batch 4700 Loss 0.4050
# Epoch 15 Batch 4800 Loss 0.4686
# Epoch 15 Batch 4900 Loss 0.4173
# Epoch 15 Batch 5000 Loss 0.4315
# Epoch 15 Batch 5100 Loss 0.4915
# Epoch 15 Batch 5200 Loss 0.4179
# Epoch 15 Batch 5300 Loss 0.3977
# Epoch 15 Batch 5400 Loss 0.5297
# Epoch 15 Batch 5500 Loss 0.5244
# Epoch 15 Batch 5600 Loss 0.4064
# Epoch 15 Batch 5700 Loss 0.4506
# Epoch 15 Batch 5800 Loss 0.4726
# Epoch 15 Batch 5900 Loss 0.4879
# Epoch 15 Batch 6000 Loss 0.4215
# Epoch 15 Batch 6100 Loss 0.4269
# Epoch 15 Batch 6200 Loss 0.4757
# Epoch 15 Batch 6300 Loss 0.4340
# Epoch 15 Batch 6400 Loss 0.4602
# Epoch 15 Batch 6500 Loss 0.4290
# Epoch 15 Batch 6600 Loss 0.4422
# Epoch 15 Batch 6700 Loss 0.4602
# Epoch 15 Batch 6800 Loss 0.4457
# Epoch 15 Batch 6900 Loss 0.4983
# Epoch 15 Batch 7000 Loss 0.4318
# Epoch 15 Batch 7100 Loss 0.4616
# Epoch 15 Batch 7200 Loss 0.4125
# Epoch 15 Batch 7300 Loss 0.4211
# Epoch 15 Loss 0.449913
# Time taken for 1 epoch 2002.08 sec
#
# Epoch 16 Batch 0 Loss 0.4355
# Epoch 16 Batch 100 Loss 0.4254
# Epoch 16 Batch 200 Loss 0.4662
# Epoch 16 Batch 300 Loss 0.4035
# Epoch 16 Batch 400 Loss 0.4914
# Epoch 16 Batch 500 Loss 0.4519
# Epoch 16 Batch 600 Loss 0.4562
# Epoch 16 Batch 700 Loss 0.4474
# Epoch 16 Batch 800 Loss 0.4819
# Epoch 16 Batch 900 Loss 0.4400
# Epoch 16 Batch 1000 Loss 0.4367
# Epoch 16 Batch 1100 Loss 0.4149
# Epoch 16 Batch 1200 Loss 0.4925
# Epoch 16 Batch 1300 Loss 0.4425
# Epoch 16 Batch 1400 Loss 0.4657
# Epoch 16 Batch 1500 Loss 0.4580
# Epoch 16 Batch 1600 Loss 0.4289
# Epoch 16 Batch 1700 Loss 0.4813
# Epoch 16 Batch 1800 Loss 0.4473
# Epoch 16 Batch 1900 Loss 0.4556
# Epoch 16 Batch 2000 Loss 0.5245
# Epoch 16 Batch 2100 Loss 0.4291
# Epoch 16 Batch 2200 Loss 0.4101
# Epoch 16 Batch 2300 Loss 0.4843
# Epoch 16 Batch 2400 Loss 0.4316
# Epoch 16 Batch 2500 Loss 0.4252
# Epoch 16 Batch 2600 Loss 0.4076
# Epoch 16 Batch 2700 Loss 0.4453
# Epoch 16 Batch 2800 Loss 0.4918
# Epoch 16 Batch 2900 Loss 0.4489
# Epoch 16 Batch 3000 Loss 0.4263
# Epoch 16 Batch 3100 Loss 0.4597
# Epoch 16 Batch 3200 Loss 0.4500
# Epoch 16 Batch 3300 Loss 0.4364
# Epoch 16 Batch 3400 Loss 0.4137
# Epoch 16 Batch 3500 Loss 0.4382
# Epoch 16 Batch 3600 Loss 0.4162
# Epoch 16 Batch 3700 Loss 0.4575
# Epoch 16 Batch 3800 Loss 0.4372
# Epoch 16 Batch 3900 Loss 0.4631
# Epoch 16 Batch 4000 Loss 0.4100
# Epoch 16 Batch 4100 Loss 0.4345
# Epoch 16 Batch 4200 Loss 0.4361
# Epoch 16 Batch 4300 Loss 0.4458
# Epoch 16 Batch 4400 Loss 0.4349
# Epoch 16 Batch 4500 Loss 0.4486
# Epoch 16 Batch 4600 Loss 0.4680
# Epoch 16 Batch 4700 Loss 0.4500
# Epoch 16 Batch 4800 Loss 0.4642
# Epoch 16 Batch 4900 Loss 0.4401
# Epoch 16 Batch 5000 Loss 0.4481
# Epoch 16 Batch 5100 Loss 0.4511
# Epoch 16 Batch 5200 Loss 0.4531
# Epoch 16 Batch 5300 Loss 0.4475
# Epoch 16 Batch 5400 Loss 0.4468
# Epoch 16 Batch 5500 Loss 0.4717
# Epoch 16 Batch 5600 Loss 0.4639
# Epoch 16 Batch 5700 Loss 0.4464
# Epoch 16 Batch 5800 Loss 0.4834
# Epoch 16 Batch 5900 Loss 0.4264
# Epoch 16 Batch 6000 Loss 0.4358
# Epoch 16 Batch 6100 Loss 0.4427
# Epoch 16 Batch 6200 Loss 0.4726
# Epoch 16 Batch 6300 Loss 0.4326
# Epoch 16 Batch 6400 Loss 0.4278
# Epoch 16 Batch 6500 Loss 0.4504
# Epoch 16 Batch 6600 Loss 0.4441
# Epoch 16 Batch 6700 Loss 0.5104
# Epoch 16 Batch 6800 Loss 0.4450
# Epoch 16 Batch 6900 Loss 0.4470
# Epoch 16 Batch 7000 Loss 0.4721
# Epoch 16 Batch 7100 Loss 0.4249
# Epoch 16 Batch 7200 Loss 0.4693
# Epoch 16 Batch 7300 Loss 0.4700
# Epoch 16 Loss 0.447082
# Time taken for 1 epoch 2002.22 sec
#
# Epoch 17 Batch 0 Loss 0.4088
# Epoch 17 Batch 100 Loss 0.4469
# Epoch 17 Batch 200 Loss 0.4449
# Epoch 17 Batch 300 Loss 0.4255
# Epoch 17 Batch 400 Loss 0.4484
# Epoch 17 Batch 500 Loss 0.4671
# Epoch 17 Batch 600 Loss 0.4224
# Epoch 17 Batch 700 Loss 0.4007
# Epoch 17 Batch 800 Loss 0.4428
# Epoch 17 Batch 900 Loss 0.4531
# Epoch 17 Batch 1000 Loss 0.4302
# Epoch 17 Batch 1100 Loss 0.4556
# Epoch 17 Batch 1200 Loss 0.4613
# Epoch 17 Batch 1300 Loss 0.4417
# Epoch 17 Batch 1400 Loss 0.4383
# Epoch 17 Batch 1500 Loss 0.5053
# Epoch 17 Batch 1600 Loss 0.4214
# Epoch 17 Batch 1700 Loss 0.4578
# Epoch 17 Batch 1800 Loss 0.4382
# Epoch 17 Batch 1900 Loss 0.4426
# Epoch 17 Batch 2000 Loss 0.3938
# Epoch 17 Batch 2100 Loss 0.4429
# Epoch 17 Batch 2200 Loss 0.4569
# Epoch 17 Batch 2300 Loss 0.4158
# Epoch 17 Batch 2400 Loss 0.4446
# Epoch 17 Batch 2500 Loss 0.4302
# Epoch 17 Batch 2600 Loss 0.4063
# Epoch 17 Batch 2700 Loss 0.4548
# Epoch 17 Batch 2800 Loss 0.4417
# Epoch 17 Batch 2900 Loss 0.4227
# Epoch 17 Batch 3000 Loss 0.5262
# Epoch 17 Batch 3100 Loss 0.4379
# Epoch 17 Batch 3200 Loss 0.4328
# Epoch 17 Batch 3300 Loss 0.4188
# Epoch 17 Batch 3400 Loss 0.4155
# Epoch 17 Batch 3500 Loss 0.4239
# Epoch 17 Batch 3600 Loss 0.4195
# Epoch 17 Batch 3700 Loss 0.4712
# Epoch 17 Batch 3800 Loss 0.4493
# Epoch 17 Batch 3900 Loss 0.5082
# Epoch 17 Batch 4000 Loss 0.4684
# Epoch 17 Batch 4100 Loss 0.4439
# Epoch 17 Batch 4200 Loss 0.4532
# Epoch 17 Batch 4300 Loss 0.4408
# Epoch 17 Batch 4400 Loss 0.4491
# Epoch 17 Batch 4500 Loss 0.4741
# Epoch 17 Batch 4600 Loss 0.4966
# Epoch 17 Batch 4700 Loss 0.4549
# Epoch 17 Batch 4800 Loss 0.4425
# Epoch 17 Batch 4900 Loss 0.4147
# Epoch 17 Batch 5000 Loss 0.4503
# Epoch 17 Batch 5100 Loss 0.4466
# Epoch 17 Batch 5200 Loss 0.4536
# Epoch 17 Batch 5300 Loss 0.4593
# Epoch 17 Batch 5400 Loss 0.4423
# Epoch 17 Batch 5500 Loss 0.4658
# Epoch 17 Batch 5600 Loss 0.4511
# Epoch 17 Batch 5700 Loss 0.4272
# Epoch 17 Batch 5800 Loss 0.4195
# Epoch 17 Batch 5900 Loss 0.4454
# Epoch 17 Batch 6000 Loss 0.4181
# Epoch 17 Batch 6100 Loss 0.4508
# Epoch 17 Batch 6200 Loss 0.4365
# Epoch 17 Batch 6300 Loss 0.4223
# Epoch 17 Batch 6400 Loss 0.4013
# Epoch 17 Batch 6500 Loss 0.5091
# Epoch 17 Batch 6600 Loss 0.4867
# Epoch 17 Batch 6700 Loss 0.4301
# Epoch 17 Batch 6800 Loss 0.4320
# Epoch 17 Batch 6900 Loss 0.4459
# Epoch 17 Batch 7000 Loss 0.4385
# Epoch 17 Batch 7100 Loss 0.4606
# Epoch 17 Batch 7200 Loss 0.4576
# Epoch 17 Batch 7300 Loss 0.4513
# Epoch 17 Loss 0.442722
# Time taken for 1 epoch 2000.89 sec
#
# Epoch 18 Batch 0 Loss 0.4328
# Epoch 18 Batch 100 Loss 0.4448
# Epoch 18 Batch 200 Loss 0.4457
# Epoch 18 Batch 300 Loss 0.4672
# Epoch 18 Batch 400 Loss 0.4573
# Epoch 18 Batch 500 Loss 0.5036
# Epoch 18 Batch 600 Loss 0.4320
# Epoch 18 Batch 700 Loss 0.4086
# Epoch 18 Batch 800 Loss 0.4625
# Epoch 18 Batch 900 Loss 0.4438
# Epoch 18 Batch 1000 Loss 0.4583
# Epoch 18 Batch 1100 Loss 0.4445
# Epoch 18 Batch 1200 Loss 0.4388
# Epoch 18 Batch 1300 Loss 0.4913
# Epoch 18 Batch 1400 Loss 0.5160
# Epoch 18 Batch 1500 Loss 0.4255
# Epoch 18 Batch 1600 Loss 0.4578
# Epoch 18 Batch 1700 Loss 0.4467
# Epoch 18 Batch 1800 Loss 0.4346
# Epoch 18 Batch 1900 Loss 0.4300
# Epoch 18 Batch 2000 Loss 0.4105
# Epoch 18 Batch 2100 Loss 0.5108
# Epoch 18 Batch 2200 Loss 0.4567
# Epoch 18 Batch 2300 Loss 0.4145
# Epoch 18 Batch 2400 Loss 0.4281
# Epoch 18 Batch 2500 Loss 0.4720
# Epoch 18 Batch 2600 Loss 0.4104
# Epoch 18 Batch 2700 Loss 0.4611
# Epoch 18 Batch 2800 Loss 0.4157
# Epoch 18 Batch 2900 Loss 0.4192
# Epoch 18 Batch 3000 Loss 0.4536
# Epoch 18 Batch 3100 Loss 0.4806
# Epoch 18 Batch 3200 Loss 0.4305
# Epoch 18 Batch 3300 Loss 0.4085
# Epoch 18 Batch 3400 Loss 0.4536
# Epoch 18 Batch 3500 Loss 0.4474
# Epoch 18 Batch 3600 Loss 0.4188
# Epoch 18 Batch 3700 Loss 0.4719
# Epoch 18 Batch 3800 Loss 0.4303
# Epoch 18 Batch 3900 Loss 0.4453
# Epoch 18 Batch 4000 Loss 0.4292
# Epoch 18 Batch 4100 Loss 0.4457
# Epoch 18 Batch 4200 Loss 0.4504
# Epoch 18 Batch 4300 Loss 0.4402
# Epoch 18 Batch 4400 Loss 0.4587
# Epoch 18 Batch 4500 Loss 0.4482
# Epoch 18 Batch 4600 Loss 0.4684
# Epoch 18 Batch 4700 Loss 0.4074
# Epoch 18 Batch 4800 Loss 0.4003
# Epoch 18 Batch 4900 Loss 0.4603
# Epoch 18 Batch 5000 Loss 0.4312
# Epoch 18 Batch 5100 Loss 0.4357
# Epoch 18 Batch 5200 Loss 0.4366
# Epoch 18 Batch 5300 Loss 0.4318
# Epoch 18 Batch 5400 Loss 0.4407
# Epoch 18 Batch 5500 Loss 0.4193
# Epoch 18 Batch 5600 Loss 0.4248
# Epoch 18 Batch 5700 Loss 0.4509
# Epoch 18 Batch 5800 Loss 0.3822
# Epoch 18 Batch 5900 Loss 0.4423
# Epoch 18 Batch 6000 Loss 0.3889
# Epoch 18 Batch 6100 Loss 0.4422
# Epoch 18 Batch 6200 Loss 0.4428
# Epoch 18 Batch 6300 Loss 0.4059
# Epoch 18 Batch 6400 Loss 0.4321
# Epoch 18 Batch 6500 Loss 0.4788
# Epoch 18 Batch 6600 Loss 0.4450
# Epoch 18 Batch 6700 Loss 0.4391
# Epoch 18 Batch 6800 Loss 0.4763
# Epoch 18 Batch 6900 Loss 0.4891
# Epoch 18 Batch 7000 Loss 0.4511
# Epoch 18 Batch 7100 Loss 0.4314
# Epoch 18 Batch 7200 Loss 0.4059
# Epoch 18 Batch 7300 Loss 0.4315
# Epoch 18 Loss 0.439792
# Time taken for 1 epoch 2002.45 sec
#
# Epoch 19 Batch 0 Loss 0.4370
# Epoch 19 Batch 100 Loss 0.4186
# Epoch 19 Batch 200 Loss 0.3848
# Epoch 19 Batch 300 Loss 0.4797
# Epoch 19 Batch 400 Loss 0.4371
# Epoch 19 Batch 500 Loss 0.4408
# Epoch 19 Batch 600 Loss 0.4095
# Epoch 19 Batch 700 Loss 0.4255
# Epoch 19 Batch 800 Loss 0.5644
# Epoch 19 Batch 900 Loss 0.4204
# Epoch 19 Batch 1000 Loss 0.5155
# Epoch 19 Batch 1100 Loss 0.4930
# Epoch 19 Batch 1200 Loss 0.4716
# Epoch 19 Batch 1300 Loss 0.4618
# Epoch 19 Batch 1400 Loss 0.4305
# Epoch 19 Batch 1500 Loss 0.4355
# Epoch 19 Batch 1600 Loss 0.4384
# Epoch 19 Batch 1700 Loss 0.4597
# Epoch 19 Batch 1800 Loss 0.4413
# Epoch 19 Batch 1900 Loss 0.4499
# Epoch 19 Batch 2000 Loss 0.4588
# Epoch 19 Batch 2100 Loss 0.4413
# Epoch 19 Batch 2200 Loss 0.4428
# Epoch 19 Batch 2300 Loss 0.4534
# Epoch 19 Batch 2400 Loss 0.4440
# Epoch 19 Batch 2500 Loss 0.4223
# Epoch 19 Batch 2600 Loss 0.4472
# Epoch 19 Batch 2700 Loss 0.3950
# Epoch 19 Batch 2800 Loss 0.4446
# Epoch 19 Batch 2900 Loss 0.4330
# Epoch 19 Batch 3000 Loss 0.4501
# Epoch 19 Batch 3100 Loss 0.4506
# Epoch 19 Batch 3200 Loss 0.4013
# Epoch 19 Batch 3300 Loss 0.4217
# Epoch 19 Batch 3400 Loss 0.4206
# Epoch 19 Batch 3500 Loss 0.5164
# Epoch 19 Batch 3600 Loss 0.4515
# Epoch 19 Batch 3700 Loss 0.4379
# Epoch 19 Batch 3800 Loss 0.4894
# Epoch 19 Batch 3900 Loss 0.4084
# Epoch 19 Batch 4000 Loss 0.4406
# Epoch 19 Batch 4100 Loss 0.4380
# Epoch 19 Batch 4200 Loss 0.4296
# Epoch 19 Batch 4300 Loss 0.4286
# Epoch 19 Batch 4400 Loss 0.4296
# Epoch 19 Batch 4500 Loss 0.4192
# Epoch 19 Batch 4600 Loss 0.4667
# Epoch 19 Batch 4700 Loss 0.4933
# Epoch 19 Batch 4800 Loss 0.4265
# Epoch 19 Batch 4900 Loss 0.4111
# Epoch 19 Batch 5000 Loss 0.4456
# Epoch 19 Batch 5100 Loss 0.4530
# Epoch 19 Batch 5200 Loss 0.4681
# Epoch 19 Batch 5300 Loss 0.4001
# Epoch 19 Batch 5400 Loss 0.4400
# Epoch 19 Batch 5500 Loss 0.4620
# Epoch 19 Batch 5600 Loss 0.4398
# Epoch 19 Batch 5700 Loss 0.4542
# Epoch 19 Batch 5800 Loss 0.4270
# Epoch 19 Batch 5900 Loss 0.4010
# Epoch 19 Batch 6000 Loss 0.4504
# Epoch 19 Batch 6100 Loss 0.4426
# Epoch 19 Batch 6200 Loss 0.3667
# Epoch 19 Batch 6300 Loss 0.4349
# Epoch 19 Batch 6400 Loss 0.4303
# Epoch 19 Batch 6500 Loss 0.4254
# Epoch 19 Batch 6600 Loss 0.3964
# Epoch 19 Batch 6700 Loss 0.4641
# Epoch 19 Batch 6800 Loss 0.4421
# Epoch 19 Batch 6900 Loss 0.4324
# Epoch 19 Batch 7000 Loss 0.4119
# Epoch 19 Batch 7100 Loss 0.4218
# Epoch 19 Batch 7200 Loss 0.4201
# Epoch 19 Batch 7300 Loss 0.4304
# Epoch 19 Loss 0.441999
# Time taken for 1 epoch 2000.72 sec
#
# Epoch 20 Batch 0 Loss 0.4423
# Epoch 20 Batch 100 Loss 0.4572
# Epoch 20 Batch 200 Loss 0.4135
# Epoch 20 Batch 300 Loss 0.3846
# Epoch 20 Batch 400 Loss 0.4693
# Epoch 20 Batch 500 Loss 0.4301
# Epoch 20 Batch 600 Loss 0.3892
# Epoch 20 Batch 700 Loss 0.4516
# Epoch 20 Batch 800 Loss 0.4397
# Epoch 20 Batch 900 Loss 0.4086
# Epoch 20 Batch 1000 Loss 0.4052
# Epoch 20 Batch 1100 Loss 0.4255
# Epoch 20 Batch 1200 Loss 0.4857
# Epoch 20 Batch 1300 Loss 0.3901
# Epoch 20 Batch 1400 Loss 0.4356
# Epoch 20 Batch 1500 Loss 0.4405
# Epoch 20 Batch 1600 Loss 0.4823
# Epoch 20 Batch 1700 Loss 0.4779
# Epoch 20 Batch 1800 Loss 0.4763
# Epoch 20 Batch 1900 Loss 0.4053
# Epoch 20 Batch 2000 Loss 0.5074
# Epoch 20 Batch 2100 Loss 0.4110
# Epoch 20 Batch 2200 Loss 0.4319
# Epoch 20 Batch 2300 Loss 0.4294
# Epoch 20 Batch 2400 Loss 0.4033
# Epoch 20 Batch 2500 Loss 0.4277
# Epoch 20 Batch 2600 Loss 0.4180
# Epoch 20 Batch 2700 Loss 0.4621
# Epoch 20 Batch 2800 Loss 0.4504
# Epoch 20 Batch 2900 Loss 0.4286
# Epoch 20 Batch 3000 Loss 0.4638
# Epoch 20 Batch 3100 Loss 0.4550
# Epoch 20 Batch 3200 Loss 0.4803
# Epoch 20 Batch 3300 Loss 0.4640
# Epoch 20 Batch 3400 Loss 0.4204
# Epoch 20 Batch 3500 Loss 0.4303
# Epoch 20 Batch 3600 Loss 0.4572
# Epoch 20 Batch 3700 Loss 0.4054
# Epoch 20 Batch 3800 Loss 0.4189
# Epoch 20 Batch 3900 Loss 0.4149
# Epoch 20 Batch 4000 Loss 0.4274
# Epoch 20 Batch 4100 Loss 0.4297
# Epoch 20 Batch 4200 Loss 0.4529
# Epoch 20 Batch 4300 Loss 0.4601
# Epoch 20 Batch 4400 Loss 0.4256
# Epoch 20 Batch 4500 Loss 0.4815
# Epoch 20 Batch 4600 Loss 0.4369
# Epoch 20 Batch 4700 Loss 0.4677
# Epoch 20 Batch 4800 Loss 0.4417
# Epoch 20 Batch 4900 Loss 0.4118
# Epoch 20 Batch 5000 Loss 0.4078
# Epoch 20 Batch 5100 Loss 0.4161
# Epoch 20 Batch 5200 Loss 0.4374
# Epoch 20 Batch 5300 Loss 0.4231
# Epoch 20 Batch 5400 Loss 0.4620
# Epoch 20 Batch 5500 Loss 0.4393
# Epoch 20 Batch 5600 Loss 0.4328
# Epoch 20 Batch 5700 Loss 0.4196
# Epoch 20 Batch 5800 Loss 0.4243
# Epoch 20 Batch 5900 Loss 0.4421
# Epoch 20 Batch 6000 Loss 0.4319
# Epoch 20 Batch 6100 Loss 0.4349
# Epoch 20 Batch 6200 Loss 0.4119
# Epoch 20 Batch 6300 Loss 0.4616
# Epoch 20 Batch 6400 Loss 0.4627
# Epoch 20 Batch 6500 Loss 0.4554
# Epoch 20 Batch 6600 Loss 0.4385
# Epoch 20 Batch 6700 Loss 0.3905
# Epoch 20 Batch 6800 Loss 0.4433
# Epoch 20 Batch 6900 Loss 0.4457
# Epoch 20 Batch 7000 Loss 0.3989
# Epoch 20 Batch 7100 Loss 0.3940
# Epoch 20 Batch 7200 Loss 0.4708
# Epoch 20 Batch 7300 Loss 0.4126
# Epoch 20 Loss 0.437925
# Time taken for 1 epoch 2000.37 sec
#
# Epoch 21 Batch 0 Loss 0.4290
# Epoch 21 Batch 100 Loss 0.4120
# Epoch 21 Batch 200 Loss 0.4343
# Epoch 21 Batch 300 Loss 0.4597
# Epoch 21 Batch 400 Loss 0.4121
# Epoch 21 Batch 500 Loss 0.4559
# Epoch 21 Batch 600 Loss 0.4351
# Epoch 21 Batch 700 Loss 0.3824
# Epoch 21 Batch 800 Loss 0.4236
# Epoch 21 Batch 900 Loss 0.4579
# Epoch 21 Batch 1000 Loss 0.3833
# Epoch 21 Batch 1100 Loss 0.4085
# Epoch 21 Batch 1200 Loss 0.4134
# Epoch 21 Batch 1300 Loss 0.4284
# Epoch 21 Batch 1400 Loss 0.4490
# Epoch 21 Batch 1500 Loss 0.4402
# Epoch 21 Batch 1600 Loss 0.4886
# Epoch 21 Batch 1700 Loss 0.4369
# Epoch 21 Batch 1800 Loss 0.4638
# Epoch 21 Batch 1900 Loss 0.3982
# Epoch 21 Batch 2000 Loss 0.4416
# Epoch 21 Batch 2100 Loss 0.4673
# Epoch 21 Batch 2200 Loss 0.4220
# Epoch 21 Batch 2300 Loss 0.4588
# Epoch 21 Batch 2400 Loss 0.4087
# Epoch 21 Batch 2500 Loss 0.4368
# Epoch 21 Batch 2600 Loss 0.4345
# Epoch 21 Batch 2700 Loss 0.4574
# Epoch 21 Batch 2800 Loss 0.4195
# Epoch 21 Batch 2900 Loss 0.3811
# Epoch 21 Batch 3000 Loss 0.4034
# Epoch 21 Batch 3100 Loss 0.4294
# Epoch 21 Batch 3200 Loss 0.4171
# Epoch 21 Batch 3300 Loss 0.3878
# Epoch 21 Batch 3400 Loss 0.4282
# Epoch 21 Batch 3500 Loss 0.4027
# Epoch 21 Batch 3600 Loss 0.4418
# Epoch 21 Batch 3700 Loss 0.4330
# Epoch 21 Batch 3800 Loss 0.3993
# Epoch 21 Batch 3900 Loss 0.4513
# Epoch 21 Batch 4000 Loss 0.4219
# Epoch 21 Batch 4100 Loss 0.4301
# Epoch 21 Batch 4200 Loss 0.4152
# Epoch 21 Batch 4300 Loss 0.4579
# Epoch 21 Batch 4400 Loss 0.4180
# Epoch 21 Batch 4500 Loss 0.4200
# Epoch 21 Batch 4600 Loss 0.4340
# Epoch 21 Batch 4700 Loss 0.4101
# Epoch 21 Batch 4800 Loss 0.3883
# Epoch 21 Batch 4900 Loss 0.4659
# Epoch 21 Batch 5000 Loss 0.4041
# Epoch 21 Batch 5100 Loss 0.4279
# Epoch 21 Batch 5200 Loss 0.4302
# Epoch 21 Batch 5300 Loss 0.4400
# Epoch 21 Batch 5400 Loss 0.3892
# Epoch 21 Batch 5500 Loss 0.4164
# Epoch 21 Batch 5600 Loss 0.4310
# Epoch 21 Batch 5700 Loss 0.4195
# Epoch 21 Batch 5800 Loss 0.4156
# Epoch 21 Batch 5900 Loss 0.4185
# Epoch 21 Batch 6000 Loss 0.4245
# Epoch 21 Batch 6100 Loss 0.4366
# Epoch 21 Batch 6200 Loss 0.4341
# Epoch 21 Batch 6300 Loss 0.4264
# Epoch 21 Batch 6400 Loss 0.4552
# Epoch 21 Batch 6500 Loss 0.4492
# Epoch 21 Batch 6600 Loss 0.4494
# Epoch 21 Batch 6700 Loss 0.4507
# Epoch 21 Batch 6800 Loss 0.4513
# Epoch 21 Batch 6900 Loss 0.4333
# Epoch 21 Batch 7000 Loss 0.4282
# Epoch 21 Batch 7100 Loss 0.4553
# Epoch 21 Batch 7200 Loss 0.4557
# Epoch 21 Batch 7300 Loss 0.4504
# Epoch 21 Loss 0.431689
# Time taken for 1 epoch 2006.36 sec
#
# Epoch 22 Batch 0 Loss 0.4135
# Epoch 22 Batch 100 Loss 0.4081
# Epoch 22 Batch 200 Loss 0.4774
# Epoch 22 Batch 300 Loss 0.4367
# Epoch 22 Batch 400 Loss 0.4466
# Epoch 22 Batch 500 Loss 0.4392
# Epoch 22 Batch 600 Loss 0.3997
# Epoch 22 Batch 700 Loss 0.4452
# Epoch 22 Batch 800 Loss 0.4865
# Epoch 22 Batch 900 Loss 0.4075
# Epoch 22 Batch 1000 Loss 0.4249
# Epoch 22 Batch 1100 Loss 0.4549
# Epoch 22 Batch 1200 Loss 0.4348
# Epoch 22 Batch 1300 Loss 0.4101
# Epoch 22 Batch 1400 Loss 0.4106
# Epoch 22 Batch 1500 Loss 0.4333
# Epoch 22 Batch 1600 Loss 0.4221
# Epoch 22 Batch 1700 Loss 0.4431
# Epoch 22 Batch 1800 Loss 0.4098
# Epoch 22 Batch 1900 Loss 0.4269
# Epoch 22 Batch 2000 Loss 0.4284
# Epoch 22 Batch 2100 Loss 0.4723
# Epoch 22 Batch 2200 Loss 0.4101
# Epoch 22 Batch 2300 Loss 0.4389
# Epoch 22 Batch 2400 Loss 0.4902
# Epoch 22 Batch 2500 Loss 0.4846
# Epoch 22 Batch 2600 Loss 0.3930
# Epoch 22 Batch 2700 Loss 0.4507
# Epoch 22 Batch 2800 Loss 0.4336
# Epoch 22 Batch 2900 Loss 0.4455
# Epoch 22 Batch 3000 Loss 0.4125
# Epoch 22 Batch 3100 Loss 0.3939
# Epoch 22 Batch 3200 Loss 0.4311
# Epoch 22 Batch 3300 Loss 0.4017
# Epoch 22 Batch 3400 Loss 0.4864
# Epoch 22 Batch 3500 Loss 0.4370
# Epoch 22 Batch 3600 Loss 0.4446
# Epoch 22 Batch 3700 Loss 0.3869
# Epoch 22 Batch 3800 Loss 0.4158
# Epoch 22 Batch 3900 Loss 0.3987
# Epoch 22 Batch 4000 Loss 0.4496
# Epoch 22 Batch 4100 Loss 0.4225
# Epoch 22 Batch 4200 Loss 0.4306
# Epoch 22 Batch 4300 Loss 0.4376
# Epoch 22 Batch 4400 Loss 0.4118
# Epoch 22 Batch 4500 Loss 0.4528
# Epoch 22 Batch 4600 Loss 0.4404
# Epoch 22 Batch 4700 Loss 0.4523
# Epoch 22 Batch 4800 Loss 0.4618
# Epoch 22 Batch 4900 Loss 0.4045
# Epoch 22 Batch 5000 Loss 0.4352
# Epoch 22 Batch 5100 Loss 0.4145
# Epoch 22 Batch 5200 Loss 0.4464
# Epoch 22 Batch 5300 Loss 0.4111
# Epoch 22 Batch 5400 Loss 0.4545
# Epoch 22 Batch 5500 Loss 0.4344
# Epoch 22 Batch 5600 Loss 0.4307
# Epoch 22 Batch 5700 Loss 0.4295
# Epoch 22 Batch 5800 Loss 0.3963
# Epoch 22 Batch 5900 Loss 0.4610
# Epoch 22 Batch 6000 Loss 0.4472
# Epoch 22 Batch 6100 Loss 0.4205
# Epoch 22 Batch 6200 Loss 0.4621
# Epoch 22 Batch 6300 Loss 0.4139
# Epoch 22 Batch 6400 Loss 0.3633
# Epoch 22 Batch 6500 Loss 0.4340
# Epoch 22 Batch 6600 Loss 0.3976
# Epoch 22 Batch 6700 Loss 0.4263
# Epoch 22 Batch 6800 Loss 0.4501
# Epoch 22 Batch 6900 Loss 0.4836
# Epoch 22 Batch 7000 Loss 0.4277
# Epoch 22 Batch 7100 Loss 0.4359
# Epoch 22 Batch 7200 Loss 0.3917
# Epoch 22 Batch 7300 Loss 0.4016
# Epoch 22 Loss 0.429497
# Time taken for 1 epoch 2001.84 sec
#
# Epoch 23 Batch 0 Loss 0.4379
# Epoch 23 Batch 100 Loss 0.3685
# Epoch 23 Batch 200 Loss 0.4255
# Epoch 23 Batch 300 Loss 0.4026
# Epoch 23 Batch 400 Loss 0.4643
# Epoch 23 Batch 500 Loss 0.4452
# Epoch 23 Batch 600 Loss 0.4697
# Epoch 23 Batch 700 Loss 0.3852
# Epoch 23 Batch 800 Loss 0.4274
# Epoch 23 Batch 900 Loss 0.3961
# Epoch 23 Batch 1000 Loss 0.4225
# Epoch 23 Batch 1100 Loss 0.4459
# Epoch 23 Batch 1200 Loss 0.4467
# Epoch 23 Batch 1300 Loss 0.3920
# Epoch 23 Batch 1400 Loss 0.4381
# Epoch 23 Batch 1500 Loss 0.4269
# Epoch 23 Batch 1600 Loss 0.4010
# Epoch 23 Batch 1700 Loss 0.4161
# Epoch 23 Batch 1800 Loss 0.4479
# Epoch 23 Batch 1900 Loss 0.4251
# Epoch 23 Batch 2000 Loss 0.4511
# Epoch 23 Batch 2100 Loss 0.4650
# Epoch 23 Batch 2200 Loss 0.4074
# Epoch 23 Batch 2300 Loss 0.4069
# Epoch 23 Batch 2400 Loss 0.4546
# Epoch 23 Batch 2500 Loss 0.4341
# Epoch 23 Batch 2600 Loss 0.4301
# Epoch 23 Batch 2700 Loss 0.4258
# Epoch 23 Batch 2800 Loss 0.4320
# Epoch 23 Batch 2900 Loss 0.4545
# Epoch 23 Batch 3000 Loss 0.4130
# Epoch 23 Batch 3100 Loss 0.4476
# Epoch 23 Batch 3200 Loss 0.3930
# Epoch 23 Batch 3300 Loss 0.4468
# Epoch 23 Batch 3400 Loss 0.4469
# Epoch 23 Batch 3500 Loss 0.4365
# Epoch 23 Batch 3600 Loss 0.4394
# Epoch 23 Batch 3700 Loss 0.4399
# Epoch 23 Batch 3800 Loss 0.4293
# Epoch 23 Batch 3900 Loss 0.4406
# Epoch 23 Batch 4000 Loss 0.4158
# Epoch 23 Batch 4100 Loss 0.4536
# Epoch 23 Batch 4200 Loss 0.4206
# Epoch 23 Batch 4300 Loss 0.4135
# Epoch 23 Batch 4400 Loss 0.4166
# Epoch 23 Batch 4500 Loss 0.4244
# Epoch 23 Batch 4600 Loss 0.4465
# Epoch 23 Batch 4700 Loss 0.4394
# Epoch 23 Batch 4800 Loss 0.4293
# Epoch 23 Batch 4900 Loss 0.4667
# Epoch 23 Batch 5000 Loss 0.4539
# Epoch 23 Batch 5100 Loss 0.4192
# Epoch 23 Batch 5200 Loss 0.4273
# Epoch 23 Batch 5300 Loss 0.4629
# Epoch 23 Batch 5400 Loss 0.4509
# Epoch 23 Batch 5500 Loss 0.4061
# Epoch 23 Batch 5600 Loss 0.4428
# Epoch 23 Batch 5700 Loss 0.4390
# Epoch 23 Batch 5800 Loss 0.3962
# Epoch 23 Batch 5900 Loss 0.4579
# Epoch 23 Batch 6000 Loss 0.4155
# Epoch 23 Batch 6100 Loss 0.4588
# Epoch 23 Batch 6200 Loss 0.4198
# Epoch 23 Batch 6300 Loss 0.4127
# Epoch 23 Batch 6400 Loss 0.3805
# Epoch 23 Batch 6500 Loss 0.4570
# Epoch 23 Batch 6600 Loss 0.4298
# Epoch 23 Batch 6700 Loss 0.4297
# Epoch 23 Batch 6800 Loss 0.4487
# Epoch 23 Batch 6900 Loss 0.4134
# Epoch 23 Batch 7000 Loss 0.4208
# Epoch 23 Batch 7100 Loss 0.3902
# Epoch 23 Batch 7200 Loss 0.4138
# Epoch 23 Batch 7300 Loss 0.4184
# Epoch 23 Loss 0.427286
# Time taken for 1 epoch 2000.65 sec
#
# Epoch 24 Batch 0 Loss 0.4272
# Epoch 24 Batch 100 Loss 0.4216
# Epoch 24 Batch 200 Loss 0.4104
# Epoch 24 Batch 300 Loss 0.4139
# Epoch 24 Batch 400 Loss 0.4422
# Epoch 24 Batch 500 Loss 0.3902
# Epoch 24 Batch 600 Loss 0.4642
# Epoch 24 Batch 700 Loss 0.4052
# Epoch 24 Batch 800 Loss 0.4283
# Epoch 24 Batch 900 Loss 0.4489
# Epoch 24 Batch 1000 Loss 0.4243
# Epoch 24 Batch 1100 Loss 0.4237
# Epoch 24 Batch 1200 Loss 0.4175
# Epoch 24 Batch 1300 Loss 0.3923
# Epoch 24 Batch 1400 Loss 0.4228
# Epoch 24 Batch 1500 Loss 0.4467
# Epoch 24 Batch 1600 Loss 0.4522
# Epoch 24 Batch 1700 Loss 0.4573
# Epoch 24 Batch 1800 Loss 0.4348
# Epoch 24 Batch 1900 Loss 0.4225
# Epoch 24 Batch 2000 Loss 0.4381
# Epoch 24 Batch 2100 Loss 0.4491
# Epoch 24 Batch 2200 Loss 0.4013
# Epoch 24 Batch 2300 Loss 0.3993
# Epoch 24 Batch 2400 Loss 0.4302
# Epoch 24 Batch 2500 Loss 0.4219
# Epoch 24 Batch 2600 Loss 0.4373
# Epoch 24 Batch 2700 Loss 0.4007
# Epoch 24 Batch 2800 Loss 0.4684
# Epoch 24 Batch 2900 Loss 0.4065
# Epoch 24 Batch 3000 Loss 0.4625
# Epoch 24 Batch 3100 Loss 0.3743
# Epoch 24 Batch 3200 Loss 0.4421
# Epoch 24 Batch 3300 Loss 0.4918
# Epoch 24 Batch 3400 Loss 0.3953
# Epoch 24 Batch 3500 Loss 0.4113
# Epoch 24 Batch 3600 Loss 0.4418
# Epoch 24 Batch 3700 Loss 0.4281
# Epoch 24 Batch 3800 Loss 0.3835
# Epoch 24 Batch 3900 Loss 0.4241
# Epoch 24 Batch 4000 Loss 0.4320
# Epoch 24 Batch 4100 Loss 0.3999
# Epoch 24 Batch 4200 Loss 0.4428
# Epoch 24 Batch 4300 Loss 0.4247
# Epoch 24 Batch 4400 Loss 0.4191
# Epoch 24 Batch 4500 Loss 0.4239
# Epoch 24 Batch 4600 Loss 0.4277
# Epoch 24 Batch 4700 Loss 0.3887
# Epoch 24 Batch 4800 Loss 0.4107
# Epoch 24 Batch 4900 Loss 0.4471
# Epoch 24 Batch 5000 Loss 0.4606
# Epoch 24 Batch 5100 Loss 0.4555
# Epoch 24 Batch 5200 Loss 0.3920
# Epoch 24 Batch 5300 Loss 0.4765
# Epoch 24 Batch 5400 Loss 0.4158
# Epoch 24 Batch 5500 Loss 0.4079
# Epoch 24 Batch 5600 Loss 0.4172
# Epoch 24 Batch 5700 Loss 0.3856
# Epoch 24 Batch 5800 Loss 0.4176
# Epoch 24 Batch 5900 Loss 0.4198
# Epoch 24 Batch 6000 Loss 0.4178
# Epoch 24 Batch 6100 Loss 0.4030
# Epoch 24 Batch 6200 Loss 0.4673
# Epoch 24 Batch 6300 Loss 0.4513
# Epoch 24 Batch 6400 Loss 0.4120
# Epoch 24 Batch 6500 Loss 0.4235
# Epoch 24 Batch 6600 Loss 0.3912
# Epoch 24 Batch 6700 Loss 0.4235
# Epoch 24 Batch 6800 Loss 0.4390
# Epoch 24 Batch 6900 Loss 0.4367
# Epoch 24 Batch 7000 Loss 0.4052
# Epoch 24 Batch 7100 Loss 0.4736
# Epoch 24 Batch 7200 Loss 0.3706
# Epoch 24 Batch 7300 Loss 0.4214
# Epoch 24 Loss 0.425691
# Time taken for 1 epoch 2000.20 sec
#
# Epoch 25 Batch 0 Loss 0.3992
# Epoch 25 Batch 100 Loss 0.4037
# Epoch 25 Batch 200 Loss 0.4129
# Epoch 25 Batch 300 Loss 0.3907
# Epoch 25 Batch 400 Loss 0.4368
# Epoch 25 Batch 500 Loss 0.4688
# Epoch 25 Batch 600 Loss 0.4017
# Epoch 25 Batch 700 Loss 0.4253
# Epoch 25 Batch 800 Loss 0.4369
# Epoch 25 Batch 900 Loss 0.4448
# Epoch 25 Batch 1000 Loss 0.4168
# Epoch 25 Batch 1100 Loss 0.4098
# Epoch 25 Batch 1200 Loss 0.4681
# Epoch 25 Batch 1300 Loss 0.4082
# Epoch 25 Batch 1400 Loss 0.4372
# Epoch 25 Batch 1500 Loss 0.3807
# Epoch 25 Batch 1600 Loss 0.4666
# Epoch 25 Batch 1700 Loss 0.4240
# Epoch 25 Batch 1800 Loss 0.4521
# Epoch 25 Batch 1900 Loss 0.4273
# Epoch 25 Batch 2000 Loss 0.4656
# Epoch 25 Batch 2100 Loss 0.4077
# Epoch 25 Batch 2200 Loss 0.3906
# Epoch 25 Batch 2300 Loss 0.3838
# Epoch 25 Batch 2400 Loss 0.4082
# Epoch 25 Batch 2500 Loss 0.4172
# Epoch 25 Batch 2600 Loss 0.4177
# Epoch 25 Batch 2700 Loss 0.4530
# Epoch 25 Batch 2800 Loss 0.4860
# Epoch 25 Batch 2900 Loss 0.3962
# Epoch 25 Batch 3000 Loss 0.3940
# Epoch 25 Batch 3100 Loss 0.4079
# Epoch 25 Batch 3200 Loss 0.4432
# Epoch 25 Batch 3300 Loss 0.4258
# Epoch 25 Batch 3400 Loss 0.4129
# Epoch 25 Batch 3500 Loss 0.4042
# Epoch 25 Batch 3600 Loss 0.4209
# Epoch 25 Batch 3700 Loss 0.4525
# Epoch 25 Batch 3800 Loss 0.4313
# Epoch 25 Batch 3900 Loss 0.4220
# Epoch 25 Batch 4000 Loss 0.4412
# Epoch 25 Batch 4100 Loss 0.4239
# Epoch 25 Batch 4200 Loss 0.4145
# Epoch 25 Batch 4300 Loss 0.4401
# Epoch 25 Batch 4400 Loss 0.4456
# Epoch 25 Batch 4500 Loss 0.3960
# Epoch 25 Batch 4600 Loss 0.4509
# Epoch 25 Batch 4700 Loss 0.4002
# Epoch 25 Batch 4800 Loss 0.4083
# Epoch 25 Batch 4900 Loss 0.4153
# Epoch 25 Batch 5000 Loss 0.4183
# Epoch 25 Batch 5100 Loss 0.4270
# Epoch 25 Batch 5200 Loss 0.4299
# Epoch 25 Batch 5300 Loss 0.3985
# Epoch 25 Batch 5400 Loss 0.3989
# Epoch 25 Batch 5500 Loss 0.4469
# Epoch 25 Batch 5600 Loss 0.4436
# Epoch 25 Batch 5700 Loss 0.4692
# Epoch 25 Batch 5800 Loss 0.4177
# Epoch 25 Batch 5900 Loss 0.4213
# Epoch 25 Batch 6000 Loss 0.4349
# Epoch 25 Batch 6100 Loss 0.4880
# Epoch 25 Batch 6200 Loss 0.4246
# Epoch 25 Batch 6300 Loss 0.3918
# Epoch 25 Batch 6400 Loss 0.4126
# Epoch 25 Batch 6500 Loss 0.4207
# Epoch 25 Batch 6600 Loss 0.4004
# Epoch 25 Batch 6700 Loss 0.3935
# Epoch 25 Batch 6800 Loss 0.3981
# Epoch 25 Batch 6900 Loss 0.4175
# Epoch 25 Batch 7000 Loss 0.4195
# Epoch 25 Batch 7100 Loss 0.4156
# Epoch 25 Batch 7200 Loss 0.3859
# Epoch 25 Batch 7300 Loss 0.4266
# Epoch 25 Loss 0.423916
# Time taken for 1 epoch 2003.22 sec

# %%
plt.plot(loss_plot)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Loss Plot")
plt.grid()
plt.show()

# %%
def evaluate(image):
    attention_plot = np.zeros((max_length, attention_features_shape))

    hidden = decoder.reset_state(batch_size=1)

    temp_input = tf.expand_dims(load_image(image)[0], 0)
    img_tensor_val = image_features_extract(temp_input)
    img_tensor_val = tf.reshape(img_tensor_val, (img_tensor_val.shape[0],
                                                 -1,
                                                 img_tensor_val.shape[3]))

    features = encoder(img_tensor_val)

    dec_input = tf.expand_dims([word_to_index('<start>')], 0)
    result = []

    for i in range(max_length):
        predictions, hidden, attention_weights = decoder(dec_input,
                                                         features,
                                                         hidden)

        attention_plot[i] = tf.reshape(attention_weights, (-1, )).numpy()
        #attention_plot[i] = tf.reshape(81, (-1, )).numpy()

        predicted_id = tf.random.categorical(predictions, 1)[0][0].numpy()
        predicted_word = tf.compat.as_text(index_to_word(predicted_id).numpy())
        result.append(predicted_word)

        if predicted_word == '<end>':
            return result, attention_plot

        dec_input = tf.expand_dims([predicted_id], 0)

    attention_plot = attention_plot[:len(result), :]
    return result, attention_plot

# %%
def plot_attention(image, result, attention_plot):
    temp_image = np.array(Image.open(image))

    fig = plt.figure(figsize=(10, 10))

    len_result = len(result)
    for i in range(len_result):
        temp_att = np.resize(attention_plot[i], (8, 8))
        grid_size = max(int(np.ceil(len_result/2)), 2)
        ax = fig.add_subplot(grid_size, grid_size, i+1)
        ax.set_title(result[i])
        img = ax.imshow(temp_image)
        ax.imshow(temp_att, cmap='gray', alpha=0.6, extent=img.get_extent())

    plt.tight_layout()
    plt.show()

# %%
import nltk
from nltk.translate.bleu_score import SmoothingFunction

# %%
from operator import mod
# captions on the validation set
rid = np.random.randint(0, len(img_name_val))
image = img_name_val[rid]
real_caption = ' '.join([tf.compat.as_text(index_to_word(i).numpy())
                         for i in cap_val[rid] if i not in [0]])
result, attention_plot = evaluate(image)

print('Real Caption:', real_caption)
print('Prediction Caption:', ' '.join(result))
plot_attention(image, result, attention_plot)

print("\n\n\n\nBLEU Scores:")
predCap=" ".join(result).replace("<end>","")
modRealCap=real_caption.replace("<start>","").replace("<end>","")
print("Dataset size: ",len(img_name_train))
print("Vocabulary size : ",vocabulary_size)
print("Description length : ",max_length)

print("real caption: ",modRealCap,"\nPredicted Cap: ",predCap)
list_of_ref=[modRealCap.split(" ")]
list_of_hyp=[predCap.split(" ")]

smoothie=SmoothingFunction().method5

print("BLEU-1 : ",nltk.translate.bleu_score.corpus_bleu(list_of_ref,list_of_hyp,weights=(1.0,0,0,0),smoothing_function= smoothie))
print("BLEU-2 : ",nltk.translate.bleu_score.corpus_bleu(list_of_ref,list_of_hyp,weights=(0.5,0.5,0,0),smoothing_function=smoothie))
print("BLEU-3 : ",nltk.translate.bleu_score.corpus_bleu(list_of_ref,list_of_hyp,weights=(0.3,0.3,0.3,0),smoothing_function=smoothie))
print("BLEU-4 : ",nltk.translate.bleu_score.corpus_bleu(list_of_ref,list_of_hyp,weights=(0.25,0.25,0.25,0.25),smoothing_function=smoothie))

print(image)
# Out:
# Real Caption: <start> a man pulls a suitcase on wheels down a sidewalk. <end>
# Prediction Caption: a man riding a suitcase down the street. <end>
# BLEU Scores:
# Dataset size:  473402
# Vocabulary size :  15000
# Description length :  50
# real caption:   a man pulls a suitcase on wheels down a sidewalk.
# Predicted Cap:  a man riding a suitcase down the street.
# BLEU-1 :  0.4074074074074074
# BLEU-2 :  0.2352167763365142
# BLEU-3 :  0.1658123596227853
# BLEU-4 :  0.07840559211217141
# /content/train2017/000000170950.jpg

# %%
from matplotlib import pyplot as plt
from matplotlib import image as mpimg
 
plt.title("IMAGE")
plt.xlabel("X pixel scaling")
plt.ylabel("Y pixels scaling")
 
ima = mpimg.imread("/content/train2017/000000170950.jpg")
plt.imshow(ima)
plt.show()

# %%
image_url = 'https://tensorflow.org/images/surf.jpg'
image_extension = image_url[-4:]
image_path = tf.keras.utils.get_file('image'+image_extension, origin=image_url)

result, attention_plot = evaluate(image_path)
print('Prediction Caption:', ' '.join(result))
plot_attention(image_path, result, attention_plot)
# opening the image
Image.open(image_path)
# Out:
# Prediction Caption: a guy wave on the board rides a wave <end>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x426 at 0x7FC244115D10>

# %%
Image_Model.save("b7.h5")
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
