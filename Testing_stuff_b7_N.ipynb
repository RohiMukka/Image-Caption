# %% [markdown]
# <a href="https://colab.research.google.com/github/RohiMukka/Image-Caption/blob/main/Testing_stuff_b7_N.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import collections
import random
from tqdm import tqdm
import numpy as np
import os
import time
import json
from PIL import Image

# %%
# !wget https://storage.googleapis.com/cloud-tpu-checkpoints/efficientnet/noisystudent/noisy_student_efficientnet-b7.tar.gz
# Out:
# --2022-04-09 06:37:14--  https://storage.googleapis.com/cloud-tpu-checkpoints/efficientnet/noisystudent/noisy_student_efficientnet-b7.tar.gz
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.119.128, 108.177.126.128, 108.177.127.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.119.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 491946092 (469M) [application/octet-stream]
# Saving to: ‘noisy_student_efficientnet-b7.tar.gz’
#
# noisy_student_effic 100%[===================>] 469.16M  53.5MB/s    in 9.7s
#
# 2022-04-09 06:37:25 (48.4 MB/s) - ‘noisy_student_efficientnet-b7.tar.gz’ saved [491946092/491946092]

# %%
# !tar -xf noisy_student_efficientnet-b7.tar.gz

# %%
#!wget https://github.com/MarkusRosen/keras-efficientnet-regression/blob/master/efficientnet_weight_update_util.py
# !python weight_update_util.py --model b7 --notop --ckpt /content/noisy_student_efficientnet-b7/model.ckpt --o efficientnetb7_notop.h5
# Out:
# 2022-04-09 06:38:14.041071: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb7_notop.h5
# 258080768/258076736 [==============================] - 1s 0us/step
# 258088960/258076736 [==============================] - 1s 0us/step
# check variables match in each block
# blocks_0 and block1a match.
# blocks_1 and block1b match.
# blocks_2 and block1c match.
# blocks_3 and block1d match.
# blocks_4 and block2a match.
# blocks_5 and block2b match.
# blocks_6 and block2c match.
# blocks_7 and block2d match.
# blocks_8 and block2e match.
# blocks_9 and block2f match.
# blocks_10 and block2g match.
# blocks_11 and block3a match.
# blocks_12 and block3b match.
# blocks_13 and block3c match.
# blocks_14 and block3d match.
# blocks_15 and block3e match.
# blocks_16 and block3f match.
# blocks_17 and block3g match.
# blocks_18 and block4a match.
# blocks_19 and block4b match.
# blocks_20 and block4c match.
# blocks_21 and block4d match.
# blocks_22 and block4e match.
# blocks_23 and block4f match.
# blocks_24 and block4g match.
# blocks_25 and block4h match.
# blocks_26 and block4i match.
# blocks_27 and block4j match.
# blocks_28 and block5a match.
# blocks_29 and block5b match.
# blocks_30 and block5c match.
# blocks_31 and block5d match.
# blocks_32 and block5e match.
# blocks_33 and block5f match.
# blocks_34 and block5g match.
# blocks_35 and block5h match.
# blocks_36 and block5i match.
# blocks_37 and block5j match.
# blocks_38 and block6a match.
# blocks_39 and block6b match.
# blocks_40 and block6c match.
# blocks_41 and block6d match.
# blocks_42 and block6e match.
# blocks_43 and block6f match.
# blocks_44 and block6g match.
# blocks_45 and block6h match.
# blocks_46 and block6i match.
# blocks_47 and block6j match.
# blocks_48 and block6k match.
# blocks_49 and block6l match.
# blocks_50 and block6m match.
# blocks_51 and block7a match.
# blocks_52 and block7b match.
# blocks_53 and block7c match.
# blocks_54 and block7d match.
# skipping variable normalization/mean:0: normalization is a layerin keras implementation, but preprocessing in TF implementation.
# skipping variable normalization/variance:0: normalization is a layerin keras implementation, but preprocessing in TF implementation.
# skipping variable normalization/count:0: normalization is a layerin keras implementation, but preprocessing in TF implementation.
# 1035/1038 weights updated

# %%
#!unzip /content/noisy.student.notop-b6.h5.zip
#from efficientnet.model import EfficientNetB6
#!pip install efficientnet
#import efficientnet.keras as efn 

#model = efn.EfficientNetB6(weights="/content/noisy.student.notop-b6.h5", include_top=False)
#model = EfficientNetB6(weights="/content/noisy.student.notop-b6.h5", include_top=False)

# %%
# Download caption annotation files
annotation_folder = '/annotations/'
if not os.path.exists(os.path.abspath('.') + annotation_folder):
  annotation_zip = tf.keras.utils.get_file('captions.zip',
                                           cache_subdir=os.path.abspath('.'),
                                           origin='http://images.cocodataset.org/annotations/annotations_trainval2017.zip',
                                           extract=True)
  annotation_file = os.path.dirname(annotation_zip)+'/annotations/captions_train2017.json'
  os.remove(annotation_zip)

# Download image files
image_folder = '/train2017/'
if not os.path.exists(os.path.abspath('.') + image_folder):
  image_zip = tf.keras.utils.get_file('train2017.zip',
                                      cache_subdir=os.path.abspath('.'),
                                      origin='http://images.cocodataset.org/zips/train2017.zip',
                                      extract=True)
  PATH = os.path.dirname(image_zip) + image_folder
  os.remove(image_zip)
else:
  PATH = os.path.abspath('.') + image_folder
# Out:
# Downloading data from http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# 252911616/252907541 [==============================] - 7s 0us/step
# 252919808/252907541 [==============================] - 7s 0us/step
# Downloading data from http://images.cocodataset.org/zips/train2017.zip
# 19336863744/19336861798 [==============================] - 521s 0us/step
# 19336871936/19336861798 [==============================] - 521s 0us/step

# %%
with open(annotation_file, 'r') as f:
    annotations = json.load(f)

# %%
# Group all captions together having the same image ID.
image_path_to_caption = collections.defaultdict(list)
for val in annotations['annotations']:
  caption = f"<start> {val['caption']} <end>"
  image_path = PATH + '%012d.jpg' % (val['image_id'])
  image_path_to_caption[image_path].append(caption)

# %%
image_paths = list(image_path_to_caption.keys())
random.shuffle(image_paths)
train_image_paths = image_paths
print("Number of images : ",len(image_paths),"\nDataset size: ",len(train_image_paths))
# Out:
# Number of images :  118287
# Dataset size:  118287

# %%
train_captions=[]
img_name_vector=[]

for path in train_image_paths:
    caption_list=image_path_to_caption[path]
    train_captions.extend(caption_list)
    img_name_vector.extend([path]*len(caption_list))

# %%
print(train_captions[1])
Image.open(img_name_vector[1])
# Out:
# <start> The yellow hydrant is across the street from tall buildings. <end>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=420x640 at 0x7FC7CDED6D50>

# %%
def load_image(image_path):
    img=tf.io.read_file(image_path)
    img=tf.io.decode_jpeg(img,channels=3)
    img=tf.keras.layers.Resizing(300,300)(img)
    img=tf.keras.applications.efficientnet.preprocess_input(img)
    return img, image_path

# %%
Image_Model=tf.keras.applications.EfficientNetB7(include_top=False,weights='/content/efficientnetb7_notop.h5')
new_input = Image_Model.input
hidden_layer=Image_Model.layers[-1].output
image_features_extract=tf.keras.Model(new_input,hidden_layer)

# %%
encode_train=sorted(set(img_name_vector))
image_dataset=tf.data.Dataset.from_tensor_slices(encode_train)
image_dataset=image_dataset.map(load_image,num_parallel_calls=tf.data.AUTOTUNE).batch(64)

for img,path in tqdm(image_dataset):
    batch_features=image_features_extract(img)
    batch_features=tf.reshape(batch_features,(batch_features.shape[0],-1,batch_features.shape[3]))
    for bf, p in zip(batch_features,path):
        path_of_feature=p.numpy().decode("utf-8")
        np.save(path_of_feature,bf.numpy())
# Out:
# 100%|██████████| 1849/1849 [28:58<00:00,  1.06it/s]

# %%
caption_dataset= tf.data.Dataset.from_tensor_slices(train_captions)

def standardize(inputs):
    inputs=tf.strings.lower(inputs)
    return tf.strings.regex_replace(inputs,r'''!\"#$%\(\)\*\+.,-/:;=?@\[\\\]^_`{|}~''',"")

max_length=50 #max word count
vocabulary_size=9490
tokenizer=tf.keras.layers.TextVectorization(max_tokens=vocabulary_size,standardize=standardize,output_sequence_length=max_length)
tokenizer.adapt(caption_dataset)

# %%
cap_vector = caption_dataset.map(lambda x: tokenizer(x))

# %%
word_to_index = tf.keras.layers.StringLookup(
    mask_token="",
    vocabulary=tokenizer.get_vocabulary())
index_to_word = tf.keras.layers.StringLookup(
    mask_token="",
    vocabulary=tokenizer.get_vocabulary(),
    invert=True)

# %%
img_to_cap_vector = collections.defaultdict(list)
for img, cap in zip(img_name_vector, cap_vector):
  img_to_cap_vector[img].append(cap)

# Create training and validation sets using an 80-20 split randomly.
img_keys = list(img_to_cap_vector.keys())
random.shuffle(img_keys)

slice_index = int(len(img_keys)*0.8)
img_name_train_keys, img_name_val_keys = img_keys[:slice_index], img_keys[slice_index:]

img_name_train = []
cap_train = []
for imgt in img_name_train_keys:
  capt_len = len(img_to_cap_vector[imgt])
  img_name_train.extend([imgt] * capt_len)
  cap_train.extend(img_to_cap_vector[imgt])

img_name_val = []
cap_val = []
for imgv in img_name_val_keys:
  capv_len = len(img_to_cap_vector[imgv])
  img_name_val.extend([imgv] * capv_len)
  cap_val.extend(img_to_cap_vector[imgv])

# %%
len(img_name_train), len(cap_train), len(img_name_val), len(cap_val)
# Out:
# (473409, 473409, 118344, 118344)

# %%
BATCH_SIZE = 64
BUFFER_SIZE = 1000
embedding_dim = 600
units = 512
num_steps = len(img_name_train) // BATCH_SIZE
# These two variables represent that vector shape
features_shape = 2560
attention_features_shape = 81

# %%
def map_func(img_name, cap):
  img_tensor = np.load(img_name.decode('utf-8')+'.npy')
  return img_tensor, cap

# %%
dataset = tf.data.Dataset.from_tensor_slices((img_name_train, cap_train))

# Use map to load the numpy files in parallel
dataset = dataset.map(lambda item1, item2: tf.numpy_function(
          map_func, [item1, item2], [tf.float32, tf.int64]),
          num_parallel_calls=tf.data.AUTOTUNE)

# Shuffle and batch
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
dataset = dataset.prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
class BahdanauAttention(tf.keras.Model):
  def __init__(self, units):
    super(BahdanauAttention, self).__init__()
    self.W1 = tf.keras.layers.Dense(units)
    self.W2 = tf.keras.layers.Dense(units)
    self.V = tf.keras.layers.Dense(1)

  def call(self, features, hidden):
    
    hidden_with_time_axis = tf.expand_dims(hidden, 1)

    
    attention_hidden_layer = (tf.nn.tanh(self.W1(features) +
                                         self.W2(hidden_with_time_axis)))

    
    score = self.V(attention_hidden_layer)

    
    attention_weights = tf.nn.softmax(score, axis=1)

    
    context_vector = attention_weights * features
    context_vector = tf.reduce_sum(context_vector, axis=1)

    return context_vector, attention_weights

# %%
class CNN_Encoder(tf.keras.Model):
    
    def __init__(self, embedding_dim):
        super(CNN_Encoder, self).__init__()
        
        self.fc = tf.keras.layers.Dense(embedding_dim)

    def call(self, x):
        x = self.fc(x)
        x = tf.nn.relu(x)
        return x

# %%
class RNN_Decoder(tf.keras.Model):
  def __init__(self, embedding_dim, units, vocab_size):
    super(RNN_Decoder, self).__init__()
    self.units = units

    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc1 = tf.keras.layers.Dense(self.units)
    self.fc2 = tf.keras.layers.Dense(vocab_size)

    self.attention = BahdanauAttention(self.units)

  def call(self, x, features, hidden):
    # defining attention as a separate model
    context_vector, attention_weights = self.attention(features, hidden)
    x = self.embedding(x)
    x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)
    output, state = self.gru(x)
    x = self.fc1(output)
    x = tf.reshape(x, (-1, x.shape[2]))
    x = self.fc2(x)

    return x, state, attention_weights

  def reset_state(self, batch_size):
    return tf.zeros((batch_size, self.units))

# %%
encoder = CNN_Encoder(embedding_dim)
decoder = RNN_Decoder(embedding_dim, units, tokenizer.vocabulary_size())

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')


def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %%
checkpoint_path = "./checkpoints/train"
ckpt = tf.train.Checkpoint(encoder=encoder,
                           decoder=decoder,
                           optimizer=optimizer)
ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# %%
start_epoch = 0
if ckpt_manager.latest_checkpoint:
  start_epoch = int(ckpt_manager.latest_checkpoint.split('-')[-1])
  # restoring the latest checkpoint in checkpoint_path
  ckpt.restore(ckpt_manager.latest_checkpoint)

# %%
loss_plot = []

# %%
@tf.function
def train_step(img_tensor, target):
  loss = 0


  hidden = decoder.reset_state(batch_size=target.shape[0])

  dec_input = tf.expand_dims([word_to_index('<start>')] * target.shape[0], 1)

  with tf.GradientTape() as tape:
      features = encoder(img_tensor)

      for i in range(1, target.shape[1]):
          # passing the features through the decoder
          predictions, hidden, _ = decoder(dec_input, features, hidden)

          loss += loss_function(target[:, i], predictions)

          # using teacher forcing
          dec_input = tf.expand_dims(target[:, i], 1)

  total_loss = (loss / int(target.shape[1]))

  trainable_variables = encoder.trainable_variables + decoder.trainable_variables

  gradients = tape.gradient(loss, trainable_variables)

  optimizer.apply_gradients(zip(gradients, trainable_variables))

  return loss, total_loss

# %%
EPOCHS = 20

for epoch in range(start_epoch, EPOCHS):
    start = time.time()
    total_loss = 0

    for (batch, (img_tensor, target)) in enumerate(dataset):
        batch_loss, t_loss = train_step(img_tensor, target)
        total_loss += t_loss

        if batch % 100 == 0:
            average_batch_loss = batch_loss.numpy()/int(target.shape[1])
            print(f'Epoch {epoch+1} Batch {batch} Loss {average_batch_loss:.4f}')
    # storing the epoch end loss value to plot later
    loss_plot.append(total_loss / num_steps)

    if epoch % 5 == 0:
      ckpt_manager.save()

    print(f'Epoch {epoch+1} Loss {total_loss/num_steps:.6f}')
    print(f'Time taken for 1 epoch {time.time()-start:.2f} sec\n')
# Out:
# Epoch 1 Batch 0 Loss 2.0663
# Epoch 1 Batch 100 Loss 1.2484
# Epoch 1 Batch 200 Loss 1.0419
# Epoch 1 Batch 300 Loss 0.9986
# Epoch 1 Batch 400 Loss 0.8623
# Epoch 1 Batch 500 Loss 0.7955
# Epoch 1 Batch 600 Loss 0.8446
# Epoch 1 Batch 700 Loss 0.7927
# Epoch 1 Batch 800 Loss 0.7705
# Epoch 1 Batch 900 Loss 0.7655
# Epoch 1 Batch 1000 Loss 0.8298
# Epoch 1 Batch 1100 Loss 0.7651
# Epoch 1 Batch 1200 Loss 0.6687
# Epoch 1 Batch 1300 Loss 0.7195
# Epoch 1 Batch 1400 Loss 0.6260
# Epoch 1 Batch 1500 Loss 0.7132
# Epoch 1 Batch 1600 Loss 0.7109
# Epoch 1 Batch 1700 Loss 0.6783
# Epoch 1 Batch 1800 Loss 0.6833
# Epoch 1 Batch 1900 Loss 0.6985
# Epoch 1 Batch 2000 Loss 0.6769
# Epoch 1 Batch 2100 Loss 0.6741
# Epoch 1 Batch 2200 Loss 0.6169
# Epoch 1 Batch 2300 Loss 0.6661
# Epoch 1 Batch 2400 Loss 0.6679
# Epoch 1 Batch 2500 Loss 0.6510
# Epoch 1 Batch 2600 Loss 0.6370
# Epoch 1 Batch 2700 Loss 0.7120
# Epoch 1 Batch 2800 Loss 0.6243
# Epoch 1 Batch 2900 Loss 0.6885
# Epoch 1 Batch 3000 Loss 0.7174
# Epoch 1 Batch 3100 Loss 0.6394
# Epoch 1 Batch 3200 Loss 0.6078
# Epoch 1 Batch 3300 Loss 0.6714
# Epoch 1 Batch 3400 Loss 0.7323
# Epoch 1 Batch 3500 Loss 0.6414
# Epoch 1 Batch 3600 Loss 0.6029
# Epoch 1 Batch 3700 Loss 0.6410
# Epoch 1 Batch 3800 Loss 0.6407
# Epoch 1 Batch 3900 Loss 0.5991
# Epoch 1 Batch 4000 Loss 0.7136
# Epoch 1 Batch 4100 Loss 0.6038
# Epoch 1 Batch 4200 Loss 0.6058
# Epoch 1 Batch 4300 Loss 0.5656
# Epoch 1 Batch 4400 Loss 0.7036
# Epoch 1 Batch 4500 Loss 0.6899
# Epoch 1 Batch 4600 Loss 0.6148
# Epoch 1 Batch 4700 Loss 0.5602
# Epoch 1 Batch 4800 Loss 0.6613
# Epoch 1 Batch 4900 Loss 0.5937
# Epoch 1 Batch 5000 Loss 0.6703
# Epoch 1 Batch 5100 Loss 0.6242
# Epoch 1 Batch 5200 Loss 0.6112
# Epoch 1 Batch 5300 Loss 0.5666
# Epoch 1 Batch 5400 Loss 0.5881
# Epoch 1 Batch 5500 Loss 0.6036
# Epoch 1 Batch 5600 Loss 0.6430
# Epoch 1 Batch 5700 Loss 0.6463
# Epoch 1 Batch 5800 Loss 0.6230
# Epoch 1 Batch 5900 Loss 0.6558
# Epoch 1 Batch 6000 Loss 0.6278
# Epoch 1 Batch 6100 Loss 0.6405
# Epoch 1 Batch 6200 Loss 0.6073
# Epoch 1 Batch 6300 Loss 0.6037
# Epoch 1 Batch 6400 Loss 0.5567
# Epoch 1 Batch 6500 Loss 0.5913
# Epoch 1 Batch 6600 Loss 0.6045
# Epoch 1 Batch 6700 Loss 0.6418
# Epoch 1 Batch 6800 Loss 0.7304
# Epoch 1 Batch 6900 Loss 0.5997
# Epoch 1 Batch 7000 Loss 0.7476
# Epoch 1 Batch 7100 Loss 0.6415
# Epoch 1 Batch 7200 Loss 0.6516
# Epoch 1 Batch 7300 Loss 0.5973
# Epoch 1 Loss 0.680652
# Time taken for 1 epoch 2008.54 sec
#
# Epoch 2 Batch 0 Loss 0.6223
# Epoch 2 Batch 100 Loss 0.6415
# Epoch 2 Batch 200 Loss 0.5842
# Epoch 2 Batch 300 Loss 0.6956
# Epoch 2 Batch 400 Loss 0.5977
# Epoch 2 Batch 500 Loss 0.6556
# Epoch 2 Batch 600 Loss 0.5978
# Epoch 2 Batch 700 Loss 0.6317
# Epoch 2 Batch 800 Loss 0.5944
# Epoch 2 Batch 900 Loss 0.6644
# Epoch 2 Batch 1000 Loss 0.5642
# Epoch 2 Batch 1100 Loss 0.6046
# Epoch 2 Batch 1200 Loss 0.5548
# Epoch 2 Batch 1300 Loss 0.6507
# Epoch 2 Batch 1400 Loss 0.6103
# Epoch 2 Batch 1500 Loss 0.5928
# Epoch 2 Batch 1600 Loss 0.6355
# Epoch 2 Batch 1700 Loss 0.6124
# Epoch 2 Batch 1800 Loss 0.6288
# Epoch 2 Batch 1900 Loss 0.5571
# Epoch 2 Batch 2000 Loss 0.6694
# Epoch 2 Batch 2100 Loss 0.5938
# Epoch 2 Batch 2200 Loss 0.6398
# Epoch 2 Batch 2300 Loss 0.6279
# Epoch 2 Batch 2400 Loss 0.6353
# Epoch 2 Batch 2500 Loss 0.6342
# Epoch 2 Batch 2600 Loss 0.6183
# Epoch 2 Batch 2700 Loss 0.5828
# Epoch 2 Batch 2800 Loss 0.6160
# Epoch 2 Batch 2900 Loss 0.6006
# Epoch 2 Batch 3000 Loss 0.5911
# Epoch 2 Batch 3100 Loss 0.6493
# Epoch 2 Batch 3200 Loss 0.5235
# Epoch 2 Batch 3300 Loss 0.6190
# Epoch 2 Batch 3400 Loss 0.6126
# Epoch 2 Batch 3500 Loss 0.5688
# Epoch 2 Batch 3600 Loss 0.5511
# Epoch 2 Batch 3700 Loss 0.5766
# Epoch 2 Batch 3800 Loss 0.5606
# Epoch 2 Batch 3900 Loss 0.5543
# Epoch 2 Batch 4000 Loss 0.5918
# Epoch 2 Batch 4100 Loss 0.6326
# Epoch 2 Batch 4200 Loss 0.6498
# Epoch 2 Batch 4300 Loss 0.5698
# Epoch 2 Batch 4400 Loss 0.5835
# Epoch 2 Batch 4500 Loss 0.6028
# Epoch 2 Batch 4600 Loss 0.5748
# Epoch 2 Batch 4700 Loss 0.6160
# Epoch 2 Batch 4800 Loss 0.6772
# Epoch 2 Batch 4900 Loss 0.5884
# Epoch 2 Batch 5000 Loss 0.5991
# Epoch 2 Batch 5100 Loss 0.6063
# Epoch 2 Batch 5200 Loss 0.5922
# Epoch 2 Batch 5300 Loss 0.6041
# Epoch 2 Batch 5400 Loss 0.5297
# Epoch 2 Batch 5500 Loss 0.6000
# Epoch 2 Batch 5600 Loss 0.5921
# Epoch 2 Batch 5700 Loss 0.6050
# Epoch 2 Batch 5800 Loss 0.6108
# Epoch 2 Batch 5900 Loss 0.6312
# Epoch 2 Batch 6000 Loss 0.5841
# Epoch 2 Batch 6100 Loss 0.5985
# Epoch 2 Batch 6200 Loss 0.5850
# Epoch 2 Batch 6300 Loss 0.5364
# Epoch 2 Batch 6400 Loss 0.5720
# Epoch 2 Batch 6500 Loss 0.5641
# Epoch 2 Batch 6600 Loss 0.5588
# Epoch 2 Batch 6700 Loss 0.5887
# Epoch 2 Batch 6800 Loss 0.5960
# Epoch 2 Batch 6900 Loss 0.4989
# Epoch 2 Batch 7000 Loss 0.5707
# Epoch 2 Batch 7100 Loss 0.6099
# Epoch 2 Batch 7200 Loss 0.5877
# Epoch 2 Batch 7300 Loss 0.6493
# Epoch 2 Loss 0.593051
# Time taken for 1 epoch 1920.23 sec
#
# Epoch 3 Batch 0 Loss 0.5618
# Epoch 3 Batch 100 Loss 0.6075
# Epoch 3 Batch 200 Loss 0.5359
# Epoch 3 Batch 300 Loss 0.5377
# Epoch 3 Batch 400 Loss 0.5576
# Epoch 3 Batch 500 Loss 0.5644
# Epoch 3 Batch 600 Loss 0.5931
# Epoch 3 Batch 700 Loss 0.6037
# Epoch 3 Batch 800 Loss 0.6365
# Epoch 3 Batch 900 Loss 0.5689
# Epoch 3 Batch 1000 Loss 0.5736
# Epoch 3 Batch 1100 Loss 0.6196
# Epoch 3 Batch 1200 Loss 0.5468
# Epoch 3 Batch 1300 Loss 0.5453
# Epoch 3 Batch 1400 Loss 0.5170
# Epoch 3 Batch 1500 Loss 0.5480
# Epoch 3 Batch 1600 Loss 0.5997
# Epoch 3 Batch 1700 Loss 0.5699
# Epoch 3 Batch 1800 Loss 0.5398
# Epoch 3 Batch 1900 Loss 0.5772
# Epoch 3 Batch 2000 Loss 0.5623
# Epoch 3 Batch 2100 Loss 0.5511
# Epoch 3 Batch 2200 Loss 0.5592
# Epoch 3 Batch 2300 Loss 0.5289
# Epoch 3 Batch 2400 Loss 0.6229
# Epoch 3 Batch 2500 Loss 0.6181
# Epoch 3 Batch 2600 Loss 0.6451
# Epoch 3 Batch 2700 Loss 0.6620
# Epoch 3 Batch 2800 Loss 0.5325
# Epoch 3 Batch 2900 Loss 0.5585
# Epoch 3 Batch 3000 Loss 0.5582
# Epoch 3 Batch 3100 Loss 0.5176
# Epoch 3 Batch 3200 Loss 0.5367
# Epoch 3 Batch 3300 Loss 0.5878
# Epoch 3 Batch 3400 Loss 0.6426
# Epoch 3 Batch 3500 Loss 0.5446
# Epoch 3 Batch 3600 Loss 0.5433
# Epoch 3 Batch 3700 Loss 0.6198
# Epoch 3 Batch 3800 Loss 0.5145
# Epoch 3 Batch 3900 Loss 0.5831
# Epoch 3 Batch 4000 Loss 0.5065
# Epoch 3 Batch 4100 Loss 0.5808
# Epoch 3 Batch 4200 Loss 0.5343
# Epoch 3 Batch 4300 Loss 0.5471
# Epoch 3 Batch 4400 Loss 0.5534
# Epoch 3 Batch 4500 Loss 0.5614
# Epoch 3 Batch 4600 Loss 0.5373
# Epoch 3 Batch 4700 Loss 0.5356
# Epoch 3 Batch 4800 Loss 0.5550
# Epoch 3 Batch 4900 Loss 0.4718
# Epoch 3 Batch 5000 Loss 0.5279
# Epoch 3 Batch 5100 Loss 0.5739
# Epoch 3 Batch 5200 Loss 0.5598
# Epoch 3 Batch 5300 Loss 0.6347
# Epoch 3 Batch 5400 Loss 0.5381
# Epoch 3 Batch 5500 Loss 0.5190
# Epoch 3 Batch 5600 Loss 0.5245
# Epoch 3 Batch 5700 Loss 0.5868
# Epoch 3 Batch 5800 Loss 0.5175
# Epoch 3 Batch 5900 Loss 0.5268
# Epoch 3 Batch 6000 Loss 0.5801
# Epoch 3 Batch 6100 Loss 0.5594
# Epoch 3 Batch 6200 Loss 0.5332
# Epoch 3 Batch 6300 Loss 0.5746
# Epoch 3 Batch 6400 Loss 0.5080
# Epoch 3 Batch 6500 Loss 0.5981
# Epoch 3 Batch 6600 Loss 0.5680
# Epoch 3 Batch 6700 Loss 0.5476
# Epoch 3 Batch 6800 Loss 0.5396
# Epoch 3 Batch 6900 Loss 0.5681
# Epoch 3 Batch 7000 Loss 0.5140
# Epoch 3 Batch 7100 Loss 0.5499
# Epoch 3 Batch 7200 Loss 0.5724
# Epoch 3 Batch 7300 Loss 0.5117
# Epoch 3 Loss 0.564934
# Time taken for 1 epoch 1919.78 sec
#
# Epoch 4 Batch 0 Loss 0.5217
# Epoch 4 Batch 100 Loss 0.5185
# Epoch 4 Batch 200 Loss 0.5352
# Epoch 4 Batch 300 Loss 0.5367
# Epoch 4 Batch 400 Loss 0.5930
# Epoch 4 Batch 500 Loss 0.5524
# Epoch 4 Batch 600 Loss 0.6075
# Epoch 4 Batch 700 Loss 0.5817
# Epoch 4 Batch 800 Loss 0.5451
# Epoch 4 Batch 900 Loss 0.6605
# Epoch 4 Batch 1000 Loss 0.5444
# Epoch 4 Batch 1100 Loss 0.5536
# Epoch 4 Batch 1200 Loss 0.4740
# Epoch 4 Batch 1300 Loss 0.6337
# Epoch 4 Batch 1400 Loss 0.4964
# Epoch 4 Batch 1500 Loss 0.6060
# Epoch 4 Batch 1600 Loss 0.5201
# Epoch 4 Batch 1700 Loss 0.6033
# Epoch 4 Batch 1800 Loss 0.5415
# Epoch 4 Batch 1900 Loss 0.5397
# Epoch 4 Batch 2000 Loss 0.5360
# Epoch 4 Batch 2100 Loss 0.5996
# Epoch 4 Batch 2200 Loss 0.5137
# Epoch 4 Batch 2300 Loss 0.6215
# Epoch 4 Batch 2400 Loss 0.5287
# Epoch 4 Batch 2500 Loss 0.5688
# Epoch 4 Batch 2600 Loss 0.5591
# Epoch 4 Batch 2700 Loss 0.5514
# Epoch 4 Batch 2800 Loss 0.5562
# Epoch 4 Batch 2900 Loss 0.5844
# Epoch 4 Batch 3000 Loss 0.5342
# Epoch 4 Batch 3100 Loss 0.5449
# Epoch 4 Batch 3200 Loss 0.5196
# Epoch 4 Batch 3300 Loss 0.5582
# Epoch 4 Batch 3400 Loss 0.5074
# Epoch 4 Batch 3500 Loss 0.5457
# Epoch 4 Batch 3600 Loss 0.5061
# Epoch 4 Batch 3700 Loss 0.5689
# Epoch 4 Batch 3800 Loss 0.4976
# Epoch 4 Batch 3900 Loss 0.5828
# Epoch 4 Batch 4000 Loss 0.5531
# Epoch 4 Batch 4100 Loss 0.5837
# Epoch 4 Batch 4200 Loss 0.6189
# Epoch 4 Batch 4300 Loss 0.6145
# Epoch 4 Batch 4400 Loss 0.5675
# Epoch 4 Batch 4500 Loss 0.5279
# Epoch 4 Batch 4600 Loss 0.4845
# Epoch 4 Batch 4700 Loss 0.5024
# Epoch 4 Batch 4800 Loss 0.4917
# Epoch 4 Batch 4900 Loss 0.5661
# Epoch 4 Batch 5000 Loss 0.5784
# Epoch 4 Batch 5100 Loss 0.5673
# Epoch 4 Batch 5200 Loss 0.5258
# Epoch 4 Batch 5300 Loss 0.4987
# Epoch 4 Batch 5400 Loss 0.5285
# Epoch 4 Batch 5500 Loss 0.5527
# Epoch 4 Batch 5600 Loss 0.5623
# Epoch 4 Batch 5700 Loss 0.5322
# Epoch 4 Batch 5800 Loss 0.5519
# Epoch 4 Batch 5900 Loss 0.6216
# Epoch 4 Batch 6000 Loss 0.4978
# Epoch 4 Batch 6100 Loss 0.5501
# Epoch 4 Batch 6200 Loss 0.5228
# Epoch 4 Batch 6300 Loss 0.5469
# Epoch 4 Batch 6400 Loss 0.5204
# Epoch 4 Batch 6500 Loss 0.5048
# Epoch 4 Batch 6600 Loss 0.5574
# Epoch 4 Batch 6700 Loss 0.5679
# Epoch 4 Batch 6800 Loss 0.5366
# Epoch 4 Batch 6900 Loss 0.5776
# Epoch 4 Batch 7000 Loss 0.5580
# Epoch 4 Batch 7100 Loss 0.5148
# Epoch 4 Batch 7200 Loss 0.4908
# Epoch 4 Batch 7300 Loss 0.4841
# Epoch 4 Loss 0.545735
# Time taken for 1 epoch 1922.47 sec
#
# Epoch 5 Batch 0 Loss 0.5503
# Epoch 5 Batch 100 Loss 0.5551
# Epoch 5 Batch 200 Loss 0.5533
# Epoch 5 Batch 300 Loss 0.5525
# Epoch 5 Batch 400 Loss 0.5280
# Epoch 5 Batch 500 Loss 0.5071
# Epoch 5 Batch 600 Loss 0.5192
# Epoch 5 Batch 700 Loss 0.6315
# Epoch 5 Batch 800 Loss 0.5497
# Epoch 5 Batch 900 Loss 0.5544
# Epoch 5 Batch 1000 Loss 0.4926
# Epoch 5 Batch 1100 Loss 0.5457
# Epoch 5 Batch 1200 Loss 0.5140
# Epoch 5 Batch 1300 Loss 0.4779
# Epoch 5 Batch 1400 Loss 0.5116
# Epoch 5 Batch 1500 Loss 0.4976
# Epoch 5 Batch 1600 Loss 0.5177
# Epoch 5 Batch 1700 Loss 0.5428
# Epoch 5 Batch 1800 Loss 0.5109
# Epoch 5 Batch 1900 Loss 0.6056
# Epoch 5 Batch 2000 Loss 0.5597
# Epoch 5 Batch 2100 Loss 0.5427
# Epoch 5 Batch 2200 Loss 0.5261
# Epoch 5 Batch 2300 Loss 0.5770
# Epoch 5 Batch 2400 Loss 0.5643
# Epoch 5 Batch 2500 Loss 0.5835
# Epoch 5 Batch 2600 Loss 0.4673
# Epoch 5 Batch 2700 Loss 0.5171
# Epoch 5 Batch 2800 Loss 0.4814
# Epoch 5 Batch 2900 Loss 0.4853
# Epoch 5 Batch 3000 Loss 0.5075
# Epoch 5 Batch 3100 Loss 0.5664
# Epoch 5 Batch 3200 Loss 0.4918
# Epoch 5 Batch 3300 Loss 0.5382
# Epoch 5 Batch 3400 Loss 0.5433
# Epoch 5 Batch 3500 Loss 0.4899
# Epoch 5 Batch 3600 Loss 0.5393
# Epoch 5 Batch 3700 Loss 0.6203
# Epoch 5 Batch 3800 Loss 0.4768
# Epoch 5 Batch 3900 Loss 0.5273
# Epoch 5 Batch 4000 Loss 0.4714
# Epoch 5 Batch 4100 Loss 0.5530
# Epoch 5 Batch 4200 Loss 0.5196
# Epoch 5 Batch 4300 Loss 0.6339
# Epoch 5 Batch 4400 Loss 0.5773
# Epoch 5 Batch 4500 Loss 0.5226
# Epoch 5 Batch 4600 Loss 0.5576
# Epoch 5 Batch 4700 Loss 0.4970
# Epoch 5 Batch 4800 Loss 0.5137
# Epoch 5 Batch 4900 Loss 0.4862
# Epoch 5 Batch 5000 Loss 0.4677
# Epoch 5 Batch 5100 Loss 0.5068
# Epoch 5 Batch 5200 Loss 0.5476
# Epoch 5 Batch 5300 Loss 0.4923
# Epoch 5 Batch 5400 Loss 0.5248
# Epoch 5 Batch 5500 Loss 0.5666
# Epoch 5 Batch 5600 Loss 0.5786
# Epoch 5 Batch 5700 Loss 0.5968
# Epoch 5 Batch 5800 Loss 0.5337
# Epoch 5 Batch 5900 Loss 0.5455
# Epoch 5 Batch 6000 Loss 0.6059
# Epoch 5 Batch 6100 Loss 0.5622
# Epoch 5 Batch 6200 Loss 0.5240
# Epoch 5 Batch 6300 Loss 0.5333
# Epoch 5 Batch 6400 Loss 0.5169
# Epoch 5 Batch 6500 Loss 0.5495
# Epoch 5 Batch 6600 Loss 0.4978
# Epoch 5 Batch 6700 Loss 0.4747
# Epoch 5 Batch 6800 Loss 0.5353
# Epoch 5 Batch 6900 Loss 0.5807
# Epoch 5 Batch 7000 Loss 0.5301
# Epoch 5 Batch 7100 Loss 0.5059
# Epoch 5 Batch 7200 Loss 0.4667
# Epoch 5 Batch 7300 Loss 0.5348
# Epoch 5 Loss 0.530159
# Time taken for 1 epoch 1949.89 sec
#
# Epoch 6 Batch 0 Loss 0.5026
# Epoch 6 Batch 100 Loss 0.5209
# Epoch 6 Batch 200 Loss 0.5017
# Epoch 6 Batch 300 Loss 0.5136
# Epoch 6 Batch 400 Loss 0.6148
# Epoch 6 Batch 500 Loss 0.5008
# Epoch 6 Batch 600 Loss 0.5150
# Epoch 6 Batch 700 Loss 0.5299
# Epoch 6 Batch 800 Loss 0.4821
# Epoch 6 Batch 900 Loss 0.5117
# Epoch 6 Batch 1000 Loss 0.4847
# Epoch 6 Batch 1100 Loss 0.5210
# Epoch 6 Batch 1200 Loss 0.5128
# Epoch 6 Batch 1300 Loss 0.5357
# Epoch 6 Batch 1400 Loss 0.5556
# Epoch 6 Batch 1500 Loss 0.5412
# Epoch 6 Batch 1600 Loss 0.5015
# Epoch 6 Batch 1700 Loss 0.5530
# Epoch 6 Batch 1800 Loss 0.5336
# Epoch 6 Batch 1900 Loss 0.5241
# Epoch 6 Batch 2000 Loss 0.5154
# Epoch 6 Batch 2100 Loss 0.5213
# Epoch 6 Batch 2200 Loss 0.4691
# Epoch 6 Batch 2300 Loss 0.5104
# Epoch 6 Batch 2400 Loss 0.4802
# Epoch 6 Batch 2500 Loss 0.5345
# Epoch 6 Batch 2600 Loss 0.4926
# Epoch 6 Batch 2700 Loss 0.5004
# Epoch 6 Batch 2800 Loss 0.5062
# Epoch 6 Batch 2900 Loss 0.5338
# Epoch 6 Batch 3000 Loss 0.5327
# Epoch 6 Batch 3100 Loss 0.5260
# Epoch 6 Batch 3200 Loss 0.5337
# Epoch 6 Batch 3300 Loss 0.4575
# Epoch 6 Batch 3400 Loss 0.5407
# Epoch 6 Batch 3500 Loss 0.5131
# Epoch 6 Batch 3600 Loss 0.5584
# Epoch 6 Batch 3700 Loss 0.5097
# Epoch 6 Batch 3800 Loss 0.5226
# Epoch 6 Batch 3900 Loss 0.5425
# Epoch 6 Batch 4000 Loss 0.5167
# Epoch 6 Batch 4100 Loss 0.5450
# Epoch 6 Batch 4200 Loss 0.4797
# Epoch 6 Batch 4300 Loss 0.4947
# Epoch 6 Batch 4400 Loss 0.5476
# Epoch 6 Batch 4500 Loss 0.5319
# Epoch 6 Batch 4600 Loss 0.4849
# Epoch 6 Batch 4700 Loss 0.5387
# Epoch 6 Batch 4800 Loss 0.5164
# Epoch 6 Batch 4900 Loss 0.5506
# Epoch 6 Batch 5000 Loss 0.5272
# Epoch 6 Batch 5100 Loss 0.5339
# Epoch 6 Batch 5200 Loss 0.5252
# Epoch 6 Batch 5300 Loss 0.5166
# Epoch 6 Batch 5400 Loss 0.5008
# Epoch 6 Batch 5500 Loss 0.5349
# Epoch 6 Batch 5600 Loss 0.5141
# Epoch 6 Batch 5700 Loss 0.5812
# Epoch 6 Batch 5800 Loss 0.5390
# Epoch 6 Batch 5900 Loss 0.4641
# Epoch 6 Batch 6000 Loss 0.4662
# Epoch 6 Batch 6100 Loss 0.5098
# Epoch 6 Batch 6200 Loss 0.4980
# Epoch 6 Batch 6300 Loss 0.5277
# Epoch 6 Batch 6400 Loss 0.5133
# Epoch 6 Batch 6500 Loss 0.4880
# Epoch 6 Batch 6600 Loss 0.5012
# Epoch 6 Batch 6700 Loss 0.5036
# Epoch 6 Batch 6800 Loss 0.4783
# Epoch 6 Batch 6900 Loss 0.4892
# Epoch 6 Batch 7000 Loss 0.4936
# Epoch 6 Batch 7100 Loss 0.5203
# Epoch 6 Batch 7200 Loss 0.5380
# Epoch 6 Batch 7300 Loss 0.4867
# Epoch 6 Loss 0.516915
# Time taken for 1 epoch 1974.33 sec
#
# Epoch 7 Batch 0 Loss 0.5095
# Epoch 7 Batch 100 Loss 0.5232
# Epoch 7 Batch 200 Loss 0.5191
# Epoch 7 Batch 300 Loss 0.5103
# Epoch 7 Batch 400 Loss 0.5091
# Epoch 7 Batch 500 Loss 0.5095
# Epoch 7 Batch 600 Loss 0.4617
# Epoch 7 Batch 700 Loss 0.5651
# Epoch 7 Batch 800 Loss 0.4984
# Epoch 7 Batch 900 Loss 0.5331
# Epoch 7 Batch 1000 Loss 0.5252
# Epoch 7 Batch 1100 Loss 0.5210
# Epoch 7 Batch 1200 Loss 0.4729
# Epoch 7 Batch 1300 Loss 0.5471
# Epoch 7 Batch 1400 Loss 0.5379
# Epoch 7 Batch 1500 Loss 0.4890
# Epoch 7 Batch 1600 Loss 0.5178
# Epoch 7 Batch 1700 Loss 0.5303
# Epoch 7 Batch 1800 Loss 0.5487
# Epoch 7 Batch 1900 Loss 0.5220
# Epoch 7 Batch 2000 Loss 0.5198
# Epoch 7 Batch 2100 Loss 0.5037
# Epoch 7 Batch 2200 Loss 0.5539
# Epoch 7 Batch 2300 Loss 0.5157
# Epoch 7 Batch 2400 Loss 0.5061
# Epoch 7 Batch 2500 Loss 0.5174
# Epoch 7 Batch 2600 Loss 0.5401
# Epoch 7 Batch 2700 Loss 0.5158
# Epoch 7 Batch 2800 Loss 0.5150
# Epoch 7 Batch 2900 Loss 0.4968
# Epoch 7 Batch 3000 Loss 0.5946
# Epoch 7 Batch 3100 Loss 0.5204
# Epoch 7 Batch 3200 Loss 0.4757
# Epoch 7 Batch 3300 Loss 0.5441
# Epoch 7 Batch 3400 Loss 0.5197
# Epoch 7 Batch 3500 Loss 0.4597
# Epoch 7 Batch 3600 Loss 0.4832
# Epoch 7 Batch 3700 Loss 0.5197
# Epoch 7 Batch 3800 Loss 0.5508
# Epoch 7 Batch 3900 Loss 0.4199
# Epoch 7 Batch 4000 Loss 0.5219
# Epoch 7 Batch 4100 Loss 0.5511
# Epoch 7 Batch 4200 Loss 0.4938
# Epoch 7 Batch 4300 Loss 0.5368
# Epoch 7 Batch 4400 Loss 0.5044
# Epoch 7 Batch 4500 Loss 0.4577
# Epoch 7 Batch 4600 Loss 0.5202
# Epoch 7 Batch 4700 Loss 0.5334
# Epoch 7 Batch 4800 Loss 0.4555
# Epoch 7 Batch 4900 Loss 0.5288
# Epoch 7 Batch 5000 Loss 0.4769
# Epoch 7 Batch 5100 Loss 0.4721
# Epoch 7 Batch 5200 Loss 0.4828
# Epoch 7 Batch 5300 Loss 0.4883
# Epoch 7 Batch 5400 Loss 0.4717
# Epoch 7 Batch 5500 Loss 0.5739
# Epoch 7 Batch 5600 Loss 0.5197
# Epoch 7 Batch 5700 Loss 0.5158
# Epoch 7 Batch 5800 Loss 0.5520
# Epoch 7 Batch 5900 Loss 0.5173
# Epoch 7 Batch 6000 Loss 0.4833
# Epoch 7 Batch 6100 Loss 0.4717
# Epoch 7 Batch 6200 Loss 0.4729
# Epoch 7 Batch 6300 Loss 0.4996
# Epoch 7 Batch 6400 Loss 0.5080
# Epoch 7 Batch 6500 Loss 0.5130
# Epoch 7 Batch 6600 Loss 0.5270
# Epoch 7 Batch 6700 Loss 0.5306
# Epoch 7 Batch 6800 Loss 0.4874
# Epoch 7 Batch 6900 Loss 0.5175
# Epoch 7 Batch 7000 Loss 0.5136
# Epoch 7 Batch 7100 Loss 0.4898
# Epoch 7 Batch 7200 Loss 0.5309
# Epoch 7 Batch 7300 Loss 0.5289
# Epoch 7 Loss 0.505912
# Time taken for 1 epoch 1976.30 sec
#
# Epoch 8 Batch 0 Loss 0.4904
# Epoch 8 Batch 100 Loss 0.5485
# Epoch 8 Batch 200 Loss 0.4921
# Epoch 8 Batch 300 Loss 0.5327
# Epoch 8 Batch 400 Loss 0.5025
# Epoch 8 Batch 500 Loss 0.4920
# Epoch 8 Batch 600 Loss 0.4607
# Epoch 8 Batch 700 Loss 0.5299
# Epoch 8 Batch 800 Loss 0.4990
# Epoch 8 Batch 900 Loss 0.5422
# Epoch 8 Batch 1000 Loss 0.5224
# Epoch 8 Batch 1100 Loss 0.5374
# Epoch 8 Batch 1200 Loss 0.4744
# Epoch 8 Batch 1300 Loss 0.4914
# Epoch 8 Batch 1400 Loss 0.5076
# Epoch 8 Batch 1500 Loss 0.4825
# Epoch 8 Batch 1600 Loss 0.4902
# Epoch 8 Batch 1700 Loss 0.5542
# Epoch 8 Batch 1800 Loss 0.5317
# Epoch 8 Batch 1900 Loss 0.5097
# Epoch 8 Batch 2000 Loss 0.4810
# Epoch 8 Batch 2100 Loss 0.5306
# Epoch 8 Batch 2200 Loss 0.4978
# Epoch 8 Batch 2300 Loss 0.5307
# Epoch 8 Batch 2400 Loss 0.4751
# Epoch 8 Batch 2500 Loss 0.5121
# Epoch 8 Batch 2600 Loss 0.5046
# Epoch 8 Batch 2700 Loss 0.5424
# Epoch 8 Batch 2800 Loss 0.5587
# Epoch 8 Batch 2900 Loss 0.4774
# Epoch 8 Batch 3000 Loss 0.5075
# Epoch 8 Batch 3100 Loss 0.5472
# Epoch 8 Batch 3200 Loss 0.4818
# Epoch 8 Batch 3300 Loss 0.5107
# Epoch 8 Batch 3400 Loss 0.4915
# Epoch 8 Batch 3500 Loss 0.5085
# Epoch 8 Batch 3600 Loss 0.5185
# Epoch 8 Batch 3700 Loss 0.4722
# Epoch 8 Batch 3800 Loss 0.5211
# Epoch 8 Batch 3900 Loss 0.4880
# Epoch 8 Batch 4000 Loss 0.5238
# Epoch 8 Batch 4100 Loss 0.5191
# Epoch 8 Batch 4200 Loss 0.4897
# Epoch 8 Batch 4300 Loss 0.4443
# Epoch 8 Batch 4400 Loss 0.4981
# Epoch 8 Batch 4500 Loss 0.4860
# Epoch 8 Batch 4600 Loss 0.5083
# Epoch 8 Batch 4700 Loss 0.4348
# Epoch 8 Batch 4800 Loss 0.4491
# Epoch 8 Batch 4900 Loss 0.4729
# Epoch 8 Batch 5000 Loss 0.4471
# Epoch 8 Batch 5100 Loss 0.4992
# Epoch 8 Batch 5200 Loss 0.4731
# Epoch 8 Batch 5300 Loss 0.4494
# Epoch 8 Batch 5400 Loss 0.5502
# Epoch 8 Batch 5500 Loss 0.4902
# Epoch 8 Batch 5600 Loss 0.4944
# Epoch 8 Batch 5700 Loss 0.4396
# Epoch 8 Batch 5800 Loss 0.5532
# Epoch 8 Batch 5900 Loss 0.4537
# Epoch 8 Batch 6000 Loss 0.4760
# Epoch 8 Batch 6100 Loss 0.5333
# Epoch 8 Batch 6200 Loss 0.4834
# Epoch 8 Batch 6300 Loss 0.4794
# Epoch 8 Batch 6400 Loss 0.5184
# Epoch 8 Batch 6500 Loss 0.5345
# Epoch 8 Batch 6600 Loss 0.4788
# Epoch 8 Batch 6700 Loss 0.5268
# Epoch 8 Batch 6800 Loss 0.4901
# Epoch 8 Batch 6900 Loss 0.5433
# Epoch 8 Batch 7000 Loss 0.4956
# Epoch 8 Batch 7100 Loss 0.5207
# Epoch 8 Batch 7200 Loss 0.5075
# Epoch 8 Batch 7300 Loss 0.4585
# Epoch 8 Loss 0.496184
# Time taken for 1 epoch 1973.87 sec
#
# Epoch 9 Batch 0 Loss 0.5206
# Epoch 9 Batch 100 Loss 0.4939
# Epoch 9 Batch 200 Loss 0.5171
# Epoch 9 Batch 300 Loss 0.4838
# Epoch 9 Batch 400 Loss 0.5098
# Epoch 9 Batch 500 Loss 0.5095
# Epoch 9 Batch 600 Loss 0.4970
# Epoch 9 Batch 700 Loss 0.4723
# Epoch 9 Batch 800 Loss 0.4956
# Epoch 9 Batch 900 Loss 0.4993
# Epoch 9 Batch 1000 Loss 0.5219
# Epoch 9 Batch 1100 Loss 0.5358
# Epoch 9 Batch 1200 Loss 0.4963
# Epoch 9 Batch 1300 Loss 0.5210
# Epoch 9 Batch 1400 Loss 0.4954
# Epoch 9 Batch 1500 Loss 0.4773
# Epoch 9 Batch 1600 Loss 0.4875
# Epoch 9 Batch 1700 Loss 0.4955
# Epoch 9 Batch 1800 Loss 0.5257
# Epoch 9 Batch 1900 Loss 0.5801
# Epoch 9 Batch 2000 Loss 0.4510
# Epoch 9 Batch 2100 Loss 0.4532
# Epoch 9 Batch 2200 Loss 0.4976
# Epoch 9 Batch 2300 Loss 0.4916
# Epoch 9 Batch 2400 Loss 0.4865
# Epoch 9 Batch 2500 Loss 0.5066
# Epoch 9 Batch 2600 Loss 0.4416
# Epoch 9 Batch 2700 Loss 0.4777
# Epoch 9 Batch 2800 Loss 0.4897
# Epoch 9 Batch 2900 Loss 0.5266
# Epoch 9 Batch 3000 Loss 0.5334
# Epoch 9 Batch 3100 Loss 0.5387
# Epoch 9 Batch 3200 Loss 0.4947
# Epoch 9 Batch 3300 Loss 0.4494
# Epoch 9 Batch 3400 Loss 0.4775
# Epoch 9 Batch 3500 Loss 0.5072
# Epoch 9 Batch 3600 Loss 0.4862
# Epoch 9 Batch 3700 Loss 0.5542
# Epoch 9 Batch 3800 Loss 0.4703
# Epoch 9 Batch 3900 Loss 0.4973
# Epoch 9 Batch 4000 Loss 0.4967
# Epoch 9 Batch 4100 Loss 0.4914
# Epoch 9 Batch 4200 Loss 0.5007
# Epoch 9 Batch 4300 Loss 0.4776
# Epoch 9 Batch 4400 Loss 0.5413
# Epoch 9 Batch 4500 Loss 0.4679
# Epoch 9 Batch 4600 Loss 0.4821
# Epoch 9 Batch 4700 Loss 0.4691
# Epoch 9 Batch 4800 Loss 0.4913
# Epoch 9 Batch 4900 Loss 0.4926
# Epoch 9 Batch 5000 Loss 0.4366
# Epoch 9 Batch 5100 Loss 0.4567
# Epoch 9 Batch 5200 Loss 0.4888
# Epoch 9 Batch 5300 Loss 0.4643
# Epoch 9 Batch 5400 Loss 0.4614
# Epoch 9 Batch 5500 Loss 0.4532
# Epoch 9 Batch 5600 Loss 0.5350
# Epoch 9 Batch 5700 Loss 0.5038
# Epoch 9 Batch 5800 Loss 0.4723
# Epoch 9 Batch 5900 Loss 0.5513
# Epoch 9 Batch 6000 Loss 0.4672
# Epoch 9 Batch 6100 Loss 0.4620
# Epoch 9 Batch 6200 Loss 0.4710
# Epoch 9 Batch 6300 Loss 0.4484
# Epoch 9 Batch 6400 Loss 0.5204
# Epoch 9 Batch 6500 Loss 0.5078
# Epoch 9 Batch 6600 Loss 0.4811
# Epoch 9 Batch 6700 Loss 0.5308
# Epoch 9 Batch 6800 Loss 0.4672
# Epoch 9 Batch 6900 Loss 0.4903
# Epoch 9 Batch 7000 Loss 0.4741
# Epoch 9 Batch 7100 Loss 0.4374
# Epoch 9 Batch 7200 Loss 0.4899
# Epoch 9 Batch 7300 Loss 0.4860
# Epoch 9 Loss 0.487480
# Time taken for 1 epoch 1977.65 sec
#
# Epoch 10 Batch 0 Loss 0.4952
# Epoch 10 Batch 100 Loss 0.4731
# Epoch 10 Batch 200 Loss 0.4595
# Epoch 10 Batch 300 Loss 0.4982
# Epoch 10 Batch 400 Loss 0.4791
# Epoch 10 Batch 500 Loss 0.4887
# Epoch 10 Batch 600 Loss 0.5092
# Epoch 10 Batch 700 Loss 0.4988
# Epoch 10 Batch 800 Loss 0.4513
# Epoch 10 Batch 900 Loss 0.5097
# Epoch 10 Batch 1000 Loss 0.4766
# Epoch 10 Batch 1100 Loss 0.4767
# Epoch 10 Batch 1200 Loss 0.4291
# Epoch 10 Batch 1300 Loss 0.5139
# Epoch 10 Batch 1400 Loss 0.4521
# Epoch 10 Batch 1500 Loss 0.5327
# Epoch 10 Batch 1600 Loss 0.4776
# Epoch 10 Batch 1700 Loss 0.4992
# Epoch 10 Batch 1800 Loss 0.4452
# Epoch 10 Batch 1900 Loss 0.5420
# Epoch 10 Batch 2000 Loss 0.4596
# Epoch 10 Batch 2100 Loss 0.4635
# Epoch 10 Batch 2200 Loss 0.4863
# Epoch 10 Batch 2300 Loss 0.4838
# Epoch 10 Batch 2400 Loss 0.4831
# Epoch 10 Batch 2500 Loss 0.4869
# Epoch 10 Batch 2600 Loss 0.4281
# Epoch 10 Batch 2700 Loss 0.4585
# Epoch 10 Batch 2800 Loss 0.4705
# Epoch 10 Batch 2900 Loss 0.4417
# Epoch 10 Batch 3000 Loss 0.4770
# Epoch 10 Batch 3100 Loss 0.4532
# Epoch 10 Batch 3200 Loss 0.4589
# Epoch 10 Batch 3300 Loss 0.4378
# Epoch 10 Batch 3400 Loss 0.4358
# Epoch 10 Batch 3500 Loss 0.5006
# Epoch 10 Batch 3600 Loss 0.4729
# Epoch 10 Batch 3700 Loss 0.5033
# Epoch 10 Batch 3800 Loss 0.4752
# Epoch 10 Batch 3900 Loss 0.4996
# Epoch 10 Batch 4000 Loss 0.4982
# Epoch 10 Batch 4100 Loss 0.5341
# Epoch 10 Batch 4200 Loss 0.5311
# Epoch 10 Batch 4300 Loss 0.5190
# Epoch 10 Batch 4400 Loss 0.4556
# Epoch 10 Batch 4500 Loss 0.4631
# Epoch 10 Batch 4600 Loss 0.4698
# Epoch 10 Batch 4700 Loss 0.4380
# Epoch 10 Batch 4800 Loss 0.5115
# Epoch 10 Batch 4900 Loss 0.4494
# Epoch 10 Batch 5000 Loss 0.4777
# Epoch 10 Batch 5100 Loss 0.4567
# Epoch 10 Batch 5200 Loss 0.4192
# Epoch 10 Batch 5300 Loss 0.4751
# Epoch 10 Batch 5400 Loss 0.4382
# Epoch 10 Batch 5500 Loss 0.4796
# Epoch 10 Batch 5600 Loss 0.4913
# Epoch 10 Batch 5700 Loss 0.4755
# Epoch 10 Batch 5800 Loss 0.4555
# Epoch 10 Batch 5900 Loss 0.4903
# Epoch 10 Batch 6000 Loss 0.4937
# Epoch 10 Batch 6100 Loss 0.4735
# Epoch 10 Batch 6200 Loss 0.4957
# Epoch 10 Batch 6300 Loss 0.4808
# Epoch 10 Batch 6400 Loss 0.4509
# Epoch 10 Batch 6500 Loss 0.4968
# Epoch 10 Batch 6600 Loss 0.4878
# Epoch 10 Batch 6700 Loss 0.4978
# Epoch 10 Batch 6800 Loss 0.4875
# Epoch 10 Batch 6900 Loss 0.4831
# Epoch 10 Batch 7000 Loss 0.5068
# Epoch 10 Batch 7100 Loss 0.4752
# Epoch 10 Batch 7200 Loss 0.5169
# Epoch 10 Batch 7300 Loss 0.4618
# Epoch 10 Loss 0.479900
# Time taken for 1 epoch 1972.87 sec
#
# Epoch 11 Batch 0 Loss 0.4872
# Epoch 11 Batch 100 Loss 0.4485
# Epoch 11 Batch 200 Loss 0.4447
# Epoch 11 Batch 300 Loss 0.4824
# Epoch 11 Batch 400 Loss 0.4723
# Epoch 11 Batch 500 Loss 0.4542
# Epoch 11 Batch 600 Loss 0.4609
# Epoch 11 Batch 700 Loss 0.4999
# Epoch 11 Batch 800 Loss 0.5056
# Epoch 11 Batch 900 Loss 0.4711
# Epoch 11 Batch 1000 Loss 0.4718
# Epoch 11 Batch 1100 Loss 0.5386
# Epoch 11 Batch 1200 Loss 0.4970
# Epoch 11 Batch 1300 Loss 0.5409
# Epoch 11 Batch 1400 Loss 0.4642
# Epoch 11 Batch 1500 Loss 0.4562
# Epoch 11 Batch 1600 Loss 0.5023
# Epoch 11 Batch 1700 Loss 0.4567
# Epoch 11 Batch 1800 Loss 0.5312
# Epoch 11 Batch 1900 Loss 0.4599
# Epoch 11 Batch 2000 Loss 0.5014
# Epoch 11 Batch 2100 Loss 0.4782
# Epoch 11 Batch 2200 Loss 0.5111
# Epoch 11 Batch 2300 Loss 0.4888
# Epoch 11 Batch 2400 Loss 0.4559
# Epoch 11 Batch 2500 Loss 0.4804
# Epoch 11 Batch 2600 Loss 0.4471
# Epoch 11 Batch 2700 Loss 0.4732
# Epoch 11 Batch 2800 Loss 0.4582
# Epoch 11 Batch 2900 Loss 0.5091
# Epoch 11 Batch 3000 Loss 0.4533
# Epoch 11 Batch 3100 Loss 0.4751
# Epoch 11 Batch 3200 Loss 0.4787
# Epoch 11 Batch 3300 Loss 0.4895
# Epoch 11 Batch 3400 Loss 0.4636
# Epoch 11 Batch 3500 Loss 0.5112
# Epoch 11 Batch 3600 Loss 0.4619
# Epoch 11 Batch 3700 Loss 0.4628
# Epoch 11 Batch 3800 Loss 0.4480
# Epoch 11 Batch 3900 Loss 0.4581
# Epoch 11 Batch 4000 Loss 0.4593
# Epoch 11 Batch 4100 Loss 0.5042
# Epoch 11 Batch 4200 Loss 0.4746
# Epoch 11 Batch 4300 Loss 0.4641
# Epoch 11 Batch 4400 Loss 0.4898
# Epoch 11 Batch 4500 Loss 0.4846
# Epoch 11 Batch 4600 Loss 0.4843
# Epoch 11 Batch 4700 Loss 0.4482
# Epoch 11 Batch 4800 Loss 0.4955
# Epoch 11 Batch 4900 Loss 0.4848
# Epoch 11 Batch 5000 Loss 0.4547
# Epoch 11 Batch 5100 Loss 0.4888
# Epoch 11 Batch 5200 Loss 0.5174
# Epoch 11 Batch 5300 Loss 0.4580
# Epoch 11 Batch 5400 Loss 0.4853
# Epoch 11 Batch 5500 Loss 0.4450
# Epoch 11 Batch 5600 Loss 0.4739
# Epoch 11 Batch 5700 Loss 0.4431
# Epoch 11 Batch 5800 Loss 0.5329
# Epoch 11 Batch 5900 Loss 0.4727
# Epoch 11 Batch 6000 Loss 0.4440
# Epoch 11 Batch 6100 Loss 0.4926
# Epoch 11 Batch 6200 Loss 0.4709
# Epoch 11 Batch 6300 Loss 0.4799
# Epoch 11 Batch 6400 Loss 0.4251
# Epoch 11 Batch 6500 Loss 0.4979
# Epoch 11 Batch 6600 Loss 0.4601
# Epoch 11 Batch 6700 Loss 0.4155
# Epoch 11 Batch 6800 Loss 0.4606
# Epoch 11 Batch 6900 Loss 0.4093
# Epoch 11 Batch 7000 Loss 0.4616
# Epoch 11 Batch 7100 Loss 0.4615
# Epoch 11 Batch 7200 Loss 0.4520
# Epoch 11 Batch 7300 Loss 0.4550
# Epoch 11 Loss 0.473788
# Time taken for 1 epoch 1975.15 sec
#
# Epoch 12 Batch 0 Loss 0.4334
# Epoch 12 Batch 100 Loss 0.4479
# Epoch 12 Batch 200 Loss 0.4474
# Epoch 12 Batch 300 Loss 0.5014
# Epoch 12 Batch 400 Loss 0.5006
# Epoch 12 Batch 500 Loss 0.4543
# Epoch 12 Batch 600 Loss 0.5026
# Epoch 12 Batch 700 Loss 0.5017
# Epoch 12 Batch 800 Loss 0.4657
# Epoch 12 Batch 900 Loss 0.4523
# Epoch 12 Batch 1000 Loss 0.5026
# Epoch 12 Batch 1100 Loss 0.4245
# Epoch 12 Batch 1200 Loss 0.4710
# Epoch 12 Batch 1300 Loss 0.4888
# Epoch 12 Batch 1400 Loss 0.4373
# Epoch 12 Batch 1500 Loss 0.4889
# Epoch 12 Batch 1600 Loss 0.4741
# Epoch 12 Batch 1700 Loss 0.4421
# Epoch 12 Batch 1800 Loss 0.4498
# Epoch 12 Batch 1900 Loss 0.4316
# Epoch 12 Batch 2000 Loss 0.4426
# Epoch 12 Batch 2100 Loss 0.5064
# Epoch 12 Batch 2200 Loss 0.4776
# Epoch 12 Batch 2300 Loss 0.5349
# Epoch 12 Batch 2400 Loss 0.4730
# Epoch 12 Batch 2500 Loss 0.4828
# Epoch 12 Batch 2600 Loss 0.5183
# Epoch 12 Batch 2700 Loss 0.4697
# Epoch 12 Batch 2800 Loss 0.4361
# Epoch 12 Batch 2900 Loss 0.4611
# Epoch 12 Batch 3000 Loss 0.4602
# Epoch 12 Batch 3100 Loss 0.5154
# Epoch 12 Batch 3200 Loss 0.4910
# Epoch 12 Batch 3300 Loss 0.5048
# Epoch 12 Batch 3400 Loss 0.4484
# Epoch 12 Batch 3500 Loss 0.4620
# Epoch 12 Batch 3600 Loss 0.4925
# Epoch 12 Batch 3700 Loss 0.4700
# Epoch 12 Batch 3800 Loss 0.4410
# Epoch 12 Batch 3900 Loss 0.4793
# Epoch 12 Batch 4000 Loss 0.4298
# Epoch 12 Batch 4100 Loss 0.4543
# Epoch 12 Batch 4200 Loss 0.4877
# Epoch 12 Batch 4300 Loss 0.4654
# Epoch 12 Batch 4400 Loss 0.5119
# Epoch 12 Batch 4500 Loss 0.4771
# Epoch 12 Batch 4600 Loss 0.4490
# Epoch 12 Batch 4700 Loss 0.4687
# Epoch 12 Batch 4800 Loss 0.5037
# Epoch 12 Batch 4900 Loss 0.4383
# Epoch 12 Batch 5000 Loss 0.4718
# Epoch 12 Batch 5100 Loss 0.4629
# Epoch 12 Batch 5200 Loss 0.4587
# Epoch 12 Batch 5300 Loss 0.4922
# Epoch 12 Batch 5400 Loss 0.4960
# Epoch 12 Batch 5500 Loss 0.4827
# Epoch 12 Batch 5600 Loss 0.4274
# Epoch 12 Batch 5700 Loss 0.4294
# Epoch 12 Batch 5800 Loss 0.4418
# Epoch 12 Batch 5900 Loss 0.4717
# Epoch 12 Batch 6000 Loss 0.4537
# Epoch 12 Batch 6100 Loss 0.4625
# Epoch 12 Batch 6200 Loss 0.4643
# Epoch 12 Batch 6300 Loss 0.4749
# Epoch 12 Batch 6400 Loss 0.4427
# Epoch 12 Batch 6500 Loss 0.4512
# Epoch 12 Batch 6600 Loss 0.4618
# Epoch 12 Batch 6700 Loss 0.4631
# Epoch 12 Batch 6800 Loss 0.4380
# Epoch 12 Batch 6900 Loss 0.4921
# Epoch 12 Batch 7000 Loss 0.4779
# Epoch 12 Batch 7100 Loss 0.4471
# Epoch 12 Batch 7200 Loss 0.4829
# Epoch 12 Batch 7300 Loss 0.4471
# Epoch 12 Loss 0.469371
# Time taken for 1 epoch 1974.99 sec
#
# Epoch 13 Batch 0 Loss 0.4648
# Epoch 13 Batch 100 Loss 0.4403
# Epoch 13 Batch 200 Loss 0.4589
# Epoch 13 Batch 300 Loss 0.4461
# Epoch 13 Batch 400 Loss 0.4618
# Epoch 13 Batch 500 Loss 0.4924
# Epoch 13 Batch 600 Loss 0.4747
# Epoch 13 Batch 700 Loss 0.4517
# Epoch 13 Batch 800 Loss 0.4418
# Epoch 13 Batch 900 Loss 0.4542
# Epoch 13 Batch 1000 Loss 0.4489
# Epoch 13 Batch 1100 Loss 0.5194
# Epoch 13 Batch 1200 Loss 0.4500
# Epoch 13 Batch 1300 Loss 0.4523
# Epoch 13 Batch 1400 Loss 0.4657
# Epoch 13 Batch 1500 Loss 0.4711
# Epoch 13 Batch 1600 Loss 0.4282
# Epoch 13 Batch 1700 Loss 0.4571
# Epoch 13 Batch 1800 Loss 0.4832
# Epoch 13 Batch 1900 Loss 0.4972
# Epoch 13 Batch 2000 Loss 0.4850
# Epoch 13 Batch 2100 Loss 0.4834
# Epoch 13 Batch 2200 Loss 0.4469
# Epoch 13 Batch 2300 Loss 0.4529
# Epoch 13 Batch 2400 Loss 0.4532
# Epoch 13 Batch 2500 Loss 0.5045
# Epoch 13 Batch 2600 Loss 0.4936
# Epoch 13 Batch 2700 Loss 0.4397
# Epoch 13 Batch 2800 Loss 0.4138
# Epoch 13 Batch 2900 Loss 0.4517
# Epoch 13 Batch 3000 Loss 0.4752
# Epoch 13 Batch 3100 Loss 0.4707
# Epoch 13 Batch 3200 Loss 0.4922
# Epoch 13 Batch 3300 Loss 0.4574
# Epoch 13 Batch 3400 Loss 0.4420
# Epoch 13 Batch 3500 Loss 0.4255
# Epoch 13 Batch 3600 Loss 0.4628
# Epoch 13 Batch 3700 Loss 0.4525
# Epoch 13 Batch 3800 Loss 0.4508
# Epoch 13 Batch 3900 Loss 0.4308
# Epoch 13 Batch 4000 Loss 0.4897
# Epoch 13 Batch 4100 Loss 0.4804
# Epoch 13 Batch 4200 Loss 0.5088
# Epoch 13 Batch 4300 Loss 0.4602
# Epoch 13 Batch 4400 Loss 0.4957
# Epoch 13 Batch 4500 Loss 0.4679
# Epoch 13 Batch 4600 Loss 0.4011
# Epoch 13 Batch 4700 Loss 0.4439
# Epoch 13 Batch 4800 Loss 0.4923
# Epoch 13 Batch 4900 Loss 0.5144
# Epoch 13 Batch 5000 Loss 0.4475
# Epoch 13 Batch 5100 Loss 0.4333
# Epoch 13 Batch 5200 Loss 0.4595
# Epoch 13 Batch 5300 Loss 0.4464
# Epoch 13 Batch 5400 Loss 0.4439
# Epoch 13 Batch 5500 Loss 0.4676
# Epoch 13 Batch 5600 Loss 0.4999
# Epoch 13 Batch 5700 Loss 0.4286
# Epoch 13 Batch 5800 Loss 0.4436
# Epoch 13 Batch 5900 Loss 0.5119
# Epoch 13 Batch 6000 Loss 0.4608
# Epoch 13 Batch 6100 Loss 0.4262
# Epoch 13 Batch 6200 Loss 0.4773
# Epoch 13 Batch 6300 Loss 0.4397
# Epoch 13 Batch 6400 Loss 0.3983
# Epoch 13 Batch 6500 Loss 0.4846
# Epoch 13 Batch 6600 Loss 0.4514
# Epoch 13 Batch 6700 Loss 0.4761
# Epoch 13 Batch 6800 Loss 0.5056
# Epoch 13 Batch 6900 Loss 0.4662
# Epoch 13 Batch 7000 Loss 0.4390
# Epoch 13 Batch 7100 Loss 0.4814
# Epoch 13 Batch 7200 Loss 0.4705
# Epoch 13 Batch 7300 Loss 0.4738
# Epoch 13 Loss 0.463323
# Time taken for 1 epoch 1974.76 sec
#
# Epoch 14 Batch 0 Loss 0.4508
# Epoch 14 Batch 100 Loss 0.4503
# Epoch 14 Batch 200 Loss 0.4006
# Epoch 14 Batch 300 Loss 0.4575
# Epoch 14 Batch 400 Loss 0.4673
# Epoch 14 Batch 500 Loss 0.4978
# Epoch 14 Batch 600 Loss 0.4412
# Epoch 14 Batch 700 Loss 0.4623
# Epoch 14 Batch 800 Loss 0.4348
# Epoch 14 Batch 900 Loss 0.4379
# Epoch 14 Batch 1000 Loss 0.4343
# Epoch 14 Batch 1100 Loss 0.4426
# Epoch 14 Batch 1200 Loss 0.4677
# Epoch 14 Batch 1300 Loss 0.4429
# Epoch 14 Batch 1400 Loss 0.4552
# Epoch 14 Batch 1500 Loss 0.4647
# Epoch 14 Batch 1600 Loss 0.4892
# Epoch 14 Batch 1700 Loss 0.4536
# Epoch 14 Batch 1800 Loss 0.4400
# Epoch 14 Batch 1900 Loss 0.5138
# Epoch 14 Batch 2000 Loss 0.4377
# Epoch 14 Batch 2100 Loss 0.4771
# Epoch 14 Batch 2200 Loss 0.4844
# Epoch 14 Batch 2300 Loss 0.4328
# Epoch 14 Batch 2400 Loss 0.4234
# Epoch 14 Batch 2500 Loss 0.4807
# Epoch 14 Batch 2600 Loss 0.4413
# Epoch 14 Batch 2700 Loss 0.4653
# Epoch 14 Batch 2800 Loss 0.4810
# Epoch 14 Batch 2900 Loss 0.4538
# Epoch 14 Batch 3000 Loss 0.4337
# Epoch 14 Batch 3100 Loss 0.4625
# Epoch 14 Batch 3200 Loss 0.4767
# Epoch 14 Batch 3300 Loss 0.4106
# Epoch 14 Batch 3400 Loss 0.4815
# Epoch 14 Batch 3500 Loss 0.4515
# Epoch 14 Batch 3600 Loss 0.4588
# Epoch 14 Batch 3700 Loss 0.4671
# Epoch 14 Batch 3800 Loss 0.4374
# Epoch 14 Batch 3900 Loss 0.4546
# Epoch 14 Batch 4000 Loss 0.4735
# Epoch 14 Batch 4100 Loss 0.4911
# Epoch 14 Batch 4200 Loss 0.4417
# Epoch 14 Batch 4300 Loss 0.3993
# Epoch 14 Batch 4400 Loss 0.4619
# Epoch 14 Batch 4500 Loss 0.4042
# Epoch 14 Batch 4600 Loss 0.4334
# Epoch 14 Batch 4700 Loss 0.4540
# Epoch 14 Batch 4800 Loss 0.4504
# Epoch 14 Batch 4900 Loss 0.4533
# Epoch 14 Batch 5000 Loss 0.4433
# Epoch 14 Batch 5100 Loss 0.4635
# Epoch 14 Batch 5200 Loss 0.4274
# Epoch 14 Batch 5300 Loss 0.4272
# Epoch 14 Batch 5400 Loss 0.4405
# Epoch 14 Batch 5500 Loss 0.4520
# Epoch 14 Batch 5600 Loss 0.4575
# Epoch 14 Batch 5700 Loss 0.4486
# Epoch 14 Batch 5800 Loss 0.4219
# Epoch 14 Batch 5900 Loss 0.4961
# Epoch 14 Batch 6000 Loss 0.4839
# Epoch 14 Batch 6100 Loss 0.4371
# Epoch 14 Batch 6200 Loss 0.4896
# Epoch 14 Batch 6300 Loss 0.4814
# Epoch 14 Batch 6400 Loss 0.4132
# Epoch 14 Batch 6500 Loss 0.4582
# Epoch 14 Batch 6600 Loss 0.4319
# Epoch 14 Batch 6700 Loss 0.4520
# Epoch 14 Batch 6800 Loss 0.4692
# Epoch 14 Batch 6900 Loss 0.4488
# Epoch 14 Batch 7000 Loss 0.4824
# Epoch 14 Batch 7100 Loss 0.4606
# Epoch 14 Batch 7200 Loss 0.4132
# Epoch 14 Batch 7300 Loss 0.4543
# Epoch 14 Loss 0.458660
# Time taken for 1 epoch 1937.68 sec
#
# Epoch 15 Batch 0 Loss 0.4562
# Epoch 15 Batch 100 Loss 0.4300
# Epoch 15 Batch 200 Loss 0.4424
# Epoch 15 Batch 300 Loss 0.4563
# Epoch 15 Batch 400 Loss 0.4825
# Epoch 15 Batch 500 Loss 0.4229
# Epoch 15 Batch 600 Loss 0.4485
# Epoch 15 Batch 700 Loss 0.4483
# Epoch 15 Batch 800 Loss 0.4359
# Epoch 15 Batch 900 Loss 0.5337
# Epoch 15 Batch 1000 Loss 0.4600
# Epoch 15 Batch 1100 Loss 0.4759
# Epoch 15 Batch 1200 Loss 0.4717
# Epoch 15 Batch 1300 Loss 0.4418
# Epoch 15 Batch 1400 Loss 0.4413
# Epoch 15 Batch 1500 Loss 0.4353
# Epoch 15 Batch 1600 Loss 0.4850
# Epoch 15 Batch 1700 Loss 0.4491
# Epoch 15 Batch 1800 Loss 0.4472
# Epoch 15 Batch 1900 Loss 0.4477
# Epoch 15 Batch 2000 Loss 0.4195
# Epoch 15 Batch 2100 Loss 0.5040
# Epoch 15 Batch 2200 Loss 0.4473
# Epoch 15 Batch 2300 Loss 0.4700
# Epoch 15 Batch 2400 Loss 0.5059
# Epoch 15 Batch 2500 Loss 0.4935
# Epoch 15 Batch 2600 Loss 0.4791
# Epoch 15 Batch 2700 Loss 0.4120
# Epoch 15 Batch 2800 Loss 0.4990
# Epoch 15 Batch 2900 Loss 0.4497
# Epoch 15 Batch 3000 Loss 0.5078
# Epoch 15 Batch 3100 Loss 0.4626
# Epoch 15 Batch 3200 Loss 0.4362
# Epoch 15 Batch 3300 Loss 0.4671
# Epoch 15 Batch 3400 Loss 0.4334
# Epoch 15 Batch 3500 Loss 0.4742
# Epoch 15 Batch 3600 Loss 0.4692
# Epoch 15 Batch 3700 Loss 0.4510
# Epoch 15 Batch 3800 Loss 0.5045
# Epoch 15 Batch 3900 Loss 0.4595
# Epoch 15 Batch 4000 Loss 0.4222
# Epoch 15 Batch 4100 Loss 0.4695
# Epoch 15 Batch 4200 Loss 0.4736
# Epoch 15 Batch 4300 Loss 0.4517
# Epoch 15 Batch 4400 Loss 0.4735
# Epoch 15 Batch 4500 Loss 0.4395
# Epoch 15 Batch 4600 Loss 0.4511
# Epoch 15 Batch 4700 Loss 0.4531
# Epoch 15 Batch 4800 Loss 0.4721
# Epoch 15 Batch 4900 Loss 0.4289
# Epoch 15 Batch 5000 Loss 0.4632
# Epoch 15 Batch 5100 Loss 0.4422
# Epoch 15 Batch 5200 Loss 0.4338
# Epoch 15 Batch 5300 Loss 0.5229
# Epoch 15 Batch 5400 Loss 0.4488
# Epoch 15 Batch 5500 Loss 0.4825
# Epoch 15 Batch 5600 Loss 0.4378
# Epoch 15 Batch 5700 Loss 0.4786
# Epoch 15 Batch 5800 Loss 0.4537
# Epoch 15 Batch 5900 Loss 0.4421
# Epoch 15 Batch 6000 Loss 0.4721
# Epoch 15 Batch 6100 Loss 0.4142
# Epoch 15 Batch 6200 Loss 0.4009
# Epoch 15 Batch 6300 Loss 0.4469
# Epoch 15 Batch 6400 Loss 0.3944
# Epoch 15 Batch 6500 Loss 0.4421
# Epoch 15 Batch 6600 Loss 0.4086
# Epoch 15 Batch 6700 Loss 0.4851
# Epoch 15 Batch 6800 Loss 0.4242
# Epoch 15 Batch 6900 Loss 0.4515
# Epoch 15 Batch 7000 Loss 0.4830
# Epoch 15 Batch 7100 Loss 0.4840
# Epoch 15 Batch 7200 Loss 0.4524
# Epoch 15 Batch 7300 Loss 0.4661
# Epoch 15 Loss 0.453672
# Time taken for 1 epoch 1921.65 sec
#
# Epoch 16 Batch 0 Loss 0.4968
# Epoch 16 Batch 100 Loss 0.4985
# Epoch 16 Batch 200 Loss 0.4355
# Epoch 16 Batch 300 Loss 0.4808
# Epoch 16 Batch 400 Loss 0.4623
# Epoch 16 Batch 500 Loss 0.4349
# Epoch 16 Batch 600 Loss 0.4367
# Epoch 16 Batch 700 Loss 0.4761
# Epoch 16 Batch 800 Loss 0.4544
# Epoch 16 Batch 900 Loss 0.4142
# Epoch 16 Batch 1000 Loss 0.4262
# Epoch 16 Batch 1100 Loss 0.4506
# Epoch 16 Batch 1200 Loss 0.4233
# Epoch 16 Batch 1300 Loss 0.4513
# Epoch 16 Batch 1400 Loss 0.4351
# Epoch 16 Batch 1500 Loss 0.4212
# Epoch 16 Batch 1600 Loss 0.4542
# Epoch 16 Batch 1700 Loss 0.4586
# Epoch 16 Batch 1800 Loss 0.4943
# Epoch 16 Batch 1900 Loss 0.4523
# Epoch 16 Batch 2000 Loss 0.4362
# Epoch 16 Batch 2100 Loss 0.4425
# Epoch 16 Batch 2200 Loss 0.4355
# Epoch 16 Batch 2300 Loss 0.4539
# Epoch 16 Batch 2400 Loss 0.4824
# Epoch 16 Batch 2500 Loss 0.4768
# Epoch 16 Batch 2600 Loss 0.4583
# Epoch 16 Batch 2700 Loss 0.3933
# Epoch 16 Batch 2800 Loss 0.4646
# Epoch 16 Batch 2900 Loss 0.4190
# Epoch 16 Batch 3000 Loss 0.4602
# Epoch 16 Batch 3100 Loss 0.4583
# Epoch 16 Batch 3200 Loss 0.4885
# Epoch 16 Batch 3300 Loss 0.4624
# Epoch 16 Batch 3400 Loss 0.4758
# Epoch 16 Batch 3500 Loss 0.4455
# Epoch 16 Batch 3600 Loss 0.4710
# Epoch 16 Batch 3700 Loss 0.4456
# Epoch 16 Batch 3800 Loss 0.4777
# Epoch 16 Batch 3900 Loss 0.4369
# Epoch 16 Batch 4000 Loss 0.4747
# Epoch 16 Batch 4100 Loss 0.4489
# Epoch 16 Batch 4200 Loss 0.4094
# Epoch 16 Batch 4300 Loss 0.4101
# Epoch 16 Batch 4400 Loss 0.4423
# Epoch 16 Batch 4500 Loss 0.4431
# Epoch 16 Batch 4600 Loss 0.4647
# Epoch 16 Batch 4700 Loss 0.4317
# Epoch 16 Batch 4800 Loss 0.4513
# Epoch 16 Batch 4900 Loss 0.4523
# Epoch 16 Batch 5000 Loss 0.4232
# Epoch 16 Batch 5100 Loss 0.4250
# Epoch 16 Batch 5200 Loss 0.4115
# Epoch 16 Batch 5300 Loss 0.4828
# Epoch 16 Batch 5400 Loss 0.4597
# Epoch 16 Batch 5500 Loss 0.4558
# Epoch 16 Batch 5600 Loss 0.4867
# Epoch 16 Batch 5700 Loss 0.4907
# Epoch 16 Batch 5800 Loss 0.4594
# Epoch 16 Batch 5900 Loss 0.4703
# Epoch 16 Batch 6000 Loss 0.4498
# Epoch 16 Batch 6100 Loss 0.4461
# Epoch 16 Batch 6200 Loss 0.3983
# Epoch 16 Batch 6300 Loss 0.4916
# Epoch 16 Batch 6400 Loss 0.4316
# Epoch 16 Batch 6500 Loss 0.4605
# Epoch 16 Batch 6600 Loss 0.4397
# Epoch 16 Batch 6700 Loss 0.5261
# Epoch 16 Batch 6800 Loss 0.4091
# Epoch 16 Batch 6900 Loss 0.5040
# Epoch 16 Batch 7000 Loss 0.4600
# Epoch 16 Batch 7100 Loss 0.4410
# Epoch 16 Batch 7200 Loss 0.4460
# Epoch 16 Batch 7300 Loss 0.4473
# Epoch 16 Loss 0.450187
# Time taken for 1 epoch 1922.37 sec
#
# Epoch 17 Batch 0 Loss 0.4924
# Epoch 17 Batch 100 Loss 0.4399
# Epoch 17 Batch 200 Loss 0.4469
# Epoch 17 Batch 300 Loss 0.4191
# Epoch 17 Batch 400 Loss 0.4031
# Epoch 17 Batch 500 Loss 0.4457
# Epoch 17 Batch 600 Loss 0.4325
# Epoch 17 Batch 700 Loss 0.4408
# Epoch 17 Batch 800 Loss 0.4845
# Epoch 17 Batch 900 Loss 0.4862
# Epoch 17 Batch 1000 Loss 0.4238
# Epoch 17 Batch 1100 Loss 0.4765
# Epoch 17 Batch 1200 Loss 0.4092
# Epoch 17 Batch 1300 Loss 0.4360
# Epoch 17 Batch 1400 Loss 0.4322
# Epoch 17 Batch 1500 Loss 0.4558
# Epoch 17 Batch 1600 Loss 0.4290
# Epoch 17 Batch 1700 Loss 0.4269
# Epoch 17 Batch 1800 Loss 0.4285
# Epoch 17 Batch 1900 Loss 0.4243
# Epoch 17 Batch 2000 Loss 0.4337
# Epoch 17 Batch 2100 Loss 0.4128
# Epoch 17 Batch 2200 Loss 0.4239
# Epoch 17 Batch 2300 Loss 0.4533
# Epoch 17 Batch 2400 Loss 0.4300
# Epoch 17 Batch 2500 Loss 0.4619
# Epoch 17 Batch 2600 Loss 0.4222
# Epoch 17 Batch 2700 Loss 0.4612
# Epoch 17 Batch 2800 Loss 0.4701
# Epoch 17 Batch 2900 Loss 0.4199
# Epoch 17 Batch 3000 Loss 0.4605
# Epoch 17 Batch 3100 Loss 0.4658
# Epoch 17 Batch 3200 Loss 0.3950
# Epoch 17 Batch 3300 Loss 0.4281
# Epoch 17 Batch 3400 Loss 0.4388
# Epoch 17 Batch 3500 Loss 0.4377
# Epoch 17 Batch 3600 Loss 0.4741
# Epoch 17 Batch 3700 Loss 0.4634
# Epoch 17 Batch 3800 Loss 0.4603
# Epoch 17 Batch 3900 Loss 0.4843
# Epoch 17 Batch 4000 Loss 0.4465
# Epoch 17 Batch 4100 Loss 0.4801
# Epoch 17 Batch 4200 Loss 0.4755
# Epoch 17 Batch 4300 Loss 0.4022
# Epoch 17 Batch 4400 Loss 0.4432
# Epoch 17 Batch 4500 Loss 0.4306
# Epoch 17 Batch 4600 Loss 0.4443
# Epoch 17 Batch 4700 Loss 0.4280
# Epoch 17 Batch 4800 Loss 0.5336
# Epoch 17 Batch 4900 Loss 0.4634
# Epoch 17 Batch 5000 Loss 0.4336
# Epoch 17 Batch 5100 Loss 0.4610
# Epoch 17 Batch 5200 Loss 0.3959
# Epoch 17 Batch 5300 Loss 0.4677
# Epoch 17 Batch 5400 Loss 0.4785
# Epoch 17 Batch 5500 Loss 0.4275
# Epoch 17 Batch 5600 Loss 0.4726
# Epoch 17 Batch 5700 Loss 0.4190
# Epoch 17 Batch 5800 Loss 0.4457
# Epoch 17 Batch 5900 Loss 0.4424
# Epoch 17 Batch 6000 Loss 0.4567
# Epoch 17 Batch 6100 Loss 0.4133
# Epoch 17 Batch 6200 Loss 0.4810
# Epoch 17 Batch 6300 Loss 0.4323
# Epoch 17 Batch 6400 Loss 0.4190
# Epoch 17 Batch 6500 Loss 0.4122
# Epoch 17 Batch 6600 Loss 0.4461
# Epoch 17 Batch 6700 Loss 0.4402
# Epoch 17 Batch 6800 Loss 0.4049
# Epoch 17 Batch 6900 Loss 0.4493
# Epoch 17 Batch 7000 Loss 0.3927
# Epoch 17 Batch 7100 Loss 0.4763
# Epoch 17 Batch 7200 Loss 0.4632
# Epoch 17 Batch 7300 Loss 0.4220
# Epoch 17 Loss 0.446604
# Time taken for 1 epoch 1922.90 sec
#
# Epoch 18 Batch 0 Loss 0.3898
# Epoch 18 Batch 100 Loss 0.4443
# Epoch 18 Batch 200 Loss 0.4123
# Epoch 18 Batch 300 Loss 0.3814
# Epoch 18 Batch 400 Loss 0.4394
# Epoch 18 Batch 500 Loss 0.4875
# Epoch 18 Batch 600 Loss 0.4406
# Epoch 18 Batch 700 Loss 0.4706
# Epoch 18 Batch 800 Loss 0.4714
# Epoch 18 Batch 900 Loss 0.4210
# Epoch 18 Batch 1000 Loss 0.4646
# Epoch 18 Batch 1100 Loss 0.4260
# Epoch 18 Batch 1200 Loss 0.4827
# Epoch 18 Batch 1300 Loss 0.4482
# Epoch 18 Batch 1400 Loss 0.4805
# Epoch 18 Batch 1500 Loss 0.4362
# Epoch 18 Batch 1600 Loss 0.4861
# Epoch 18 Batch 1700 Loss 0.3976
# Epoch 18 Batch 1800 Loss 0.4408
# Epoch 18 Batch 1900 Loss 0.4005
# Epoch 18 Batch 2000 Loss 0.4360
# Epoch 18 Batch 2100 Loss 0.4826
# Epoch 18 Batch 2200 Loss 0.4611
# Epoch 18 Batch 2300 Loss 0.4809
# Epoch 18 Batch 2400 Loss 0.4548
# Epoch 18 Batch 2500 Loss 0.4465
# Epoch 18 Batch 2600 Loss 0.4376
# Epoch 18 Batch 2700 Loss 0.4842
# Epoch 18 Batch 2800 Loss 0.4105
# Epoch 18 Batch 2900 Loss 0.3972
# Epoch 18 Batch 3000 Loss 0.4286
# Epoch 18 Batch 3100 Loss 0.4416
# Epoch 18 Batch 3200 Loss 0.4055
# Epoch 18 Batch 3300 Loss 0.4289
# Epoch 18 Batch 3400 Loss 0.4278
# Epoch 18 Batch 3500 Loss 0.4552
# Epoch 18 Batch 3600 Loss 0.4472
# Epoch 18 Batch 3700 Loss 0.4384
# Epoch 18 Batch 3800 Loss 0.4241
# Epoch 18 Batch 3900 Loss 0.4495
# Epoch 18 Batch 4000 Loss 0.5365
# Epoch 18 Batch 4100 Loss 0.4902
# Epoch 18 Batch 4200 Loss 0.4590
# Epoch 18 Batch 4300 Loss 0.3896
# Epoch 18 Batch 4400 Loss 0.4539
# Epoch 18 Batch 4500 Loss 0.4696
# Epoch 18 Batch 4600 Loss 0.4743
# Epoch 18 Batch 4700 Loss 0.4525
# Epoch 18 Batch 4800 Loss 0.4609
# Epoch 18 Batch 4900 Loss 0.4114
# Epoch 18 Batch 5000 Loss 0.4917
# Epoch 18 Batch 5100 Loss 0.4677
# Epoch 18 Batch 5200 Loss 0.3975
# Epoch 18 Batch 5300 Loss 0.4102
# Epoch 18 Batch 5400 Loss 0.4342
# Epoch 18 Batch 5500 Loss 0.4175
# Epoch 18 Batch 5600 Loss 0.4140
# Epoch 18 Batch 5700 Loss 0.4719
# Epoch 18 Batch 5800 Loss 0.4379
# Epoch 18 Batch 5900 Loss 0.4294
# Epoch 18 Batch 6000 Loss 0.4557
# Epoch 18 Batch 6100 Loss 0.4233
# Epoch 18 Batch 6200 Loss 0.4497
# Epoch 18 Batch 6300 Loss 0.3851
# Epoch 18 Batch 6400 Loss 0.4311
# Epoch 18 Batch 6500 Loss 0.4309
# Epoch 18 Batch 6600 Loss 0.4371
# Epoch 18 Batch 6700 Loss 0.4144
# Epoch 18 Batch 6800 Loss 0.4684
# Epoch 18 Batch 6900 Loss 0.4327
# Epoch 18 Batch 7000 Loss 0.4310
# Epoch 18 Batch 7100 Loss 0.4524
# Epoch 18 Batch 7200 Loss 0.4759
# Epoch 18 Batch 7300 Loss 0.4258
# Epoch 18 Loss 0.443362
# Time taken for 1 epoch 1922.56 sec
#
# Epoch 19 Batch 0 Loss 0.4368
# Epoch 19 Batch 100 Loss 0.4150
# Epoch 19 Batch 200 Loss 0.4461
# Epoch 19 Batch 300 Loss 0.3978
# Epoch 19 Batch 400 Loss 0.4600
# Epoch 19 Batch 500 Loss 0.4310
# Epoch 19 Batch 600 Loss 0.4405
# Epoch 19 Batch 700 Loss 0.4747
# Epoch 19 Batch 800 Loss 0.4208
# Epoch 19 Batch 900 Loss 0.4676
# Epoch 19 Batch 1000 Loss 0.4070
# Epoch 19 Batch 1100 Loss 0.4452
# Epoch 19 Batch 1200 Loss 0.4773
# Epoch 19 Batch 1300 Loss 0.4557
# Epoch 19 Batch 1400 Loss 0.4085
# Epoch 19 Batch 1500 Loss 0.4376
# Epoch 19 Batch 1600 Loss 0.4630
# Epoch 19 Batch 1700 Loss 0.4103
# Epoch 19 Batch 1800 Loss 0.4203
# Epoch 19 Batch 1900 Loss 0.4217
# Epoch 19 Batch 2000 Loss 0.4389
# Epoch 19 Batch 2100 Loss 0.4438
# Epoch 19 Batch 2200 Loss 0.4090
# Epoch 19 Batch 2300 Loss 0.4292
# Epoch 19 Batch 2400 Loss 0.4609
# Epoch 19 Batch 2500 Loss 0.4213
# Epoch 19 Batch 2600 Loss 0.4192
# Epoch 19 Batch 2700 Loss 0.4605
# Epoch 19 Batch 2800 Loss 0.4149
# Epoch 19 Batch 2900 Loss 0.4319
# Epoch 19 Batch 3000 Loss 0.4643
# Epoch 19 Batch 3100 Loss 0.4126
# Epoch 19 Batch 3200 Loss 0.4626
# Epoch 19 Batch 3300 Loss 0.4296
# Epoch 19 Batch 3400 Loss 0.4427
# Epoch 19 Batch 3500 Loss 0.4673
# Epoch 19 Batch 3600 Loss 0.4257
# Epoch 19 Batch 3700 Loss 0.4730
# Epoch 19 Batch 3800 Loss 0.4256
# Epoch 19 Batch 3900 Loss 0.4237
# Epoch 19 Batch 4000 Loss 0.4151
# Epoch 19 Batch 4100 Loss 0.4394
# Epoch 19 Batch 4200 Loss 0.4362
# Epoch 19 Batch 4300 Loss 0.4221
# Epoch 19 Batch 4400 Loss 0.4418
# Epoch 19 Batch 4500 Loss 0.4893
# Epoch 19 Batch 4600 Loss 0.4648
# Epoch 19 Batch 4700 Loss 0.4291
# Epoch 19 Batch 4800 Loss 0.4495
# Epoch 19 Batch 4900 Loss 0.4398
# Epoch 19 Batch 5000 Loss 0.4357
# Epoch 19 Batch 5100 Loss 0.4405
# Epoch 19 Batch 5200 Loss 0.4103
# Epoch 19 Batch 5300 Loss 0.4212
# Epoch 19 Batch 5400 Loss 0.4871
# Epoch 19 Batch 5500 Loss 0.4447
# Epoch 19 Batch 5600 Loss 0.4291
# Epoch 19 Batch 5700 Loss 0.4008
# Epoch 19 Batch 5800 Loss 0.4209
# Epoch 19 Batch 5900 Loss 0.4401
# Epoch 19 Batch 6000 Loss 0.4585
# Epoch 19 Batch 6100 Loss 0.4133
# Epoch 19 Batch 6200 Loss 0.4815
# Epoch 19 Batch 6300 Loss 0.4225
# Epoch 19 Batch 6400 Loss 0.4496
# Epoch 19 Batch 6500 Loss 0.4225
# Epoch 19 Batch 6600 Loss 0.4453
# Epoch 19 Batch 6700 Loss 0.4156
# Epoch 19 Batch 6800 Loss 0.4523
# Epoch 19 Batch 6900 Loss 0.4511
# Epoch 19 Batch 7000 Loss 0.4310
# Epoch 19 Batch 7100 Loss 0.4480
# Epoch 19 Batch 7200 Loss 0.4479
# Epoch 19 Batch 7300 Loss 0.4338
# Epoch 19 Loss 0.440369
# Time taken for 1 epoch 1922.58 sec
#
# Epoch 20 Batch 0 Loss 0.4145
# Epoch 20 Batch 100 Loss 0.4499
# Epoch 20 Batch 200 Loss 0.4547
# Epoch 20 Batch 300 Loss 0.4552
# Epoch 20 Batch 400 Loss 0.4534
# Epoch 20 Batch 500 Loss 0.4522
# Epoch 20 Batch 600 Loss 0.4601
# Epoch 20 Batch 700 Loss 0.4914
# Epoch 20 Batch 800 Loss 0.4228
# Epoch 20 Batch 900 Loss 0.4442
# Epoch 20 Batch 1000 Loss 0.4115
# Epoch 20 Batch 1100 Loss 0.5029
# Epoch 20 Batch 1200 Loss 0.4523
# Epoch 20 Batch 1300 Loss 0.4280
# Epoch 20 Batch 1400 Loss 0.4338
# Epoch 20 Batch 1500 Loss 0.4417
# Epoch 20 Batch 1600 Loss 0.4347
# Epoch 20 Batch 1700 Loss 0.4595
# Epoch 20 Batch 1800 Loss 0.4521
# Epoch 20 Batch 1900 Loss 0.4252
# Epoch 20 Batch 2000 Loss 0.4373
# Epoch 20 Batch 2100 Loss 0.4314
# Epoch 20 Batch 2200 Loss 0.4267
# Epoch 20 Batch 2300 Loss 0.4326
# Epoch 20 Batch 2400 Loss 0.4579
# Epoch 20 Batch 2500 Loss 0.4464
# Epoch 20 Batch 2600 Loss 0.4346
# Epoch 20 Batch 2700 Loss 0.4846
# Epoch 20 Batch 2800 Loss 0.4465
# Epoch 20 Batch 2900 Loss 0.4120
# Epoch 20 Batch 3000 Loss 0.4433
# Epoch 20 Batch 3100 Loss 0.4131
# Epoch 20 Batch 3200 Loss 0.4574
# Epoch 20 Batch 3300 Loss 0.4276
# Epoch 20 Batch 3400 Loss 0.4090
# Epoch 20 Batch 3500 Loss 0.4318
# Epoch 20 Batch 3600 Loss 0.4638
# Epoch 20 Batch 3700 Loss 0.4320
# Epoch 20 Batch 3800 Loss 0.3943
# Epoch 20 Batch 3900 Loss 0.4241
# Epoch 20 Batch 4000 Loss 0.4209
# Epoch 20 Batch 4100 Loss 0.4655
# Epoch 20 Batch 4200 Loss 0.4321
# Epoch 20 Batch 4300 Loss 0.4267
# Epoch 20 Batch 4400 Loss 0.4414
# Epoch 20 Batch 4500 Loss 0.4488
# Epoch 20 Batch 4600 Loss 0.4286
# Epoch 20 Batch 4700 Loss 0.3917
# Epoch 20 Batch 4800 Loss 0.4337
# Epoch 20 Batch 4900 Loss 0.4658
# Epoch 20 Batch 5000 Loss 0.4067
# Epoch 20 Batch 5100 Loss 0.4141
# Epoch 20 Batch 5200 Loss 0.4659
# Epoch 20 Batch 5300 Loss 0.4498
# Epoch 20 Batch 5400 Loss 0.4667
# Epoch 20 Batch 5500 Loss 0.3911
# Epoch 20 Batch 5600 Loss 0.4283
# Epoch 20 Batch 5700 Loss 0.4402
# Epoch 20 Batch 5800 Loss 0.4304
# Epoch 20 Batch 5900 Loss 0.4415
# Epoch 20 Batch 6000 Loss 0.4360
# Epoch 20 Batch 6100 Loss 0.4619
# Epoch 20 Batch 6200 Loss 0.4247
# Epoch 20 Batch 6300 Loss 0.4708
# Epoch 20 Batch 6400 Loss 0.4110
# Epoch 20 Batch 6500 Loss 0.4205
# Epoch 20 Batch 6600 Loss 0.4035
# Epoch 20 Batch 6700 Loss 0.4418
# Epoch 20 Batch 6800 Loss 0.4332
# Epoch 20 Batch 6900 Loss 0.4336
# Epoch 20 Batch 7000 Loss 0.4398
# Epoch 20 Batch 7100 Loss 0.4901
# Epoch 20 Batch 7200 Loss 0.4102
# Epoch 20 Batch 7300 Loss 0.4454
# Epoch 20 Loss 0.437399
# Time taken for 1 epoch 1923.69 sec

# %%
plt.plot(loss_plot)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Loss Plot")
plt.grid()
plt.show()

# %%
def evaluate(image):
    attention_plot = np.zeros((max_length, attention_features_shape))

    hidden = decoder.reset_state(batch_size=1)

    temp_input = tf.expand_dims(load_image(image)[0], 0)
    img_tensor_val = image_features_extract(temp_input)
    img_tensor_val = tf.reshape(img_tensor_val, (img_tensor_val.shape[0],
                                                 -1,
                                                 img_tensor_val.shape[3]))

    features = encoder(img_tensor_val)

    dec_input = tf.expand_dims([word_to_index('<start>')], 0)
    result = []

    for i in range(max_length):
        predictions, hidden, attention_weights = decoder(dec_input,
                                                         features,
                                                         hidden)

        attention_plot[i] = tf.reshape(attention_weights, (-1, )).numpy()
        #attention_plot[i] = tf.reshape(81, (-1, )).numpy()

        predicted_id = tf.random.categorical(predictions, 1)[0][0].numpy()
        predicted_word = tf.compat.as_text(index_to_word(predicted_id).numpy())
        result.append(predicted_word)

        if predicted_word == '<end>':
            return result, attention_plot

        dec_input = tf.expand_dims([predicted_id], 0)

    attention_plot = attention_plot[:len(result), :]
    return result, attention_plot

# %%
def plot_attention(image, result, attention_plot):
    temp_image = np.array(Image.open(image))

    fig = plt.figure(figsize=(10, 10))

    len_result = len(result)
    for i in range(len_result):
        temp_att = np.resize(attention_plot[i], (8, 8))
        grid_size = max(int(np.ceil(len_result/2)), 2)
        ax = fig.add_subplot(grid_size, grid_size, i+1)
        ax.set_title(result[i])
        img = ax.imshow(temp_image)
        ax.imshow(temp_att, cmap='gray', alpha=0.6, extent=img.get_extent())

    plt.tight_layout()
    plt.show()

# %%
import nltk
from nltk.translate.bleu_score import SmoothingFunction

# %%
from operator import mod
# captions on the validation set
rid = np.random.randint(0, len(img_name_val))
image = img_name_val[rid]
real_caption = ' '.join([tf.compat.as_text(index_to_word(i).numpy())
                         for i in cap_val[rid] if i not in [0]])
result, attention_plot = evaluate(image)

print('Real Caption:', real_caption)
print('Prediction Caption:', ' '.join(result))
plot_attention(image, result, attention_plot)

print("\n\n\n\nBLEU Scores:")
predCap=" ".join(result).replace("<end>","")
modRealCap=real_caption.replace("<start>","").replace("<end>","")
print("Dataset size: ",len(img_name_train))
print("Vocabulary size : ",vocabulary_size)
print("Description length : ",max_length)

print("real caption: ",modRealCap,"\nPredicted Cap: ",predCap)
list_of_ref=[modRealCap.split(" ")]
list_of_hyp=[predCap.split(" ")]

smoothie=SmoothingFunction().method5

print("BLEU-1 : ",nltk.translate.bleu_score.corpus_bleu(list_of_ref,list_of_hyp,weights=(1.0,0,0,0),smoothing_function= smoothie))
print("BLEU-2 : ",nltk.translate.bleu_score.corpus_bleu(list_of_ref,list_of_hyp,weights=(0.5,0.5,0,0),smoothing_function=smoothie))
print("BLEU-3 : ",nltk.translate.bleu_score.corpus_bleu(list_of_ref,list_of_hyp,weights=(0.3,0.3,0.3,0),smoothing_function=smoothie))
print("BLEU-4 : ",nltk.translate.bleu_score.corpus_bleu(list_of_ref,list_of_hyp,weights=(0.25,0.25,0.25,0.25),smoothing_function=smoothie))

print(image)
# Out:
# Real Caption: <start> a woman standing behind a camera recording a ski race. <end>
# Prediction Caption: a group of people standing in the [UNK] are preparing to take pictures. <end>
# BLEU Scores:
# Dataset size:  473409
# Vocabulary size :  9490
# Description length :  50
# real caption:   a woman standing behind a camera recording a ski race.
# Predicted Cap:  a group of people standing in the [UNK] are preparing to take pictures.
# BLEU-1 :  0.38095238095238093
# BLEU-2 :  0.21994295969128597
# BLEU-3 :  0.1560897890868529
# BLEU-4 :  0.07331431989709532
# /content/train2017/000000336474.jpg

# %%
from matplotlib import pyplot as plt
from matplotlib import image as mpimg
 
plt.title("IMAGE")
plt.xlabel("X pixel scaling")
plt.ylabel("Y pixels scaling")
 
ima = mpimg.imread("/content/train2017/000000336474.jpg")
plt.imshow(ima)
plt.show()

# %%
image_url = 'https://cdn.hswstatic.com/gif/becoming-doctor.jpg'
image_extension = image_url[-4:]
image_path = tf.keras.utils.get_file('image'+image_extension, origin=image_url)

result, attention_plot = evaluate(image_path)
print('Prediction Caption:', ' '.join(result))
plot_attention(image_path, result, attention_plot)
# opening the image
Image.open(image_path)
# Out:
# Prediction Caption: a person riding a surfboard on a wave <end>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x426 at 0x7FC27A7163D0>

# %%
Image_Model.save("b7-n.h5")
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
